# %%
import tensorflow as tf
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import pandas as pd

# ========== HARDWARE ACCELERATION ==========
# Enable XLA compilation for faster math
tf.config.optimizer.set_jit(True) 
# Enable Mixed Precision (uses fp16 for speed, fp32 for stability)
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# ========== CONFIGURATION ==========

DATASET_FOLDER      = 'sample_dataset'
METADATA_CSV        = os.path.join(DATASET_FOLDER, 'metadata.csv')

# Limit dataset size for testing
TRAIN_SAMPLES    =  480 # 672
VAL_SPLIT_SIZE = 48 # 96

MAX_SAMPLES = TRAIN_SAMPLES + VAL_SPLIT_SIZE

# Dataset Filters
ALLOWED_DISTANCES = [5, 7] # [5, 7, 10]
ALLOWED_PITCHES   = [30] # [10, 30, 45]

EPOCHS              = 10
ACCUMULATION_STEPS  = 12 # batch size

MODEL_PATH_RENDERER = 'models/k3_100epch_wo_custom_loss_model.h5'
MODEL_PATH_YOLO     = 'yolov8n_saved_model'

IMG_SIZE            = (500, 500)
YOLO_SIZE           = (640, 640)
TEX_RES             = 16 
TEX_UPSCALE_RES     = 256

INITIAL_TEX_PATH    = 'textures/random_tex.png'

ATTACK_MODE         = 'misclassification'   # 'hide' or 'misclassification'

DETECTION_WEIGHT    = 18.0
TV_WEIGHT           = 10.0
NPS_WEIGHT          = 12.0

LEARNING_RATE = 0.05

NPS_DIM = 5

STEPS_PER_EPOCH = TRAIN_SAMPLES // ACCUMULATION_STEPS
TOTAL_OPTIMIZER_STEPS = STEPS_PER_EPOCH * EPOCHS

VEHICLE_CLASS_IDS   = [2, 7, 5]  # car, truck, bus

CLASSES = {
    0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus',
    6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant',
    11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat',
    16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear',
    22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag',
    27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard',
    32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove',
    36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle',
    40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl',
    46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli',
    51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake',
    56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table',
    61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard',
    67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink',
    72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors',
    77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'
}

# ========== SETUP ========== 

renderer_model = tf.keras.models.load_model(MODEL_PATH_RENDERER, compile=False)
yolo_loaded    = tf.saved_model.load(MODEL_PATH_YOLO)
yolo_infer     = yolo_loaded.signatures['serving_default']


# printable colour palette for NPS
grid_1d = tf.linspace(0.05, 0.95, NPS_DIM)
r, g, b = tf.meshgrid(grid_1d, grid_1d, grid_1d)
_colors = tf.reshape(tf.stack([r, g, b], axis=-1), [-1, 3])
TARGET_COLORS = tf.boolean_mask(_colors, (tf.reduce_max(_colors, axis=1) - tf.reduce_min(_colors, axis=1)) < 0.9)


def load_image_for_style(path):
    img = tf.image.convert_image_dtype(tf.image.decode_png(tf.io.read_file(path), channels=3), tf.float32)
    return tf.expand_dims(tf.image.resize(img, [TEX_UPSCALE_RES, TEX_UPSCALE_RES]), 0)

initial_tex = load_image_for_style(INITIAL_TEX_PATH)
# Force fp32 for our optimized variable to prevent precision loss during accumulation
tf_texture  = tf.Variable(tf.image.resize(initial_tex, [TEX_RES, TEX_RES])[0], dtype=tf.float32)
gradient_accumulator = tf.Variable(tf.zeros_like(tf_texture), trainable=False, dtype=tf.float32)

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=LEARNING_RATE,
    decay_steps=TOTAL_OPTIMIZER_STEPS,
    alpha=0.01
)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

os.makedirs('noise_checkpoints', exist_ok=True) # Directory for saving patches

# ========== SAFE DATASET PIPELINE ==========

df_meta = pd.read_csv(METADATA_CSV)

# 1. Instantly filter the dataframe to only keep allowed distances and pitches
if ALLOWED_DISTANCES:
    df_meta = df_meta[df_meta['distance'].isin(ALLOWED_DISTANCES)]
if ALLOWED_PITCHES:
    df_meta = df_meta[df_meta['pitch'].isin(ALLOWED_PITCHES)]

print(f"Found {len(df_meta)} rows in CSV matching the filters. Checking files...")

valid_filenames, valid_distances, valid_pitches, valid_yaws = [], [], [], []

# 2. Iterate through the FILTERED dataframe to check file existence
for idx, row in df_meta.iterrows():
    if len(valid_filenames) >= MAX_SAMPLES:
        break
        
    base_name = str(row['filename']).zfill(5)
    ref_path = os.path.join(DATASET_FOLDER, 'reference', f"{base_name}.png")
    mask_path = os.path.join(DATASET_FOLDER, 'masks', f"{base_name}.png")
    overlay_path = os.path.join(DATASET_FOLDER, 'overlays', f"{base_name}.png")
    
    # Only include if all 3 files exist
    if os.path.exists(ref_path) and os.path.exists(mask_path) and os.path.exists(overlay_path):
        valid_filenames.append(f"{base_name}.png")
        valid_distances.append(np.float32(row['distance']))
        valid_pitches.append(np.float32(row['pitch']))
        valid_yaws.append(np.float32(row['yaw']))

NUM_SAMPLES = len(valid_filenames)
print(f"Verified {NUM_SAMPLES} valid samples for training.")

def process_path(filename, distance, pitch, yaw):
    ref_path     = tf.strings.join([DATASET_FOLDER, tf.constant('/reference/'), filename])
    mask_path    = tf.strings.join([DATASET_FOLDER, tf.constant('/masks/'), filename])
    overlay_path = tf.strings.join([DATASET_FOLDER, tf.constant('/overlays/'), filename])

    def read_img(path):
        img = tf.image.decode_png(tf.io.read_file(path), channels=3)
        return tf.image.resize(tf.image.convert_image_dtype(img, tf.float32), IMG_SIZE)

    return read_img(ref_path), read_img(mask_path), read_img(overlay_path), tf.stack([distance, pitch, yaw])

def create_dataset():
    ds = tf.data.Dataset.from_tensor_slices((valid_filenames, valid_distances, valid_pitches, valid_yaws))
    ds = ds.shuffle(buffer_size=NUM_SAMPLES)
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

# ========== RENDERING & LOSS ==========

def calc_transforms(pitch, yaw):
    yaw_diff   = ((yaw + 45.0) % 90.0) - 45.0
    cond_front = tf.logical_and(yaw > 145.0, yaw < 215.0)
    p = tf.where(cond_front, -pitch, pitch)
    y = tf.where(cond_front, -yaw_diff, 0.0)
    r = tf.where(cond_front, 0.0, -yaw_diff)
    p = tf.where(pitch < 15.0, pitch,  p);  y = tf.where(pitch < 15.0, 0.0,       y);  r = tf.where(pitch < 15.0, -yaw_diff, r)
    p = tf.where(pitch > 35.0, -pitch, p);  y = tf.where(pitch > 35.0, -yaw_diff, y);  r = tf.where(pitch > 35.0, 0.0,       r)
    return p, y, r

def get_rotation_matrix(pitch, yaw, roll):
    s = np.pi / 180.0
    p, y, r = pitch * s, yaw * s, roll * s
    Rp = tf.stack([[1., 0., 0.], [0., tf.cos(p), -tf.sin(p)], [0., tf.sin(p), tf.cos(p)]])
    Rr = tf.stack([[tf.cos(r), 0., tf.sin(r)], [0., 1., 0.], [-tf.sin(r), 0., tf.cos(r)]])
    Ry = tf.stack([[tf.cos(y), -tf.sin(y), 0.], [tf.sin(y), tf.cos(y), 0.], [0., 0., 1.]])
    return tf.matmul(Rp, tf.matmul(Rr, Ry))

@tf.function
def render_texture(texture, pitch, yaw, roll, distance, uv_scale=100.0, shift_u=0.0, shift_v=0.0):
    out_h, out_w = IMG_SIZE
    f  = 500.0
    high_res_tex = tf.image.resize(texture, [TEX_UPSCALE_RES, TEX_UPSCALE_RES], method='nearest')
    R            = get_rotation_matrix(pitch, yaw, roll)
    plane_normal = R[:, 2]
    plane_point  = plane_normal * (distance * 100.0)

    grid_x, grid_y = tf.meshgrid(tf.range(out_w), tf.range(out_h))
    ray_dir    = tf.stack([tf.cast(grid_x, tf.float32) - out_w/2.0, tf.cast(grid_y, tf.float32) - out_h/2.0, tf.ones([out_h, out_w]) * f], axis=-1)
    camera_pos = tf.constant([0.0, 0.0, -f])

    denom = tf.tensordot(ray_dir, plane_normal, axes=1)
    denom = tf.where(tf.abs(denom) < 1e-5, 1e-5, denom)
    t     = tf.tensordot(plane_point - camera_pos, plane_normal, axes=1) / denom

    hit_point = camera_pos + ray_dir * tf.expand_dims(t, -1)
    p_local   = tf.reshape(tf.matmul(tf.reshape(hit_point - plane_point, [-1, 3]), R), [out_h, out_w, 3])

    u = tf.math.floormod(p_local[:, :, 0] / uv_scale + shift_u, 1.0)
    v = tf.math.floormod(p_local[:, :, 1] / uv_scale + shift_v, 1.0)

    tex_h = tf.cast(tf.shape(high_res_tex)[0], tf.float32)
    tex_w = tf.cast(tf.shape(high_res_tex)[1], tf.float32)

    x, y_ = u * (tex_w - 1.0), v * (tex_h - 1.0)
    x  = tf.clip_by_value(x,  0.0, tex_w - 1.001)
    y_ = tf.clip_by_value(y_, 0.0, tex_h - 1.001)
    x0, y0 = tf.cast(tf.floor(x), tf.int32), tf.cast(tf.floor(y_), tf.int32)
    x1, y1 = x0 + 1, y0 + 1
    Ia, Ib = tf.gather_nd(high_res_tex, tf.stack([y0, x0], axis=-1)), tf.gather_nd(high_res_tex, tf.stack([y1, x0], axis=-1))
    Ic, Id = tf.gather_nd(high_res_tex, tf.stack([y0, x1], axis=-1)), tf.gather_nd(high_res_tex, tf.stack([y1, x1], axis=-1))
    wa = tf.expand_dims((tf.cast(x1, tf.float32) - x)  * (tf.cast(y1, tf.float32) - y_), -1)
    wb = tf.expand_dims((tf.cast(x1, tf.float32) - x)  * (y_ - tf.cast(y0, tf.float32)), -1)
    wc = tf.expand_dims((x - tf.cast(x0, tf.float32))  * (tf.cast(y1, tf.float32) - y_), -1)
    wd = tf.expand_dims((x - tf.cast(x0, tf.float32))  * (y_ - tf.cast(y0, tf.float32)), -1)
    output = tf.add_n([wa*Ia, wb*Ib, wc*Ic, wd*Id])

    return tf.where(tf.expand_dims(t > 0.0, -1), output, tf.zeros_like(output))

@tf.function
def compute_image_gradients(ref_img, mask_img, overlay_img, trans_tf, shift_u, shift_v):
    dist, pitch, yaw = trans_tf[0], trans_tf[1], trans_tf[2]
    p, y, r = calc_transforms(pitch, yaw)

    with tf.GradientTape() as tape:
        rendered   = render_texture(tf_texture, p, y, r, dist, shift_u=shift_u, shift_v=shift_v)
        tex_masked = tf.where(tf.reduce_max(mask_img, axis=-1, keepdims=True) > 0.1, rendered, tf.zeros_like(rendered))
        
        # Explicit FP32 casts for safety with Mixed Precision
        ref_f32 = tf.cast(ref_img, tf.float32)
        tex_masked_f32 = tf.cast(tex_masked, tf.float32)
        renderer_out = renderer_model([tf.expand_dims(ref_f32, 0), tf.expand_dims(tex_masked_f32, 0)], training=False)[0]
        
        adv_img  = tf.where(tf.reduce_max(overlay_img, axis=-1, keepdims=True) > 0.05, ref_img, renderer_out)
        yolo_in  = tf.cast(tf.image.resize(tf.expand_dims(adv_img, 0), YOLO_SIZE), tf.float32)
        yolo_out = yolo_infer(images=yolo_in)['output_0']

        all_class_scores = yolo_out[0, 4:, :]
        vehicle_scores   = tf.reduce_max(tf.gather(all_class_scores, VEHICLE_CLASS_IDS, axis=0), axis=0)
        
        if ATTACK_MODE == 'misclassification':
            all_idx = tf.range(tf.shape(all_class_scores)[0])
            non_vehicle_mask = tf.reduce_all(tf.not_equal(tf.expand_dims(all_idx, 1), tf.constant(VEHICLE_CLASS_IDS, dtype=all_idx.dtype)), axis=1)
            non_vehicle_scores = tf.reduce_max(tf.boolean_mask(all_class_scores, non_vehicle_mask, axis=0), axis=0)
            det_loss = tf.reduce_max(vehicle_scores - non_vehicle_scores)
        else:
            det_loss = tf.reduce_max(vehicle_scores)
            
        det_weighted_loss = DETECTION_WEIGHT * det_loss

    grads = tape.gradient(det_weighted_loss, tf_texture)
    return grads, det_loss, adv_img, yolo_out

@tf.function
def apply_accumulated_gradients(accumulated_image_grads, num_steps):
    averaged_image_grads = accumulated_image_grads / tf.cast(num_steps, tf.float32)
    
    with tf.GradientTape(persistent=True) as tape:
        tex_f32 = tf.cast(tf_texture, tf.float32) # Explicit FP32

        tv_loss  = TV_WEIGHT * tf.reduce_sum(tf.image.total_variation(tex_f32)) / tf.cast(tf.size(tex_f32), tf.float32)
        nps_loss = NPS_WEIGHT * tf.reduce_mean(tf.reduce_min(tf.sqrt(tf.reduce_sum(tf.square(tf.expand_dims(tf.reshape(tex_f32, [-1, 3]), 1) - TARGET_COLOURS) + 1e-8, axis=-1)), axis=1))

        
        nps_tv_loss= tv_loss + nps_loss

    nps_tv_grads = tape.gradient(nps_tv_loss, tf_texture)

    final_grads   = averaged_image_grads + nps_tv_grads 


    yolo_force = tf.norm(averaged_image_grads)

    nps_tv_force = tf.norm(nps_tv_grads)

    
    optimizer.apply_gradients([(final_grads, tf_texture)])
    tf_texture.assign(tf.clip_by_value(tf_texture, 0.0, 1.0))
    
    return tv_loss, nps_loss, yolo_force, nps_tv_force

def draw_yolo_results(image_tf, yolo_output, conf_thresh=0.25):
    img    = (image_tf.numpy() * 255).astype(np.uint8).copy()
    output = np.transpose(yolo_output.numpy()[0])
    scale  = [IMG_SIZE[1] / YOLO_SIZE[1], IMG_SIZE[0] / YOLO_SIZE[0]] * 2

    boxes, confs, class_ids = [], [], []
    for row in output:
        cls_id = np.argmax(row[4:])
        score  = row[4:][cls_id]
        if score > conf_thresh:
            cx, cy, w, h = row[:4] * scale
            boxes.append([int(cx - w/2), int(cy - h/2), int(w), int(h)])
            confs.append(float(score));  class_ids.append(cls_id)

    indices = cv2.dnn.NMSBoxes(boxes, confs, conf_thresh, 0.45)
    if len(indices) > 0:
        for i in indices.flatten():
            bx, by, bw, bh = boxes[i]
            cv2.rectangle(img, (bx, by), (bx+bw, by+bh), (0, 255, 0), 2)
            cv2.putText(img, f"{CLASSES.get(class_ids[i], 'obj')}: {confs[i]:.2f}", (bx, by-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    return img

# ========== DATASET SPLIT & MAIN LOOP ==========


train_filenames = valid_filenames[:-VAL_SPLIT_SIZE]
train_distances = valid_distances[:-VAL_SPLIT_SIZE]
train_pitches   = valid_pitches[:-VAL_SPLIT_SIZE]
train_yaws      = valid_yaws[:-VAL_SPLIT_SIZE]

val_filenames = valid_filenames[-VAL_SPLIT_SIZE:]
val_distances = valid_distances[-VAL_SPLIT_SIZE:]
val_pitches   = valid_pitches[-VAL_SPLIT_SIZE:]
val_yaws      = valid_yaws[-VAL_SPLIT_SIZE:]

NUM_TRAIN = len(train_filenames)
print(f"Split dataset: {NUM_TRAIN} for training, {VAL_SPLIT_SIZE} for validation.")

def create_dataset_split(f, d, p, y, shuffle=True):
    ds = tf.data.Dataset.from_tensor_slices((f, d, p, y))
    if shuffle: ds = ds.shuffle(buffer_size=len(f))
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    return ds.prefetch(tf.data.AUTOTUNE)

history = {'det': [], 'tv': [], 'nps': [], 'val_det': []}

for epoch in range(EPOCHS):
    print(f"\n--- Epoch {epoch + 1}/{EPOCHS} ---")
    
    train_dataset = create_dataset_split(train_filenames, train_distances, train_pitches, train_yaws, shuffle=True)
    gradient_accumulator.assign(tf.zeros_like(tf_texture))
    accumulated_count = 0
    step_det_losses = [] 
    
    last_tv, last_nps= 0.0, 0.0
    
    # --- TRAINING LOOP ---
    for step, (ref, mask, overlay, trans_tf) in enumerate(train_dataset):
        shift_u = tf.random.uniform(shape=[], minval=0.0, maxval=1.0)
        shift_v = tf.random.uniform(shape=[], minval=0.0, maxval=1.0)

        grads, det_loss, cur_adv, cur_yolo = compute_image_gradients(ref, mask, overlay, trans_tf, shift_u, shift_v)
        gradient_accumulator.assign_add(grads)
        accumulated_count += 1
        step_det_losses.append(det_loss.numpy())

        # Clean modulo check for flushing
        if (step + 1) % ACCUMULATION_STEPS == 0:
            tv_val, nps_val, yolo_force, nps_tv_force = apply_accumulated_gradients(gradient_accumulator, accumulated_count)

            last_tv, last_nps = tv_val.numpy(), nps_val.numpy()
            current_avg_det = np.mean(step_det_losses)
            
            # Print BEFORE we clear the array!
            print(f"Step {step+1:4d}/{NUM_TRAIN} | Batch Avg Det: {current_avg_det:.4f} | W-NPS: {last_nps:.4f} | W-TV: {last_tv:.4f} | YOLO force: {yolo_force.numpy():.6f} | NPS & TV force: {nps_tv_force.numpy():.6f}")

            history['det'].append(current_avg_det)
            history['tv'].append(last_tv); history['nps'].append(last_nps)
            
            gradient_accumulator.assign(tf.zeros_like(tf_texture))
            accumulated_count = 0
            step_det_losses = []

    # Unconditional safety flush at end of epoch
    if accumulated_count > 0:
        tv_val, nps_val = apply_accumulated_gradients(gradient_accumulator, accumulated_count)
        history['det'].append(np.mean(step_det_losses))
        history['tv'].append(tv_val.numpy()); history['nps'].append(nps_val.numpy())

    # --- VALIDATION LOOP ---
    val_dataset = create_dataset_split(val_filenames, val_distances, val_pitches, val_yaws, shuffle=False)
    val_losses = []
    
    for val_ref, val_mask, val_overlay, val_trans in val_dataset:
        # Pass through without gradients
        _, v_det, _, _ = compute_image_gradients(val_ref, val_mask, val_overlay, val_trans, 0.0, 0.0)
        val_losses.append(v_det.numpy())
        
    epoch_val_det = np.mean(val_losses)
    history['val_det'].append(epoch_val_det)

    current_lr = lr_schedule(optimizer.iterations).numpy()
    
    print(f">> EPOCH {epoch+1} SUMMARY | Train Det: {np.mean(history['det'][-(NUM_TRAIN//ACCUMULATION_STEPS):]):.4f} | Val Det: {epoch_val_det:.4f} | LR: {current_lr:.6f} <<")

    # Checkpoint the texture
    patch_bgr = cv2.cvtColor((tf.clip_by_value(tf_texture, 0.0, 1.0).numpy() * 255).astype(np.uint8), cv2.COLOR_RGB2BGR)
    cv2.imwrite(f"noise_checkpoints/patch_epoch_{epoch+1}.png", patch_bgr)

print("\nTraining complete. Patch saved to noise_checkpoints folder.")

# ========== VISUALISATION ==========
print("Visualizing results on a random test image from the loaded dataset...")

# Fetch one random sample from our validated lists
test_idx = np.random.randint(0, NUM_SAMPLES)
test_base_name = valid_filenames[test_idx]
ref_test = tf.image.resize(tf.image.convert_image_dtype(tf.image.decode_png(tf.io.read_file(os.path.join(DATASET_FOLDER, 'reference', test_base_name)), channels=3), tf.float32), IMG_SIZE)
mask_test = tf.image.resize(tf.image.convert_image_dtype(tf.image.decode_png(tf.io.read_file(os.path.join(DATASET_FOLDER, 'masks', test_base_name)), channels=3), tf.float32), IMG_SIZE)
overlay_test = tf.image.resize(tf.image.convert_image_dtype(tf.image.decode_png(tf.io.read_file(os.path.join(DATASET_FOLDER, 'overlays', test_base_name)), channels=3), tf.float32), IMG_SIZE)
trans_tf_test = tf.constant(np.array([valid_distances[test_idx], valid_pitches[test_idx], valid_yaws[test_idx]], dtype=np.float32))

# Baseline detection
ref_f32 = tf.cast(ref_test, tf.float32)
ref_yolo_in = tf.cast(tf.image.resize(tf.expand_dims(ref_f32, 0), YOLO_SIZE), tf.float32)
ref_yolo_out = yolo_infer(images=ref_yolo_in)['output_0']
ref_max_conf = tf.reduce_max(tf.stack([ref_yolo_out[0, 4 + c, :] for c in VEHICLE_CLASS_IDS]))

# Attack with Final Optimized Texture
p_test, y_test, r_test = calc_transforms(trans_tf_test[1], trans_tf_test[2])
test_rendered     = render_texture(tf_texture, p_test, y_test, r_test, trans_tf_test[0])
test_tex_masked   = tf.where(tf.reduce_max(mask_test, axis=-1, keepdims=True) > 0.1, test_rendered, tf.zeros_like(test_rendered))
test_renderer_out = renderer_model([tf.expand_dims(ref_f32, 0), tf.expand_dims(tf.cast(test_tex_masked, tf.float32), 0)], training=False)[0]
test_adv          = tf.where(tf.reduce_max(overlay_test, axis=-1, keepdims=True) > 0.05, ref_test, test_renderer_out)
test_yolo_in      = tf.cast(tf.image.resize(tf.expand_dims(test_adv, 0), YOLO_SIZE), tf.float32)
test_yolo         = yolo_infer(images=test_yolo_in)['output_0']

weighted_det_history = [x * DETECTION_WEIGHT for x in history['det']]

# Plot Results
plt.figure(figsize=(18, 10))

plt.subplot(2, 2, 1);  plt.imshow(draw_yolo_results(ref_test, ref_yolo_out));   plt.title(f"Original Reference (Conf: {ref_max_conf.numpy():.4f})")
plt.subplot(2, 2, 2);  plt.imshow(draw_yolo_results(test_adv, test_yolo));      plt.title(f"Optimized State")

plt.subplot(2, 2, 3)
plt.plot(weighted_det_history,   label='Weighted Detection',      linestyle='--')
plt.plot(history['nps'],   label='Weighted NPS',   linestyle='-.')
plt.plot(history['tv'],    label='Weighted TV',    linestyle=':')
plt.title("Loss Components (Per Accumulation Window)");  plt.xlabel("Accumulation Steps");  plt.legend()

plt.subplot(2, 2, 4);  
plt.imshow(tf.clip_by_value(tf_texture, 0.0, 1.0).numpy()); plt.title("Final Optimized Patch")

plt.tight_layout()
plt.show()
# Out:
# Found 5394 rows in CSV matching the filters. Checking files...
# Verified 528 valid samples for training.
# Split dataset: 480 for training, 48 for validation.
#
# --- Epoch 1/10 ---
# Step   12/480 | Batch Avg Det: 0.4864 | W-NPS: 2.1494 | W-TV: 6.1025 | YOLO force: 2.628861 | NPS & TV force: 1.385909
# Step   24/480 | Batch Avg Det: 0.3872 | W-NPS: 1.9850 | W-TV: 5.8676 | YOLO force: 3.577907 | NPS & TV force: 1.359997
# Step   36/480 | Batch Avg Det: 0.5346 | W-NPS: 1.9027 | W-TV: 5.7133 | YOLO force: 3.200213 | NPS & TV force: 1.332578
# Step   48/480 | Batch Avg Det: 0.4424 | W-NPS: 1.8898 | W-TV: 5.5798 | YOLO force: 4.154801 | NPS & TV force: 1.315175
# Step   60/480 | Batch Avg Det: 0.4771 | W-NPS: 1.8911 | W-TV: 5.4695 | YOLO force: 4.419487 | NPS & TV force: 1.297825
# Step   72/480 | Batch Avg Det: 0.4485 | W-NPS: 1.9103 | W-TV: 5.3876 | YOLO force: 3.791368 | NPS & TV force: 1.294279
# Step   84/480 | Batch Avg Det: 0.4740 | W-NPS: 1.9483 | W-TV: 5.3200 | YOLO force: 4.392325 | NPS & TV force: 1.284981
# Step   96/480 | Batch Avg Det: 0.2306 | W-NPS: 1.9983 | W-TV: 5.2521 | YOLO force: 2.790770 | NPS & TV force: 1.282061
# Step  108/480 | Batch Avg Det: 0.2653 | W-NPS: 2.0528 | W-TV: 5.1952 | YOLO force: 4.893305 | NPS & TV force: 1.270205
# Step  120/480 | Batch Avg Det: 0.2188 | W-NPS: 2.1070 | W-TV: 5.1581 | YOLO force: 3.412757 | NPS & TV force: 1.282253
# Step  132/480 | Batch Avg Det: 0.1940 | W-NPS: 2.1528 | W-TV: 5.1179 | YOLO force: 3.777608 | NPS & TV force: 1.275250
# Step  144/480 | Batch Avg Det: 0.1659 | W-NPS: 2.1909 | W-TV: 5.0793 | YOLO force: 3.003999 | NPS & TV force: 1.273134
# Step  156/480 | Batch Avg Det: 0.3508 | W-NPS: 2.2159 | W-TV: 5.0387 | YOLO force: 3.886871 | NPS & TV force: 1.276051
# Step  168/480 | Batch Avg Det: 0.3535 | W-NPS: 2.2310 | W-TV: 4.9929 | YOLO force: 3.468644 | NPS & TV force: 1.280645
# Step  180/480 | Batch Avg Det: 0.1274 | W-NPS: 2.2491 | W-TV: 4.9506 | YOLO force: 3.575021 | NPS & TV force: 1.286855
# Step  192/480 | Batch Avg Det: 0.2058 | W-NPS: 2.2742 | W-TV: 4.9000 | YOLO force: 2.512669 | NPS & TV force: 1.282298
# Step  204/480 | Batch Avg Det: 0.1916 | W-NPS: 2.2975 | W-TV: 4.8476 | YOLO force: 2.647169 | NPS & TV force: 1.280015
# Step  216/480 | Batch Avg Det: 0.2076 | W-NPS: 2.3167 | W-TV: 4.7929 | YOLO force: 1.797146 | NPS & TV force: 1.275034
# Step  228/480 | Batch Avg Det: 0.1254 | W-NPS: 2.3280 | W-TV: 4.7387 | YOLO force: 2.993318 | NPS & TV force: 1.269833
# Step  240/480 | Batch Avg Det: 0.1225 | W-NPS: 2.3282 | W-TV: 4.6778 | YOLO force: 3.019277 | NPS & TV force: 1.267918
# Step  252/480 | Batch Avg Det: 0.2040 | W-NPS: 2.3182 | W-TV: 4.6110 | YOLO force: 3.775254 | NPS & TV force: 1.260027
# Step  264/480 | Batch Avg Det: 0.2312 | W-NPS: 2.3166 | W-TV: 4.5721 | YOLO force: 1.382016 | NPS & TV force: 1.258623
# Step  276/480 | Batch Avg Det: 0.0921 | W-NPS: 2.3085 | W-TV: 4.5205 | YOLO force: 1.719964 | NPS & TV force: 1.266399
# Step  288/480 | Batch Avg Det: 0.1880 | W-NPS: 2.2928 | W-TV: 4.4645 | YOLO force: 1.788273 | NPS & TV force: 1.260672
# Step  300/480 | Batch Avg Det: 0.1326 | W-NPS: 2.2699 | W-TV: 4.4018 | YOLO force: 3.442085 | NPS & TV force: 1.255071
# Step  312/480 | Batch Avg Det: 0.1681 | W-NPS: 2.2383 | W-TV: 4.3381 | YOLO force: 3.262612 | NPS & TV force: 1.239043
# Step  324/480 | Batch Avg Det: 0.0714 | W-NPS: 2.2052 | W-TV: 4.2817 | YOLO force: 1.702451 | NPS & TV force: 1.239905
# Step  336/480 | Batch Avg Det: 0.2119 | W-NPS: 2.1688 | W-TV: 4.2182 | YOLO force: 1.588839 | NPS & TV force: 1.227070
# Step  348/480 | Batch Avg Det: 0.1275 | W-NPS: 2.1298 | W-TV: 4.1466 | YOLO force: 2.248326 | NPS & TV force: 1.214264
# Step  360/480 | Batch Avg Det: 0.0807 | W-NPS: 2.0924 | W-TV: 4.0817 | YOLO force: 0.784475 | NPS & TV force: 1.206977
# Step  372/480 | Batch Avg Det: 0.1645 | W-NPS: 2.0455 | W-TV: 4.0141 | YOLO force: 2.584689 | NPS & TV force: 1.196842
# Step  384/480 | Batch Avg Det: 0.1302 | W-NPS: 2.0007 | W-TV: 3.9552 | YOLO force: 2.441381 | NPS & TV force: 1.183378
# Step  396/480 | Batch Avg Det: 0.1143 | W-NPS: 1.9641 | W-TV: 3.8971 | YOLO force: 1.570604 | NPS & TV force: 1.173920
# Step  408/480 | Batch Avg Det: 0.0755 | W-NPS: 1.9278 | W-TV: 3.8446 | YOLO force: 0.850882 | NPS & TV force: 1.179939
# Step  420/480 | Batch Avg Det: 0.1648 | W-NPS: 1.8863 | W-TV: 3.7872 | YOLO force: 1.870233 | NPS & TV force: 1.177442
# Step  432/480 | Batch Avg Det: 0.2279 | W-NPS: 1.8475 | W-TV: 3.7337 | YOLO force: 2.914882 | NPS & TV force: 1.165434
# Step  444/480 | Batch Avg Det: 0.1025 | W-NPS: 1.8122 | W-TV: 3.6793 | YOLO force: 1.340304 | NPS & TV force: 1.163241
# Step  456/480 | Batch Avg Det: 0.2537 | W-NPS: 1.7818 | W-TV: 3.6243 | YOLO force: 2.725101 | NPS & TV force: 1.154706
# Step  468/480 | Batch Avg Det: 0.1604 | W-NPS: 1.7596 | W-TV: 3.5824 | YOLO force: 2.327241 | NPS & TV force: 1.145840
# Step  480/480 | Batch Avg Det: 0.1155 | W-NPS: 1.7382 | W-TV: 3.5542 | YOLO force: 1.235173 | NPS & TV force: 1.149898
# >> EPOCH 1 SUMMARY | Train Det: 0.2257 | Val Det: 0.0818 | LR: 0.048789 <<
#
# --- Epoch 2/10 ---
# Step   12/480 | Batch Avg Det: 0.1600 | W-NPS: 1.7087 | W-TV: 3.5255 | YOLO force: 2.837642 | NPS & TV force: 1.137688
# Step   24/480 | Batch Avg Det: 0.1524 | W-NPS: 1.6811 | W-TV: 3.5068 | YOLO force: 2.354846 | NPS & TV force: 1.128245
# Step   36/480 | Batch Avg Det: 0.1041 | W-NPS: 1.6582 | W-TV: 3.4826 | YOLO force: 3.017445 | NPS & TV force: 1.127158
# Step   48/480 | Batch Avg Det: 0.1462 | W-NPS: 1.6420 | W-TV: 3.4708 | YOLO force: 1.831377 | NPS & TV force: 1.120289
# Step   60/480 | Batch Avg Det: 0.1831 | W-NPS: 1.6285 | W-TV: 3.4591 | YOLO force: 2.037499 | NPS & TV force: 1.126169
# Step   72/480 | Batch Avg Det: 0.1392 | W-NPS: 1.6117 | W-TV: 3.4417 | YOLO force: 3.012628 | NPS & TV force: 1.130889
# Step   84/480 | Batch Avg Det: 0.0926 | W-NPS: 1.6025 | W-TV: 3.4225 | YOLO force: 1.720918 | NPS & TV force: 1.139513
# Step   96/480 | Batch Avg Det: 0.1353 | W-NPS: 1.5899 | W-TV: 3.3967 | YOLO force: 2.071364 | NPS & TV force: 1.133769
# Step  108/480 | Batch Avg Det: 0.2690 | W-NPS: 1.5741 | W-TV: 3.3638 | YOLO force: 2.328917 | NPS & TV force: 1.135713
# Step  120/480 | Batch Avg Det: 0.1446 | W-NPS: 1.5527 | W-TV: 3.3326 | YOLO force: 1.907258 | NPS & TV force: 1.136086
# Step  132/480 | Batch Avg Det: 0.1130 | W-NPS: 1.5330 | W-TV: 3.3015 | YOLO force: 2.138691 | NPS & TV force: 1.135873
# Step  144/480 | Batch Avg Det: 0.1532 | W-NPS: 1.5089 | W-TV: 3.2756 | YOLO force: 1.518330 | NPS & TV force: 1.137235
# Step  156/480 | Batch Avg Det: 0.1408 | W-NPS: 1.4782 | W-TV: 3.2516 | YOLO force: 2.440554 | NPS & TV force: 1.134115
# Step  168/480 | Batch Avg Det: 0.2486 | W-NPS: 1.4466 | W-TV: 3.2265 | YOLO force: 3.294985 | NPS & TV force: 1.125253
# Step  180/480 | Batch Avg Det: 0.0820 | W-NPS: 1.4207 | W-TV: 3.2207 | YOLO force: 1.066503 | NPS & TV force: 1.136151
# Step  192/480 | Batch Avg Det: 0.1345 | W-NPS: 1.3968 | W-TV: 3.2174 | YOLO force: 1.113201 | NPS & TV force: 1.148022
# Step  204/480 | Batch Avg Det: 0.0732 | W-NPS: 1.3677 | W-TV: 3.2096 | YOLO force: 0.879690 | NPS & TV force: 1.158211
# Step  216/480 | Batch Avg Det: 0.1202 | W-NPS: 1.3315 | W-TV: 3.1884 | YOLO force: 2.337723 | NPS & TV force: 1.151419
# Step  228/480 | Batch Avg Det: 0.1363 | W-NPS: 1.2945 | W-TV: 3.1658 | YOLO force: 2.237993 | NPS & TV force: 1.150254
# Step  240/480 | Batch Avg Det: 0.0662 | W-NPS: 1.2621 | W-TV: 3.1440 | YOLO force: 2.596747 | NPS & TV force: 1.143050
# Step  252/480 | Batch Avg Det: 0.2120 | W-NPS: 1.2388 | W-TV: 3.1193 | YOLO force: 1.417762 | NPS & TV force: 1.129545
# Step  264/480 | Batch Avg Det: 0.1801 | W-NPS: 1.2192 | W-TV: 3.0943 | YOLO force: 2.296875 | NPS & TV force: 1.109229
# Step  276/480 | Batch Avg Det: 0.2645 | W-NPS: 1.2099 | W-TV: 3.0709 | YOLO force: 2.430508 | NPS & TV force: 1.101454
# Step  288/480 | Batch Avg Det: 0.2167 | W-NPS: 1.2049 | W-TV: 3.0586 | YOLO force: 2.567513 | NPS & TV force: 1.107383
# Step  300/480 | Batch Avg Det: 0.1549 | W-NPS: 1.2039 | W-TV: 3.0586 | YOLO force: 1.869811 | NPS & TV force: 1.115364
# Step  312/480 | Batch Avg Det: 0.1063 | W-NPS: 1.2051 | W-TV: 3.0554 | YOLO force: 2.229267 | NPS & TV force: 1.123501
# Step  324/480 | Batch Avg Det: 0.0802 | W-NPS: 1.2093 | W-TV: 3.0473 | YOLO force: 1.071833 | NPS & TV force: 1.148161
# Step  336/480 | Batch Avg Det: 0.0861 | W-NPS: 1.2133 | W-TV: 3.0316 | YOLO force: 0.532161 | NPS & TV force: 1.141238
# Step  348/480 | Batch Avg Det: 0.1864 | W-NPS: 1.2120 | W-TV: 3.0091 | YOLO force: 1.140177 | NPS & TV force: 1.132406
# Step  360/480 | Batch Avg Det: 0.0537 | W-NPS: 1.2068 | W-TV: 2.9813 | YOLO force: 1.310887 | NPS & TV force: 1.124116
# Step  372/480 | Batch Avg Det: 0.1897 | W-NPS: 1.1950 | W-TV: 2.9520 | YOLO force: 2.684208 | NPS & TV force: 1.107989
# Step  384/480 | Batch Avg Det: 0.1800 | W-NPS: 1.1895 | W-TV: 2.9347 | YOLO force: 1.198446 | NPS & TV force: 1.102581
# Step  396/480 | Batch Avg Det: 0.1891 | W-NPS: 1.1833 | W-TV: 2.9208 | YOLO force: 2.115104 | NPS & TV force: 1.087077
# Step  408/480 | Batch Avg Det: 0.1286 | W-NPS: 1.1783 | W-TV: 2.9030 | YOLO force: 2.343494 | NPS & TV force: 1.076662
# Step  420/480 | Batch Avg Det: 0.1200 | W-NPS: 1.1739 | W-TV: 2.8861 | YOLO force: 2.489850 | NPS & TV force: 1.084109
# Step  432/480 | Batch Avg Det: 0.1198 | W-NPS: 1.1760 | W-TV: 2.8770 | YOLO force: 2.156444 | NPS & TV force: 1.093049
# Step  444/480 | Batch Avg Det: 0.1347 | W-NPS: 1.1783 | W-TV: 2.8721 | YOLO force: 1.625529 | NPS & TV force: 1.119201
# Step  456/480 | Batch Avg Det: 0.1122 | W-NPS: 1.1801 | W-TV: 2.8606 | YOLO force: 2.206062 | NPS & TV force: 1.120527
# Step  468/480 | Batch Avg Det: 0.2238 | W-NPS: 1.1864 | W-TV: 2.8489 | YOLO force: 1.199171 | NPS & TV force: 1.110069
# Step  480/480 | Batch Avg Det: 0.1390 | W-NPS: 1.1884 | W-TV: 2.8360 | YOLO force: 2.553885 | NPS & TV force: 1.120117
# >> EPOCH 2 SUMMARY | Train Det: 0.1468 | Val Det: 0.0813 | LR: 0.045273 <<
#
# --- Epoch 3/10 ---
# Step   12/480 | Batch Avg Det: 0.1094 | W-NPS: 1.1878 | W-TV: 2.8255 | YOLO force: 2.412396 | NPS & TV force: 1.121634
# Step   24/480 | Batch Avg Det: 0.1799 | W-NPS: 1.1830 | W-TV: 2.8247 | YOLO force: 2.569757 | NPS & TV force: 1.124869
# Step   36/480 | Batch Avg Det: 0.1319 | W-NPS: 1.1769 | W-TV: 2.8335 | YOLO force: 3.192292 | NPS & TV force: 1.143516
# Step   48/480 | Batch Avg Det: 0.1252 | W-NPS: 1.1738 | W-TV: 2.8534 | YOLO force: 1.616626 | NPS & TV force: 1.162014
# Step   60/480 | Batch Avg Det: 0.0957 | W-NPS: 1.1723 | W-TV: 2.8729 | YOLO force: 1.918854 | NPS & TV force: 1.172622
# Step   72/480 | Batch Avg Det: 0.1218 | W-NPS: 1.1671 | W-TV: 2.8851 | YOLO force: 1.553849 | NPS & TV force: 1.185020
# Step   84/480 | Batch Avg Det: 0.2192 | W-NPS: 1.1533 | W-TV: 2.8842 | YOLO force: 3.296458 | NPS & TV force: 1.185535
# Step   96/480 | Batch Avg Det: 0.1201 | W-NPS: 1.1448 | W-TV: 2.8861 | YOLO force: 0.963441 | NPS & TV force: 1.186457
# Step  108/480 | Batch Avg Det: 0.0991 | W-NPS: 1.1348 | W-TV: 2.8852 | YOLO force: 1.417845 | NPS & TV force: 1.182006
# Step  120/480 | Batch Avg Det: 0.1624 | W-NPS: 1.1215 | W-TV: 2.8763 | YOLO force: 2.733354 | NPS & TV force: 1.174462
# Step  132/480 | Batch Avg Det: 0.1149 | W-NPS: 1.1069 | W-TV: 2.8599 | YOLO force: 1.264027 | NPS & TV force: 1.182286
# Step  144/480 | Batch Avg Det: 0.1424 | W-NPS: 1.0904 | W-TV: 2.8428 | YOLO force: 3.645885 | NPS & TV force: 1.182286
# Step  156/480 | Batch Avg Det: 0.1305 | W-NPS: 1.0852 | W-TV: 2.8417 | YOLO force: 1.484266 | NPS & TV force: 1.182770
# Step  168/480 | Batch Avg Det: 0.1519 | W-NPS: 1.0838 | W-TV: 2.8414 | YOLO force: 1.378312 | NPS & TV force: 1.182200
# Step  180/480 | Batch Avg Det: 0.1110 | W-NPS: 1.0816 | W-TV: 2.8365 | YOLO force: 1.906444 | NPS & TV force: 1.175081
# Step  192/480 | Batch Avg Det: 0.1575 | W-NPS: 1.0757 | W-TV: 2.8327 | YOLO force: 2.060589 | NPS & TV force: 1.176853
# Step  204/480 | Batch Avg Det: 0.0629 | W-NPS: 1.0673 | W-TV: 2.8285 | YOLO force: 1.945735 | NPS & TV force: 1.182409
# Step  216/480 | Batch Avg Det: 0.0853 | W-NPS: 1.0520 | W-TV: 2.8189 | YOLO force: 1.603427 | NPS & TV force: 1.185042
# Step  228/480 | Batch Avg Det: 0.1235 | W-NPS: 1.0380 | W-TV: 2.8071 | YOLO force: 1.645055 | NPS & TV force: 1.166354
# Step  240/480 | Batch Avg Det: 0.1365 | W-NPS: 1.0233 | W-TV: 2.7937 | YOLO force: 2.743891 | NPS & TV force: 1.176935
# Step  252/480 | Batch Avg Det: 0.0865 | W-NPS: 1.0108 | W-TV: 2.7936 | YOLO force: 1.612910 | NPS & TV force: 1.157419
# Step  264/480 | Batch Avg Det: 0.1629 | W-NPS: 1.0002 | W-TV: 2.7928 | YOLO force: 0.446736 | NPS & TV force: 1.153208
# Step  276/480 | Batch Avg Det: 0.0713 | W-NPS: 0.9830 | W-TV: 2.7845 | YOLO force: 1.973964 | NPS & TV force: 1.141505
# Step  288/480 | Batch Avg Det: 0.1092 | W-NPS: 0.9606 | W-TV: 2.7751 | YOLO force: 2.188957 | NPS & TV force: 1.133945
# Step  300/480 | Batch Avg Det: 0.1591 | W-NPS: 0.9416 | W-TV: 2.7693 | YOLO force: 1.361189 | NPS & TV force: 1.128531
# Step  312/480 | Batch Avg Det: 0.1097 | W-NPS: 0.9232 | W-TV: 2.7625 | YOLO force: 1.295648 | NPS & TV force: 1.119651
# Step  324/480 | Batch Avg Det: 0.1604 | W-NPS: 0.9015 | W-TV: 2.7491 | YOLO force: 1.366797 | NPS & TV force: 1.106252
# Step  336/480 | Batch Avg Det: 0.1827 | W-NPS: 0.8821 | W-TV: 2.7287 | YOLO force: 2.611615 | NPS & TV force: 1.105481
# Step  348/480 | Batch Avg Det: 0.1141 | W-NPS: 0.8613 | W-TV: 2.7170 | YOLO force: 2.501581 | NPS & TV force: 1.111368
# Step  360/480 | Batch Avg Det: 0.3304 | W-NPS: 0.8442 | W-TV: 2.7122 | YOLO force: 4.283699 | NPS & TV force: 1.119552
# Step  372/480 | Batch Avg Det: 0.1751 | W-NPS: 0.8558 | W-TV: 2.7219 | YOLO force: 0.883553 | NPS & TV force: 1.138613
# Step  384/480 | Batch Avg Det: 0.1458 | W-NPS: 0.8826 | W-TV: 2.7324 | YOLO force: 1.628372 | NPS & TV force: 1.141303
# Step  396/480 | Batch Avg Det: 0.1352 | W-NPS: 0.9084 | W-TV: 2.7407 | YOLO force: 3.242151 | NPS & TV force: 1.147065
# Step  408/480 | Batch Avg Det: 0.1126 | W-NPS: 0.9331 | W-TV: 2.7625 | YOLO force: 1.715160 | NPS & TV force: 1.150108
# Step  420/480 | Batch Avg Det: 0.1042 | W-NPS: 0.9572 | W-TV: 2.7851 | YOLO force: 1.072827 | NPS & TV force: 1.157098
# Step  432/480 | Batch Avg Det: 0.1503 | W-NPS: 0.9693 | W-TV: 2.8011 | YOLO force: 2.206902 | NPS & TV force: 1.165502
# Step  444/480 | Batch Avg Det: 0.1028 | W-NPS: 0.9727 | W-TV: 2.8095 | YOLO force: 2.246023 | NPS & TV force: 1.171696
# Step  456/480 | Batch Avg Det: 0.1564 | W-NPS: 0.9719 | W-TV: 2.8146 | YOLO force: 2.978283 | NPS & TV force: 1.168721
# Step  468/480 | Batch Avg Det: 0.1564 | W-NPS: 0.9712 | W-TV: 2.8162 | YOLO force: 2.134936 | NPS & TV force: 1.159346
# Step  480/480 | Batch Avg Det: 0.1693 | W-NPS: 0.9772 | W-TV: 2.8178 | YOLO force: 1.266131 | NPS & TV force: 1.151827
# >> EPOCH 3 SUMMARY | Train Det: 0.1369 | Val Det: 0.0799 | LR: 0.039798 <<
#
# --- Epoch 4/10 ---
# Step   12/480 | Batch Avg Det: 0.1235 | W-NPS: 0.9814 | W-TV: 2.8162 | YOLO force: 2.174816 | NPS & TV force: 1.160200
# Step   24/480 | Batch Avg Det: 0.1504 | W-NPS: 0.9821 | W-TV: 2.8087 | YOLO force: 2.107588 | NPS & TV force: 1.163111
# Step   36/480 | Batch Avg Det: 0.1601 | W-NPS: 0.9791 | W-TV: 2.8051 | YOLO force: 1.998384 | NPS & TV force: 1.162280
# Step   48/480 | Batch Avg Det: 0.1358 | W-NPS: 0.9730 | W-TV: 2.8021 | YOLO force: 1.678622 | NPS & TV force: 1.160067
# Step   60/480 | Batch Avg Det: 0.0803 | W-NPS: 0.9657 | W-TV: 2.7967 | YOLO force: 1.623731 | NPS & TV force: 1.164255
# Step   72/480 | Batch Avg Det: 0.0996 | W-NPS: 0.9521 | W-TV: 2.7865 | YOLO force: 1.449003 | NPS & TV force: 1.161037
# Step   84/480 | Batch Avg Det: 0.0816 | W-NPS: 0.9356 | W-TV: 2.7718 | YOLO force: 1.250500 | NPS & TV force: 1.147901
# Step   96/480 | Batch Avg Det: 0.0955 | W-NPS: 0.9179 | W-TV: 2.7564 | YOLO force: 2.716967 | NPS & TV force: 1.131436
# Step  108/480 | Batch Avg Det: 0.1237 | W-NPS: 0.8965 | W-TV: 2.7451 | YOLO force: 2.178895 | NPS & TV force: 1.125615
# Step  120/480 | Batch Avg Det: 0.1640 | W-NPS: 0.8800 | W-TV: 2.7446 | YOLO force: 1.306040 | NPS & TV force: 1.134716
# Step  132/480 | Batch Avg Det: 0.1276 | W-NPS: 0.8656 | W-TV: 2.7386 | YOLO force: 2.474974 | NPS & TV force: 1.142159
# Step  144/480 | Batch Avg Det: 0.0972 | W-NPS: 0.8474 | W-TV: 2.7339 | YOLO force: 0.854690 | NPS & TV force: 1.152295
# Step  156/480 | Batch Avg Det: 0.1296 | W-NPS: 0.8303 | W-TV: 2.7275 | YOLO force: 1.766419 | NPS & TV force: 1.146964
# Step  168/480 | Batch Avg Det: 0.1335 | W-NPS: 0.8065 | W-TV: 2.7224 | YOLO force: 2.689220 | NPS & TV force: 1.133325
# Step  180/480 | Batch Avg Det: 0.0786 | W-NPS: 0.7911 | W-TV: 2.7184 | YOLO force: 1.709782 | NPS & TV force: 1.138418
# Step  192/480 | Batch Avg Det: 0.2388 | W-NPS: 0.7828 | W-TV: 2.7235 | YOLO force: 2.191373 | NPS & TV force: 1.149991
# Step  204/480 | Batch Avg Det: 0.2193 | W-NPS: 0.7787 | W-TV: 2.7267 | YOLO force: 2.657452 | NPS & TV force: 1.145939
# Step  216/480 | Batch Avg Det: 0.1984 | W-NPS: 0.7736 | W-TV: 2.7504 | YOLO force: 2.486179 | NPS & TV force: 1.159053
# Step  228/480 | Batch Avg Det: 0.1544 | W-NPS: 0.7772 | W-TV: 2.7784 | YOLO force: 0.455048 | NPS & TV force: 1.197461
# Step  240/480 | Batch Avg Det: 0.1266 | W-NPS: 0.7832 | W-TV: 2.7943 | YOLO force: 2.214673 | NPS & TV force: 1.209747
# Step  252/480 | Batch Avg Det: 0.1396 | W-NPS: 0.7884 | W-TV: 2.7995 | YOLO force: 2.247613 | NPS & TV force: 1.207741
# Step  264/480 | Batch Avg Det: 0.1633 | W-NPS: 0.7949 | W-TV: 2.7982 | YOLO force: 1.543861 | NPS & TV force: 1.208061
# Step  276/480 | Batch Avg Det: 0.2684 | W-NPS: 0.7964 | W-TV: 2.7939 | YOLO force: 2.004940 | NPS & TV force: 1.214440
# Step  288/480 | Batch Avg Det: 0.1002 | W-NPS: 0.8000 | W-TV: 2.7950 | YOLO force: 1.996066 | NPS & TV force: 1.215693
# Step  300/480 | Batch Avg Det: 0.1006 | W-NPS: 0.7982 | W-TV: 2.7891 | YOLO force: 1.321244 | NPS & TV force: 1.217702
# Step  312/480 | Batch Avg Det: 0.1176 | W-NPS: 0.7951 | W-TV: 2.7802 | YOLO force: 3.039324 | NPS & TV force: 1.215341
# Step  324/480 | Batch Avg Det: 0.2389 | W-NPS: 0.7951 | W-TV: 2.7665 | YOLO force: 2.648640 | NPS & TV force: 1.195454
# Step  336/480 | Batch Avg Det: 0.1255 | W-NPS: 0.8032 | W-TV: 2.7619 | YOLO force: 2.859324 | NPS & TV force: 1.184796
# Step  348/480 | Batch Avg Det: 0.1204 | W-NPS: 0.8179 | W-TV: 2.7559 | YOLO force: 2.077840 | NPS & TV force: 1.181558
# Step  360/480 | Batch Avg Det: 0.1583 | W-NPS: 0.8398 | W-TV: 2.7584 | YOLO force: 2.007502 | NPS & TV force: 1.188920
# Step  372/480 | Batch Avg Det: 0.1637 | W-NPS: 0.8597 | W-TV: 2.7631 | YOLO force: 2.113296 | NPS & TV force: 1.194910
# Step  384/480 | Batch Avg Det: 0.1245 | W-NPS: 0.8709 | W-TV: 2.7663 | YOLO force: 2.619419 | NPS & TV force: 1.201710
# Step  396/480 | Batch Avg Det: 0.0841 | W-NPS: 0.8779 | W-TV: 2.7733 | YOLO force: 1.662580 | NPS & TV force: 1.204116
# Step  408/480 | Batch Avg Det: 0.1631 | W-NPS: 0.8800 | W-TV: 2.7712 | YOLO force: 1.565526 | NPS & TV force: 1.185122
# Step  420/480 | Batch Avg Det: 0.1283 | W-NPS: 0.8767 | W-TV: 2.7663 | YOLO force: 2.487872 | NPS & TV force: 1.182173
# Step  432/480 | Batch Avg Det: 0.2122 | W-NPS: 0.8705 | W-TV: 2.7602 | YOLO force: 1.890481 | NPS & TV force: 1.167166
# Step  444/480 | Batch Avg Det: 0.1218 | W-NPS: 0.8637 | W-TV: 2.7550 | YOLO force: 2.095414 | NPS & TV force: 1.171979
# Step  456/480 | Batch Avg Det: 0.2338 | W-NPS: 0.8580 | W-TV: 2.7532 | YOLO force: 1.643385 | NPS & TV force: 1.171782
# Step  468/480 | Batch Avg Det: 0.1168 | W-NPS: 0.8539 | W-TV: 2.7439 | YOLO force: 0.809307 | NPS & TV force: 1.173505
# Step  480/480 | Batch Avg Det: 0.1244 | W-NPS: 0.8475 | W-TV: 2.7276 | YOLO force: 1.898196 | NPS & TV force: 1.152300
# >> EPOCH 4 SUMMARY | Train Det: 0.1431 | Val Det: 0.0800 | LR: 0.032898 <<
#
# --- Epoch 5/10 ---
# Step   12/480 | Batch Avg Det: 0.2330 | W-NPS: 0.8387 | W-TV: 2.7034 | YOLO force: 2.388745 | NPS & TV force: 1.138433
# Step   24/480 | Batch Avg Det: 0.2314 | W-NPS: 0.8327 | W-TV: 2.6899 | YOLO force: 1.756969 | NPS & TV force: 1.129526
# Step   36/480 | Batch Avg Det: 0.1713 | W-NPS: 0.8259 | W-TV: 2.6768 | YOLO force: 1.233119 | NPS & TV force: 1.127902
# Step   48/480 | Batch Avg Det: 0.1553 | W-NPS: 0.8204 | W-TV: 2.6654 | YOLO force: 0.473010 | NPS & TV force: 1.118877
# Step   60/480 | Batch Avg Det: 0.1131 | W-NPS: 0.8111 | W-TV: 2.6453 | YOLO force: 0.784602 | NPS & TV force: 1.115019
# Step   72/480 | Batch Avg Det: 0.1530 | W-NPS: 0.7967 | W-TV: 2.6204 | YOLO force: 2.755972 | NPS & TV force: 1.093308
# Step   84/480 | Batch Avg Det: 0.3282 | W-NPS: 0.7880 | W-TV: 2.6013 | YOLO force: 2.511387 | NPS & TV force: 1.076787
# Step   96/480 | Batch Avg Det: 0.1745 | W-NPS: 0.7909 | W-TV: 2.5905 | YOLO force: 0.855345 | NPS & TV force: 1.083401
# Step  108/480 | Batch Avg Det: 0.0972 | W-NPS: 0.7916 | W-TV: 2.5809 | YOLO force: 1.428819 | NPS & TV force: 1.085958
# Step  120/480 | Batch Avg Det: 0.1665 | W-NPS: 0.7896 | W-TV: 2.5711 | YOLO force: 1.391398 | NPS & TV force: 1.084315
# Step  132/480 | Batch Avg Det: 0.1678 | W-NPS: 0.7827 | W-TV: 2.5599 | YOLO force: 2.724323 | NPS & TV force: 1.091232
# Step  144/480 | Batch Avg Det: 0.1155 | W-NPS: 0.7761 | W-TV: 2.5571 | YOLO force: 3.096046 | NPS & TV force: 1.089506
# Step  156/480 | Batch Avg Det: 0.1105 | W-NPS: 0.7776 | W-TV: 2.5627 | YOLO force: 2.127366 | NPS & TV force: 1.094878
# Step  168/480 | Batch Avg Det: 0.1045 | W-NPS: 0.7938 | W-TV: 2.5798 | YOLO force: 2.599078 | NPS & TV force: 1.113782
# Step  180/480 | Batch Avg Det: 0.1925 | W-NPS: 0.8141 | W-TV: 2.6051 | YOLO force: 1.465617 | NPS & TV force: 1.142283
# Step  192/480 | Batch Avg Det: 0.0758 | W-NPS: 0.8316 | W-TV: 2.6193 | YOLO force: 1.460305 | NPS & TV force: 1.143684
# Step  204/480 | Batch Avg Det: 0.0580 | W-NPS: 0.8421 | W-TV: 2.6254 | YOLO force: 0.894630 | NPS & TV force: 1.143738
# Step  216/480 | Batch Avg Det: 0.1480 | W-NPS: 0.8431 | W-TV: 2.6238 | YOLO force: 2.002082 | NPS & TV force: 1.134747
# Step  228/480 | Batch Avg Det: 0.0953 | W-NPS: 0.8400 | W-TV: 2.6204 | YOLO force: 1.851216 | NPS & TV force: 1.111201
# Step  240/480 | Batch Avg Det: 0.0976 | W-NPS: 0.8338 | W-TV: 2.6143 | YOLO force: 1.574159 | NPS & TV force: 1.107797
# Step  252/480 | Batch Avg Det: 0.1613 | W-NPS: 0.8235 | W-TV: 2.6029 | YOLO force: 1.719393 | NPS & TV force: 1.111244
# Step  264/480 | Batch Avg Det: 0.0921 | W-NPS: 0.8122 | W-TV: 2.5903 | YOLO force: 2.262923 | NPS & TV force: 1.107989
# Step  276/480 | Batch Avg Det: 0.1455 | W-NPS: 0.8028 | W-TV: 2.5864 | YOLO force: 0.938370 | NPS & TV force: 1.123636
# Step  288/480 | Batch Avg Det: 0.1261 | W-NPS: 0.7902 | W-TV: 2.5786 | YOLO force: 2.060656 | NPS & TV force: 1.120861
# Step  300/480 | Batch Avg Det: 0.2984 | W-NPS: 0.7735 | W-TV: 2.5681 | YOLO force: 3.470174 | NPS & TV force: 1.108437
# Step  312/480 | Batch Avg Det: 0.0744 | W-NPS: 0.7632 | W-TV: 2.5774 | YOLO force: 0.766472 | NPS & TV force: 1.121889
# Step  324/480 | Batch Avg Det: 0.1259 | W-NPS: 0.7536 | W-TV: 2.5846 | YOLO force: 2.246067 | NPS & TV force: 1.134118
# Step  336/480 | Batch Avg Det: 0.1415 | W-NPS: 0.7438 | W-TV: 2.5937 | YOLO force: 2.453383 | NPS & TV force: 1.154443
# Step  348/480 | Batch Avg Det: 0.1872 | W-NPS: 0.7292 | W-TV: 2.5997 | YOLO force: 3.221325 | NPS & TV force: 1.150651
# Step  360/480 | Batch Avg Det: 0.2682 | W-NPS: 0.7255 | W-TV: 2.6096 | YOLO force: 2.473101 | NPS & TV force: 1.146023
# Step  372/480 | Batch Avg Det: 0.1342 | W-NPS: 0.7330 | W-TV: 2.6273 | YOLO force: 2.550950 | NPS & TV force: 1.155918
# Step  384/480 | Batch Avg Det: 0.1214 | W-NPS: 0.7523 | W-TV: 2.6530 | YOLO force: 2.315115 | NPS & TV force: 1.171021
# Step  396/480 | Batch Avg Det: 0.1062 | W-NPS: 0.7750 | W-TV: 2.6783 | YOLO force: 2.729197 | NPS & TV force: 1.190917
# Step  408/480 | Batch Avg Det: 0.1163 | W-NPS: 0.7958 | W-TV: 2.6957 | YOLO force: 2.700026 | NPS & TV force: 1.195313
# Step  420/480 | Batch Avg Det: 0.0993 | W-NPS: 0.8169 | W-TV: 2.7119 | YOLO force: 1.357629 | NPS & TV force: 1.198560
# Step  432/480 | Batch Avg Det: 0.0919 | W-NPS: 0.8321 | W-TV: 2.7213 | YOLO force: 2.561609 | NPS & TV force: 1.197620
# Step  444/480 | Batch Avg Det: 0.1146 | W-NPS: 0.8449 | W-TV: 2.7312 | YOLO force: 1.009913 | NPS & TV force: 1.186476
# Step  456/480 | Batch Avg Det: 0.0831 | W-NPS: 0.8520 | W-TV: 2.7342 | YOLO force: 1.422927 | NPS & TV force: 1.182333
# Step  468/480 | Batch Avg Det: 0.2048 | W-NPS: 0.8528 | W-TV: 2.7324 | YOLO force: 2.569450 | NPS & TV force: 1.165999
# Step  480/480 | Batch Avg Det: 0.0816 | W-NPS: 0.8517 | W-TV: 2.7291 | YOLO force: 1.081663 | NPS & TV force: 1.157948
# >> EPOCH 5 SUMMARY | Train Det: 0.1441 | Val Det: 0.0764 | LR: 0.025250 <<
#
# --- Epoch 6/10 ---
# Step   12/480 | Batch Avg Det: 0.1496 | W-NPS: 0.8447 | W-TV: 2.7189 | YOLO force: 2.402144 | NPS & TV force: 1.146861
# Step   24/480 | Batch Avg Det: 0.1416 | W-NPS: 0.8395 | W-TV: 2.7094 | YOLO force: 2.472206 | NPS & TV force: 1.143172
# Step   36/480 | Batch Avg Det: 0.1330 | W-NPS: 0.8354 | W-TV: 2.7021 | YOLO force: 1.955451 | NPS & TV force: 1.135810
# Step   48/480 | Batch Avg Det: 0.1421 | W-NPS: 0.8349 | W-TV: 2.6929 | YOLO force: 1.715614 | NPS & TV force: 1.135111
# Step   60/480 | Batch Avg Det: 0.1689 | W-NPS: 0.8314 | W-TV: 2.6832 | YOLO force: 1.715551 | NPS & TV force: 1.148205
# Step   72/480 | Batch Avg Det: 0.2133 | W-NPS: 0.8228 | W-TV: 2.6710 | YOLO force: 1.780181 | NPS & TV force: 1.136484
# Step   84/480 | Batch Avg Det: 0.2185 | W-NPS: 0.8092 | W-TV: 2.6567 | YOLO force: 1.188566 | NPS & TV force: 1.117964
# Step   96/480 | Batch Avg Det: 0.0529 | W-NPS: 0.7933 | W-TV: 2.6421 | YOLO force: 1.947456 | NPS & TV force: 1.108419
# Step  108/480 | Batch Avg Det: 0.0892 | W-NPS: 0.7750 | W-TV: 2.6269 | YOLO force: 2.477457 | NPS & TV force: 1.100469
# Step  120/480 | Batch Avg Det: 0.1330 | W-NPS: 0.7621 | W-TV: 2.6163 | YOLO force: 1.302492 | NPS & TV force: 1.101994
# Step  132/480 | Batch Avg Det: 0.1152 | W-NPS: 0.7478 | W-TV: 2.6081 | YOLO force: 1.572083 | NPS & TV force: 1.101758
# Step  144/480 | Batch Avg Det: 0.0775 | W-NPS: 0.7317 | W-TV: 2.5990 | YOLO force: 1.389526 | NPS & TV force: 1.104495
# Step  156/480 | Batch Avg Det: 0.0832 | W-NPS: 0.7144 | W-TV: 2.5870 | YOLO force: 2.000591 | NPS & TV force: 1.099561
# Step  168/480 | Batch Avg Det: 0.0673 | W-NPS: 0.6991 | W-TV: 2.5734 | YOLO force: 1.433141 | NPS & TV force: 1.083934
# Step  180/480 | Batch Avg Det: 0.1051 | W-NPS: 0.6863 | W-TV: 2.5610 | YOLO force: 1.603591 | NPS & TV force: 1.078185
# Step  192/480 | Batch Avg Det: 0.1158 | W-NPS: 0.6764 | W-TV: 2.5505 | YOLO force: 1.703317 | NPS & TV force: 1.074899
# Step  204/480 | Batch Avg Det: 0.1369 | W-NPS: 0.6661 | W-TV: 2.5434 | YOLO force: 1.554705 | NPS & TV force: 1.066065
# Step  216/480 | Batch Avg Det: 0.0865 | W-NPS: 0.6581 | W-TV: 2.5373 | YOLO force: 1.520233 | NPS & TV force: 1.062271
# Step  228/480 | Batch Avg Det: 0.1875 | W-NPS: 0.6480 | W-TV: 2.5302 | YOLO force: 2.484452 | NPS & TV force: 1.052493
# Step  240/480 | Batch Avg Det: 0.2196 | W-NPS: 0.6382 | W-TV: 2.5287 | YOLO force: 3.129875 | NPS & TV force: 1.053765
# Step  252/480 | Batch Avg Det: 0.0826 | W-NPS: 0.6333 | W-TV: 2.5373 | YOLO force: 2.262563 | NPS & TV force: 1.066502
# Step  264/480 | Batch Avg Det: 0.1083 | W-NPS: 0.6300 | W-TV: 2.5493 | YOLO force: 0.971512 | NPS & TV force: 1.098034
# Step  276/480 | Batch Avg Det: 0.1347 | W-NPS: 0.6276 | W-TV: 2.5593 | YOLO force: 2.095198 | NPS & TV force: 1.106696
# Step  288/480 | Batch Avg Det: 0.1369 | W-NPS: 0.6207 | W-TV: 2.5651 | YOLO force: 1.291695 | NPS & TV force: 1.103024
# Step  300/480 | Batch Avg Det: 0.0749 | W-NPS: 0.6136 | W-TV: 2.5681 | YOLO force: 1.692911 | NPS & TV force: 1.105505
# Step  312/480 | Batch Avg Det: 0.1493 | W-NPS: 0.6038 | W-TV: 2.5680 | YOLO force: 2.898336 | NPS & TV force: 1.101772
# Step  324/480 | Batch Avg Det: 0.1504 | W-NPS: 0.5928 | W-TV: 2.5704 | YOLO force: 3.245087 | NPS & TV force: 1.104036
# Step  336/480 | Batch Avg Det: 0.2727 | W-NPS: 0.5860 | W-TV: 2.5784 | YOLO force: 1.328753 | NPS & TV force: 1.113792
# Step  348/480 | Batch Avg Det: 0.1750 | W-NPS: 0.5810 | W-TV: 2.5855 | YOLO force: 2.001033 | NPS & TV force: 1.127082
# Step  360/480 | Batch Avg Det: 0.1115 | W-NPS: 0.5785 | W-TV: 2.5956 | YOLO force: 2.112278 | NPS & TV force: 1.139012
# Step  372/480 | Batch Avg Det: 0.1583 | W-NPS: 0.5777 | W-TV: 2.6050 | YOLO force: 1.779533 | NPS & TV force: 1.145452
# Step  384/480 | Batch Avg Det: 0.1529 | W-NPS: 0.5766 | W-TV: 2.6136 | YOLO force: 1.912732 | NPS & TV force: 1.156163
# Step  396/480 | Batch Avg Det: 0.1956 | W-NPS: 0.5761 | W-TV: 2.6201 | YOLO force: 1.717503 | NPS & TV force: 1.148924
# Step  408/480 | Batch Avg Det: 0.0614 | W-NPS: 0.5737 | W-TV: 2.6229 | YOLO force: 1.892601 | NPS & TV force: 1.163876
# Step  420/480 | Batch Avg Det: 0.1008 | W-NPS: 0.5713 | W-TV: 2.6203 | YOLO force: 1.810815 | NPS & TV force: 1.154345
# Step  432/480 | Batch Avg Det: 0.1399 | W-NPS: 0.5690 | W-TV: 2.6161 | YOLO force: 1.757508 | NPS & TV force: 1.135164
# Step  444/480 | Batch Avg Det: 0.1620 | W-NPS: 0.5677 | W-TV: 2.6087 | YOLO force: 2.410150 | NPS & TV force: 1.131346
# Step  456/480 | Batch Avg Det: 0.0365 | W-NPS: 0.5618 | W-TV: 2.6007 | YOLO force: 0.589882 | NPS & TV force: 1.115291
# Step  468/480 | Batch Avg Det: 0.2059 | W-NPS: 0.5551 | W-TV: 2.5899 | YOLO force: 2.392908 | NPS & TV force: 1.103258
# Step  480/480 | Batch Avg Det: 0.1430 | W-NPS: 0.5501 | W-TV: 2.5830 | YOLO force: 0.818106 | NPS & TV force: 1.086362
# >> EPOCH 6 SUMMARY | Train Det: 0.1347 | Val Det: 0.0808 | LR: 0.017602 <<
#
# --- Epoch 7/10 ---
# Step   12/480 | Batch Avg Det: 0.1303 | W-NPS: 0.5451 | W-TV: 2.5778 | YOLO force: 0.522604 | NPS & TV force: 1.083320
# Step   24/480 | Batch Avg Det: 0.1242 | W-NPS: 0.5387 | W-TV: 2.5706 | YOLO force: 1.774720 | NPS & TV force: 1.080035
# Step   36/480 | Batch Avg Det: 0.1628 | W-NPS: 0.5296 | W-TV: 2.5641 | YOLO force: 2.121352 | NPS & TV force: 1.065541
# Step   48/480 | Batch Avg Det: 0.1972 | W-NPS: 0.5237 | W-TV: 2.5599 | YOLO force: 3.351380 | NPS & TV force: 1.067775
# Step   60/480 | Batch Avg Det: 0.1539 | W-NPS: 0.5196 | W-TV: 2.5615 | YOLO force: 2.150571 | NPS & TV force: 1.073796
# Step   72/480 | Batch Avg Det: 0.1951 | W-NPS: 0.5216 | W-TV: 2.5670 | YOLO force: 2.913132 | NPS & TV force: 1.083175
# Step   84/480 | Batch Avg Det: 0.1288 | W-NPS: 0.5293 | W-TV: 2.5753 | YOLO force: 2.617237 | NPS & TV force: 1.095506
# Step   96/480 | Batch Avg Det: 0.1910 | W-NPS: 0.5415 | W-TV: 2.5851 | YOLO force: 1.747051 | NPS & TV force: 1.107949
# Step  108/480 | Batch Avg Det: 0.1382 | W-NPS: 0.5519 | W-TV: 2.5918 | YOLO force: 1.554905 | NPS & TV force: 1.123680
# Step  120/480 | Batch Avg Det: 0.1135 | W-NPS: 0.5593 | W-TV: 2.5958 | YOLO force: 0.959454 | NPS & TV force: 1.121315
# Step  132/480 | Batch Avg Det: 0.1703 | W-NPS: 0.5625 | W-TV: 2.5951 | YOLO force: 2.592887 | NPS & TV force: 1.111235
# Step  144/480 | Batch Avg Det: 0.1074 | W-NPS: 0.5672 | W-TV: 2.5935 | YOLO force: 1.863220 | NPS & TV force: 1.120553
# Step  156/480 | Batch Avg Det: 0.0844 | W-NPS: 0.5714 | W-TV: 2.5905 | YOLO force: 1.673378 | NPS & TV force: 1.119579
# Step  168/480 | Batch Avg Det: 0.1569 | W-NPS: 0.5748 | W-TV: 2.5861 | YOLO force: 2.362797 | NPS & TV force: 1.116837
# Step  180/480 | Batch Avg Det: 0.1156 | W-NPS: 0.5765 | W-TV: 2.5805 | YOLO force: 1.338520 | NPS & TV force: 1.116537
# Step  192/480 | Batch Avg Det: 0.1739 | W-NPS: 0.5740 | W-TV: 2.5723 | YOLO force: 1.849257 | NPS & TV force: 1.093840
# Step  204/480 | Batch Avg Det: 0.1665 | W-NPS: 0.5701 | W-TV: 2.5665 | YOLO force: 2.261364 | NPS & TV force: 1.092222
# Step  216/480 | Batch Avg Det: 0.0581 | W-NPS: 0.5644 | W-TV: 2.5614 | YOLO force: 1.168885 | NPS & TV force: 1.067575
# Step  228/480 | Batch Avg Det: 0.1151 | W-NPS: 0.5590 | W-TV: 2.5565 | YOLO force: 2.029763 | NPS & TV force: 1.062097
# Step  240/480 | Batch Avg Det: 0.1064 | W-NPS: 0.5537 | W-TV: 2.5530 | YOLO force: 2.220061 | NPS & TV force: 1.065251
# Step  252/480 | Batch Avg Det: 0.1425 | W-NPS: 0.5494 | W-TV: 2.5507 | YOLO force: 3.519735 | NPS & TV force: 1.066766
# Step  264/480 | Batch Avg Det: 0.1797 | W-NPS: 0.5505 | W-TV: 2.5538 | YOLO force: 2.064301 | NPS & TV force: 1.066443
# Step  276/480 | Batch Avg Det: 0.0639 | W-NPS: 0.5541 | W-TV: 2.5587 | YOLO force: 1.060678 | NPS & TV force: 1.062943
# Step  288/480 | Batch Avg Det: 0.1332 | W-NPS: 0.5559 | W-TV: 2.5620 | YOLO force: 1.765791 | NPS & TV force: 1.073014
# Step  300/480 | Batch Avg Det: 0.1634 | W-NPS: 0.5574 | W-TV: 2.5657 | YOLO force: 1.753233 | NPS & TV force: 1.083408
# Step  312/480 | Batch Avg Det: 0.2002 | W-NPS: 0.5557 | W-TV: 2.5682 | YOLO force: 2.747305 | NPS & TV force: 1.087032
# Step  324/480 | Batch Avg Det: 0.2162 | W-NPS: 0.5530 | W-TV: 2.5721 | YOLO force: 2.049072 | NPS & TV force: 1.088585
# Step  336/480 | Batch Avg Det: 0.0982 | W-NPS: 0.5522 | W-TV: 2.5762 | YOLO force: 1.248766 | NPS & TV force: 1.092417
# Step  348/480 | Batch Avg Det: 0.1200 | W-NPS: 0.5489 | W-TV: 2.5776 | YOLO force: 1.106100 | NPS & TV force: 1.093328
# Step  360/480 | Batch Avg Det: 0.0624 | W-NPS: 0.5444 | W-TV: 2.5765 | YOLO force: 1.710853 | NPS & TV force: 1.090400
# Step  372/480 | Batch Avg Det: 0.1086 | W-NPS: 0.5390 | W-TV: 2.5747 | YOLO force: 0.884431 | NPS & TV force: 1.078609
# Step  384/480 | Batch Avg Det: 0.1227 | W-NPS: 0.5328 | W-TV: 2.5715 | YOLO force: 1.424014 | NPS & TV force: 1.076331
# Step  396/480 | Batch Avg Det: 0.1662 | W-NPS: 0.5251 | W-TV: 2.5670 | YOLO force: 3.002693 | NPS & TV force: 1.067443
# Step  408/480 | Batch Avg Det: 0.1748 | W-NPS: 0.5191 | W-TV: 2.5650 | YOLO force: 1.968507 | NPS & TV force: 1.065766
# Step  420/480 | Batch Avg Det: 0.1048 | W-NPS: 0.5126 | W-TV: 2.5625 | YOLO force: 1.159840 | NPS & TV force: 1.066532
# Step  432/480 | Batch Avg Det: 0.2010 | W-NPS: 0.5045 | W-TV: 2.5594 | YOLO force: 1.788368 | NPS & TV force: 1.073931
# Step  444/480 | Batch Avg Det: 0.0741 | W-NPS: 0.4964 | W-TV: 2.5548 | YOLO force: 2.433183 | NPS & TV force: 1.060631
# Step  456/480 | Batch Avg Det: 0.1429 | W-NPS: 0.4891 | W-TV: 2.5522 | YOLO force: 2.400342 | NPS & TV force: 1.067693
# Step  468/480 | Batch Avg Det: 0.1588 | W-NPS: 0.4826 | W-TV: 2.5478 | YOLO force: 3.390098 | NPS & TV force: 1.059644
# Step  480/480 | Batch Avg Det: 0.1210 | W-NPS: 0.4762 | W-TV: 2.5451 | YOLO force: 1.326212 | NPS & TV force: 1.049531
# >> EPOCH 7 SUMMARY | Train Det: 0.1386 | Val Det: 0.0830 | LR: 0.010702 <<
#
# --- Epoch 8/10 ---
# Step   12/480 | Batch Avg Det: 0.1913 | W-NPS: 0.4720 | W-TV: 2.5444 | YOLO force: 2.916291 | NPS & TV force: 1.047017
# Step   24/480 | Batch Avg Det: 0.1966 | W-NPS: 0.4721 | W-TV: 2.5456 | YOLO force: 2.209007 | NPS & TV force: 1.046013
# Step   36/480 | Batch Avg Det: 0.2101 | W-NPS: 0.4721 | W-TV: 2.5478 | YOLO force: 0.520020 | NPS & TV force: 1.054414
# Step   48/480 | Batch Avg Det: 0.1810 | W-NPS: 0.4710 | W-TV: 2.5476 | YOLO force: 0.732183 | NPS & TV force: 1.049996
# Step   60/480 | Batch Avg Det: 0.1206 | W-NPS: 0.4680 | W-TV: 2.5448 | YOLO force: 2.737033 | NPS & TV force: 1.043931
# Step   72/480 | Batch Avg Det: 0.0635 | W-NPS: 0.4626 | W-TV: 2.5433 | YOLO force: 0.921529 | NPS & TV force: 1.054885
# Step   84/480 | Batch Avg Det: 0.1132 | W-NPS: 0.4560 | W-TV: 2.5388 | YOLO force: 1.641319 | NPS & TV force: 1.045655
# Step   96/480 | Batch Avg Det: 0.0983 | W-NPS: 0.4493 | W-TV: 2.5335 | YOLO force: 1.827858 | NPS & TV force: 1.037289
# Step  108/480 | Batch Avg Det: 0.0952 | W-NPS: 0.4426 | W-TV: 2.5289 | YOLO force: 0.884702 | NPS & TV force: 1.024614
# Step  120/480 | Batch Avg Det: 0.1612 | W-NPS: 0.4364 | W-TV: 2.5254 | YOLO force: 2.938435 | NPS & TV force: 1.024368
# Step  132/480 | Batch Avg Det: 0.1598 | W-NPS: 0.4312 | W-TV: 2.5228 | YOLO force: 2.759186 | NPS & TV force: 1.034244
# Step  144/480 | Batch Avg Det: 0.0901 | W-NPS: 0.4280 | W-TV: 2.5215 | YOLO force: 1.248012 | NPS & TV force: 1.044976
# Step  156/480 | Batch Avg Det: 0.1757 | W-NPS: 0.4262 | W-TV: 2.5206 | YOLO force: 2.040938 | NPS & TV force: 1.047915
# Step  168/480 | Batch Avg Det: 0.1078 | W-NPS: 0.4263 | W-TV: 2.5209 | YOLO force: 2.387381 | NPS & TV force: 1.053961
# Step  180/480 | Batch Avg Det: 0.1844 | W-NPS: 0.4265 | W-TV: 2.5210 | YOLO force: 0.827038 | NPS & TV force: 1.051814
# Step  192/480 | Batch Avg Det: 0.3208 | W-NPS: 0.4259 | W-TV: 2.5204 | YOLO force: 2.329461 | NPS & TV force: 1.037443
# Step  204/480 | Batch Avg Det: 0.0752 | W-NPS: 0.4236 | W-TV: 2.5206 | YOLO force: 1.546194 | NPS & TV force: 1.029900
# Step  216/480 | Batch Avg Det: 0.1226 | W-NPS: 0.4199 | W-TV: 2.5215 | YOLO force: 1.571666 | NPS & TV force: 1.033909
# Step  228/480 | Batch Avg Det: 0.1386 | W-NPS: 0.4158 | W-TV: 2.5210 | YOLO force: 1.724861 | NPS & TV force: 1.028079
# Step  240/480 | Batch Avg Det: 0.1904 | W-NPS: 0.4115 | W-TV: 2.5194 | YOLO force: 2.109153 | NPS & TV force: 1.020276
# Step  252/480 | Batch Avg Det: 0.1426 | W-NPS: 0.4076 | W-TV: 2.5181 | YOLO force: 1.915899 | NPS & TV force: 1.019538
# Step  264/480 | Batch Avg Det: 0.1419 | W-NPS: 0.4041 | W-TV: 2.5166 | YOLO force: 1.358960 | NPS & TV force: 1.020256
# Step  276/480 | Batch Avg Det: 0.1544 | W-NPS: 0.3996 | W-TV: 2.5155 | YOLO force: 3.729497 | NPS & TV force: 1.017951
# Step  288/480 | Batch Avg Det: 0.2066 | W-NPS: 0.3953 | W-TV: 2.5154 | YOLO force: 3.000737 | NPS & TV force: 1.017314
# Step  300/480 | Batch Avg Det: 0.1285 | W-NPS: 0.3935 | W-TV: 2.5173 | YOLO force: 1.899633 | NPS & TV force: 1.018176
# Step  312/480 | Batch Avg Det: 0.1046 | W-NPS: 0.3917 | W-TV: 2.5195 | YOLO force: 1.815144 | NPS & TV force: 1.015408
# Step  324/480 | Batch Avg Det: 0.2081 | W-NPS: 0.3902 | W-TV: 2.5219 | YOLO force: 2.002308 | NPS & TV force: 1.018606
# Step  336/480 | Batch Avg Det: 0.1565 | W-NPS: 0.3891 | W-TV: 2.5243 | YOLO force: 0.818107 | NPS & TV force: 1.021773
# Step  348/480 | Batch Avg Det: 0.1290 | W-NPS: 0.3872 | W-TV: 2.5250 | YOLO force: 4.680604 | NPS & TV force: 1.012863
# Step  360/480 | Batch Avg Det: 0.1793 | W-NPS: 0.3853 | W-TV: 2.5224 | YOLO force: 4.223980 | NPS & TV force: 1.011642
# Step  372/480 | Batch Avg Det: 0.1449 | W-NPS: 0.3852 | W-TV: 2.5243 | YOLO force: 1.068021 | NPS & TV force: 1.016879
# Step  384/480 | Batch Avg Det: 0.0768 | W-NPS: 0.3861 | W-TV: 2.5273 | YOLO force: 3.544063 | NPS & TV force: 1.047730
# Step  396/480 | Batch Avg Det: 0.1150 | W-NPS: 0.3870 | W-TV: 2.5298 | YOLO force: 1.855224 | NPS & TV force: 1.051647
# Step  408/480 | Batch Avg Det: 0.1206 | W-NPS: 0.3879 | W-TV: 2.5322 | YOLO force: 2.121625 | NPS & TV force: 1.050325
# Step  420/480 | Batch Avg Det: 0.1165 | W-NPS: 0.3880 | W-TV: 2.5343 | YOLO force: 1.966334 | NPS & TV force: 1.059688
# Step  432/480 | Batch Avg Det: 0.0404 | W-NPS: 0.3875 | W-TV: 2.5364 | YOLO force: 0.762819 | NPS & TV force: 1.064174
# Step  444/480 | Batch Avg Det: 0.2405 | W-NPS: 0.3861 | W-TV: 2.5373 | YOLO force: 2.362526 | NPS & TV force: 1.057730
# Step  456/480 | Batch Avg Det: 0.0993 | W-NPS: 0.3837 | W-TV: 2.5373 | YOLO force: 1.943145 | NPS & TV force: 1.058266
# Step  468/480 | Batch Avg Det: 0.1328 | W-NPS: 0.3805 | W-TV: 2.5366 | YOLO force: 2.169452 | NPS & TV force: 1.060629
# Step  480/480 | Batch Avg Det: 0.1041 | W-NPS: 0.3781 | W-TV: 2.5352 | YOLO force: 2.559606 | NPS & TV force: 1.047632
# >> EPOCH 8 SUMMARY | Train Det: 0.1435 | Val Det: 0.0848 | LR: 0.005227 <<
#
# --- Epoch 9/10 ---
# Step   12/480 | Batch Avg Det: 0.1256 | W-NPS: 0.3770 | W-TV: 2.5348 | YOLO force: 1.797346 | NPS & TV force: 1.044429
# Step   24/480 | Batch Avg Det: 0.0631 | W-NPS: 0.3763 | W-TV: 2.5343 | YOLO force: 1.069506 | NPS & TV force: 1.042666
# Step   36/480 | Batch Avg Det: 0.1971 | W-NPS: 0.3750 | W-TV: 2.5331 | YOLO force: 2.083165 | NPS & TV force: 1.049266
# Step   48/480 | Batch Avg Det: 0.1429 | W-NPS: 0.3732 | W-TV: 2.5318 | YOLO force: 2.280778 | NPS & TV force: 1.049394
# Step   60/480 | Batch Avg Det: 0.0281 | W-NPS: 0.3709 | W-TV: 2.5311 | YOLO force: 0.855265 | NPS & TV force: 1.045705
# Step   72/480 | Batch Avg Det: 0.1401 | W-NPS: 0.3682 | W-TV: 2.5296 | YOLO force: 2.676837 | NPS & TV force: 1.044870
# Step   84/480 | Batch Avg Det: 0.1771 | W-NPS: 0.3664 | W-TV: 2.5283 | YOLO force: 2.510657 | NPS & TV force: 1.039433
# Step   96/480 | Batch Avg Det: 0.0990 | W-NPS: 0.3647 | W-TV: 2.5275 | YOLO force: 1.737136 | NPS & TV force: 1.035273
# Step  108/480 | Batch Avg Det: 0.1030 | W-NPS: 0.3634 | W-TV: 2.5268 | YOLO force: 1.310650 | NPS & TV force: 1.030659
# Step  120/480 | Batch Avg Det: 0.2354 | W-NPS: 0.3619 | W-TV: 2.5262 | YOLO force: 1.503562 | NPS & TV force: 1.028330
# Step  132/480 | Batch Avg Det: 0.0848 | W-NPS: 0.3603 | W-TV: 2.5248 | YOLO force: 1.564669 | NPS & TV force: 1.017578
# Step  144/480 | Batch Avg Det: 0.1169 | W-NPS: 0.3583 | W-TV: 2.5233 | YOLO force: 1.524468 | NPS & TV force: 1.024965
# Step  156/480 | Batch Avg Det: 0.2108 | W-NPS: 0.3562 | W-TV: 2.5216 | YOLO force: 3.386452 | NPS & TV force: 1.007624
# Step  168/480 | Batch Avg Det: 0.1603 | W-NPS: 0.3551 | W-TV: 2.5216 | YOLO force: 1.449696 | NPS & TV force: 1.005567
# Step  180/480 | Batch Avg Det: 0.1140 | W-NPS: 0.3535 | W-TV: 2.5220 | YOLO force: 1.423328 | NPS & TV force: 1.012994
# Step  192/480 | Batch Avg Det: 0.1435 | W-NPS: 0.3518 | W-TV: 2.5222 | YOLO force: 1.377741 | NPS & TV force: 1.016990
# Step  204/480 | Batch Avg Det: 0.1151 | W-NPS: 0.3499 | W-TV: 2.5219 | YOLO force: 1.906826 | NPS & TV force: 1.025259
# Step  216/480 | Batch Avg Det: 0.1562 | W-NPS: 0.3465 | W-TV: 2.5209 | YOLO force: 2.688050 | NPS & TV force: 1.020743
# Step  228/480 | Batch Avg Det: 0.1733 | W-NPS: 0.3426 | W-TV: 2.5201 | YOLO force: 2.640988 | NPS & TV force: 1.020969
# Step  240/480 | Batch Avg Det: 0.1008 | W-NPS: 0.3388 | W-TV: 2.5199 | YOLO force: 2.067430 | NPS & TV force: 1.021675
# Step  252/480 | Batch Avg Det: 0.1424 | W-NPS: 0.3352 | W-TV: 2.5206 | YOLO force: 1.329750 | NPS & TV force: 1.023729
# Step  264/480 | Batch Avg Det: 0.1284 | W-NPS: 0.3317 | W-TV: 2.5207 | YOLO force: 3.474574 | NPS & TV force: 1.017792
# Step  276/480 | Batch Avg Det: 0.1866 | W-NPS: 0.3293 | W-TV: 2.5220 | YOLO force: 1.146445 | NPS & TV force: 1.008925
# Step  288/480 | Batch Avg Det: 0.1123 | W-NPS: 0.3273 | W-TV: 2.5230 | YOLO force: 2.607051 | NPS & TV force: 1.010091
# Step  300/480 | Batch Avg Det: 0.1307 | W-NPS: 0.3257 | W-TV: 2.5240 | YOLO force: 2.251229 | NPS & TV force: 1.007183
# Step  312/480 | Batch Avg Det: 0.0940 | W-NPS: 0.3238 | W-TV: 2.5253 | YOLO force: 2.238197 | NPS & TV force: 1.015318
# Step  324/480 | Batch Avg Det: 0.1958 | W-NPS: 0.3223 | W-TV: 2.5263 | YOLO force: 2.604538 | NPS & TV force: 1.009982
# Step  336/480 | Batch Avg Det: 0.2684 | W-NPS: 0.3215 | W-TV: 2.5275 | YOLO force: 1.911446 | NPS & TV force: 0.996024
# Step  348/480 | Batch Avg Det: 0.1710 | W-NPS: 0.3201 | W-TV: 2.5285 | YOLO force: 1.834130 | NPS & TV force: 0.998140
# Step  360/480 | Batch Avg Det: 0.1067 | W-NPS: 0.3185 | W-TV: 2.5290 | YOLO force: 0.948606 | NPS & TV force: 0.990937
# Step  372/480 | Batch Avg Det: 0.1470 | W-NPS: 0.3168 | W-TV: 2.5291 | YOLO force: 0.910313 | NPS & TV force: 0.994965
# Step  384/480 | Batch Avg Det: 0.1035 | W-NPS: 0.3145 | W-TV: 2.5287 | YOLO force: 0.797009 | NPS & TV force: 0.999605
# Step  396/480 | Batch Avg Det: 0.0936 | W-NPS: 0.3118 | W-TV: 2.5278 | YOLO force: 2.116701 | NPS & TV force: 0.998829
# Step  408/480 | Batch Avg Det: 0.2176 | W-NPS: 0.3089 | W-TV: 2.5266 | YOLO force: 1.273594 | NPS & TV force: 0.995020
# Step  420/480 | Batch Avg Det: 0.2052 | W-NPS: 0.3060 | W-TV: 2.5249 | YOLO force: 2.205754 | NPS & TV force: 0.984328
# Step  432/480 | Batch Avg Det: 0.1216 | W-NPS: 0.3029 | W-TV: 2.5230 | YOLO force: 3.724313 | NPS & TV force: 0.972327
# Step  444/480 | Batch Avg Det: 0.0927 | W-NPS: 0.2999 | W-TV: 2.5217 | YOLO force: 1.631300 | NPS & TV force: 0.961117
# Step  456/480 | Batch Avg Det: 0.1885 | W-NPS: 0.2975 | W-TV: 2.5209 | YOLO force: 2.654770 | NPS & TV force: 0.970161
# Step  468/480 | Batch Avg Det: 0.1951 | W-NPS: 0.2956 | W-TV: 2.5204 | YOLO force: 6.701230 | NPS & TV force: 0.987916
# Step  480/480 | Batch Avg Det: 0.1255 | W-NPS: 0.2952 | W-TV: 2.5215 | YOLO force: 2.410631 | NPS & TV force: 0.999478
# >> EPOCH 9 SUMMARY | Train Det: 0.1428 | Val Det: 0.0853 | LR: 0.001711 <<
#
# --- Epoch 10/10 ---
# Step   12/480 | Batch Avg Det: 0.0827 | W-NPS: 0.2957 | W-TV: 2.5232 | YOLO force: 1.219752 | NPS & TV force: 1.009285
# Step   24/480 | Batch Avg Det: 0.1080 | W-NPS: 0.2961 | W-TV: 2.5249 | YOLO force: 2.233493 | NPS & TV force: 1.026102
# Step   36/480 | Batch Avg Det: 0.0907 | W-NPS: 0.2962 | W-TV: 2.5263 | YOLO force: 2.146892 | NPS & TV force: 1.027304
# Step   48/480 | Batch Avg Det: 0.1370 | W-NPS: 0.2961 | W-TV: 2.5275 | YOLO force: 2.207231 | NPS & TV force: 1.023443
# Step   60/480 | Batch Avg Det: 0.1095 | W-NPS: 0.2959 | W-TV: 2.5285 | YOLO force: 2.154278 | NPS & TV force: 1.033087
# Step   72/480 | Batch Avg Det: 0.1051 | W-NPS: 0.2957 | W-TV: 2.5293 | YOLO force: 2.088716 | NPS & TV force: 1.036016
# Step   84/480 | Batch Avg Det: 0.1306 | W-NPS: 0.2953 | W-TV: 2.5297 | YOLO force: 2.101532 | NPS & TV force: 1.035329
# Step   96/480 | Batch Avg Det: 0.0746 | W-NPS: 0.2948 | W-TV: 2.5298 | YOLO force: 1.628413 | NPS & TV force: 1.032709
# Step  108/480 | Batch Avg Det: 0.1736 | W-NPS: 0.2940 | W-TV: 2.5297 | YOLO force: 2.519252 | NPS & TV force: 1.015574
# Step  120/480 | Batch Avg Det: 0.1500 | W-NPS: 0.2931 | W-TV: 2.5294 | YOLO force: 2.338498 | NPS & TV force: 1.008164
# Step  132/480 | Batch Avg Det: 0.0781 | W-NPS: 0.2920 | W-TV: 2.5291 | YOLO force: 2.009491 | NPS & TV force: 0.999596
# Step  144/480 | Batch Avg Det: 0.1362 | W-NPS: 0.2909 | W-TV: 2.5289 | YOLO force: 1.625513 | NPS & TV force: 0.998246
# Step  156/480 | Batch Avg Det: 0.1704 | W-NPS: 0.2897 | W-TV: 2.5286 | YOLO force: 1.180289 | NPS & TV force: 0.990980
# Step  168/480 | Batch Avg Det: 0.1022 | W-NPS: 0.2883 | W-TV: 2.5281 | YOLO force: 1.225339 | NPS & TV force: 0.980757
# Step  180/480 | Batch Avg Det: 0.1359 | W-NPS: 0.2868 | W-TV: 2.5275 | YOLO force: 2.607932 | NPS & TV force: 0.973649
# Step  192/480 | Batch Avg Det: 0.1911 | W-NPS: 0.2854 | W-TV: 2.5268 | YOLO force: 1.880559 | NPS & TV force: 0.967149
# Step  204/480 | Batch Avg Det: 0.0985 | W-NPS: 0.2841 | W-TV: 2.5261 | YOLO force: 1.819083 | NPS & TV force: 0.954600
# Step  216/480 | Batch Avg Det: 0.1109 | W-NPS: 0.2828 | W-TV: 2.5256 | YOLO force: 2.861874 | NPS & TV force: 0.949262
# Step  228/480 | Batch Avg Det: 0.1460 | W-NPS: 0.2817 | W-TV: 2.5251 | YOLO force: 0.957656 | NPS & TV force: 0.943498
# Step  240/480 | Batch Avg Det: 0.2846 | W-NPS: 0.2805 | W-TV: 2.5245 | YOLO force: 2.210970 | NPS & TV force: 0.941069
# Step  252/480 | Batch Avg Det: 0.2251 | W-NPS: 0.2794 | W-TV: 2.5240 | YOLO force: 2.846182 | NPS & TV force: 0.936551
# Step  264/480 | Batch Avg Det: 0.1361 | W-NPS: 0.2784 | W-TV: 2.5237 | YOLO force: 2.691803 | NPS & TV force: 0.930351
# Step  276/480 | Batch Avg Det: 0.2005 | W-NPS: 0.2775 | W-TV: 2.5237 | YOLO force: 2.262032 | NPS & TV force: 0.934118
# Step  288/480 | Batch Avg Det: 0.1540 | W-NPS: 0.2768 | W-TV: 2.5238 | YOLO force: 1.182910 | NPS & TV force: 0.931628
# Step  300/480 | Batch Avg Det: 0.1462 | W-NPS: 0.2759 | W-TV: 2.5238 | YOLO force: 0.933576 | NPS & TV force: 0.929193
# Step  312/480 | Batch Avg Det: 0.0932 | W-NPS: 0.2750 | W-TV: 2.5238 | YOLO force: 2.004648 | NPS & TV force: 0.931502
# Step  324/480 | Batch Avg Det: 0.1689 | W-NPS: 0.2741 | W-TV: 2.5238 | YOLO force: 2.620442 | NPS & TV force: 0.936035
# Step  336/480 | Batch Avg Det: 0.1395 | W-NPS: 0.2732 | W-TV: 2.5239 | YOLO force: 2.172164 | NPS & TV force: 0.940827
# Step  348/480 | Batch Avg Det: 0.1585 | W-NPS: 0.2725 | W-TV: 2.5239 | YOLO force: 1.239246 | NPS & TV force: 0.938335
# Step  360/480 | Batch Avg Det: 0.1506 | W-NPS: 0.2717 | W-TV: 2.5240 | YOLO force: 2.345377 | NPS & TV force: 0.939928
# Step  372/480 | Batch Avg Det: 0.1846 | W-NPS: 0.2709 | W-TV: 2.5240 | YOLO force: 2.395660 | NPS & TV force: 0.928664
# Step  384/480 | Batch Avg Det: 0.1592 | W-NPS: 0.2702 | W-TV: 2.5240 | YOLO force: 1.016860 | NPS & TV force: 0.932452
# Step  396/480 | Batch Avg Det: 0.0821 | W-NPS: 0.2695 | W-TV: 2.5240 | YOLO force: 1.462816 | NPS & TV force: 0.940689
# Step  408/480 | Batch Avg Det: 0.0618 | W-NPS: 0.2687 | W-TV: 2.5238 | YOLO force: 1.430135 | NPS & TV force: 0.934553
# Step  420/480 | Batch Avg Det: 0.1380 | W-NPS: 0.2679 | W-TV: 2.5236 | YOLO force: 1.704941 | NPS & TV force: 0.925944
# Step  432/480 | Batch Avg Det: 0.1771 | W-NPS: 0.2670 | W-TV: 2.5233 | YOLO force: 2.890318 | NPS & TV force: 0.914378
# Step  444/480 | Batch Avg Det: 0.1545 | W-NPS: 0.2663 | W-TV: 2.5233 | YOLO force: 1.896487 | NPS & TV force: 0.918416
# Step  456/480 | Batch Avg Det: 0.0697 | W-NPS: 0.2655 | W-TV: 2.5231 | YOLO force: 2.246994 | NPS & TV force: 0.910972
# Step  468/480 | Batch Avg Det: 0.1433 | W-NPS: 0.2648 | W-TV: 2.5230 | YOLO force: 1.876395 | NPS & TV force: 0.908895
# Step  480/480 | Batch Avg Det: 0.2704 | W-NPS: 0.2641 | W-TV: 2.5229 | YOLO force: 0.370618 | NPS & TV force: 0.911099
# >> EPOCH 10 SUMMARY | Train Det: 0.1407 | Val Det: 0.0851 | LR: 0.000500 <<
#
# Training complete. Patch saved to noise_checkpoints folder.
# Visualizing results on a random test image from the loaded dataset...
