# %%
import tensorflow as tf
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import pandas as pd

# ========== HARDWARE ACCELERATION ==========
# Enable XLA compilation for faster math
tf.config.optimizer.set_jit(True) 
# Enable Mixed Precision (uses fp16 for speed, fp32 for stability)
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# ========== CONFIGURATION ==========

DATASET_FOLDER      = 'sample_dataset'
METADATA_CSV        = os.path.join(DATASET_FOLDER, 'metadata.csv')

# Limit dataset size for testing
TRAIN_SAMPLES    =  480 # 672
VAL_SPLIT_SIZE = 72 # 96

MAX_SAMPLES = TRAIN_SAMPLES + VAL_SPLIT_SIZE

# Dataset Filters
ALLOWED_DISTANCES = [5, 7] # [5, 7, 10]
ALLOWED_PITCHES   = [30] # [10, 30, 45]

EPOCHS              = 15
ACCUMULATION_STEPS  = 12 # batch size

MODEL_PATH_RENDERER = 'models/k3_100epch_wo_custom_loss_model.h5'
MODEL_PATH_YOLO     = 'yolov8n_saved_model'

IMG_SIZE            = (500, 500)
YOLO_SIZE           = (640, 640)
TEX_RES             = 16 
TEX_UPSCALE_RES     = 256

INITIAL_TEX_PATH    = 'textures/random_tex.png'

ATTACK_MODE         = 'misclassification'   # 'hide' or 'misclassification'

DETECTION_WEIGHT    = 18.0
TV_WEIGHT           = 10.0
NPS_WEIGHT          = 12.0

LEARNING_RATE = 0.05

NPS_DIM = 5

STEPS_PER_EPOCH = TRAIN_SAMPLES // ACCUMULATION_STEPS
TOTAL_OPTIMIZER_STEPS = STEPS_PER_EPOCH * EPOCHS

VEHICLE_CLASS_IDS   = [2, 7, 5]  # car, truck, bus

CLASSES = {
    0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus',
    6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant',
    11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat',
    16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear',
    22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag',
    27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard',
    32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove',
    36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle',
    40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl',
    46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli',
    51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake',
    56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table',
    61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard',
    67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink',
    72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors',
    77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'
}

# ========== SETUP ========== 

renderer_model = tf.keras.models.load_model(MODEL_PATH_RENDERER, compile=False)
yolo_loaded    = tf.saved_model.load(MODEL_PATH_YOLO)
yolo_infer     = yolo_loaded.signatures['serving_default']


# printable colour palette for NPS
grid_1d = tf.linspace(0.05, 0.95, NPS_DIM)
r, g, b = tf.meshgrid(grid_1d, grid_1d, grid_1d)
_colors = tf.reshape(tf.stack([r, g, b], axis=-1), [-1, 3])
TARGET_COLORS = tf.boolean_mask(_colors, (tf.reduce_max(_colors, axis=1) - tf.reduce_min(_colors, axis=1)) < 0.9)


def load_image_for_style(path):
    img = tf.image.convert_image_dtype(tf.image.decode_png(tf.io.read_file(path), channels=3), tf.float32)
    return tf.expand_dims(tf.image.resize(img, [TEX_UPSCALE_RES, TEX_UPSCALE_RES]), 0)

initial_tex = load_image_for_style(INITIAL_TEX_PATH)
# Force fp32 for our optimized variable to prevent precision loss during accumulation
tf_texture  = tf.Variable(tf.image.resize(initial_tex, [TEX_RES, TEX_RES])[0], dtype=tf.float32)
gradient_accumulator = tf.Variable(tf.zeros_like(tf_texture), trainable=False, dtype=tf.float32)

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=LEARNING_RATE,
    decay_steps=TOTAL_OPTIMIZER_STEPS,
    alpha=0.01
)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

os.makedirs('noise_checkpoints', exist_ok=True) # Directory for saving patches

# ========== SAFE DATASET PIPELINE ==========

df_meta = pd.read_csv(METADATA_CSV)

# 1. Instantly filter the dataframe to only keep allowed distances and pitches
if ALLOWED_DISTANCES:
    df_meta = df_meta[df_meta['distance'].isin(ALLOWED_DISTANCES)]
if ALLOWED_PITCHES:
    df_meta = df_meta[df_meta['pitch'].isin(ALLOWED_PITCHES)]

print(f"Found {len(df_meta)} rows in CSV matching the filters. Checking files...")

valid_filenames, valid_distances, valid_pitches, valid_yaws = [], [], [], []

# 2. Iterate through the FILTERED dataframe to check file existence
for idx, row in df_meta.iterrows():
    if len(valid_filenames) >= MAX_SAMPLES:
        break
        
    base_name = str(row['filename']).zfill(5)
    ref_path = os.path.join(DATASET_FOLDER, 'reference', f"{base_name}.png")
    mask_path = os.path.join(DATASET_FOLDER, 'masks', f"{base_name}.png")
    overlay_path = os.path.join(DATASET_FOLDER, 'overlays', f"{base_name}.png")
    
    # Only include if all 3 files exist
    if os.path.exists(ref_path) and os.path.exists(mask_path) and os.path.exists(overlay_path):
        valid_filenames.append(f"{base_name}.png")
        valid_distances.append(np.float32(row['distance']))
        valid_pitches.append(np.float32(row['pitch']))
        valid_yaws.append(np.float32(row['yaw']))

NUM_SAMPLES = len(valid_filenames)
print(f"Verified {NUM_SAMPLES} valid samples for training.")

def process_path(filename, distance, pitch, yaw):
    ref_path     = tf.strings.join([DATASET_FOLDER, tf.constant('/reference/'), filename])
    mask_path    = tf.strings.join([DATASET_FOLDER, tf.constant('/masks/'), filename])
    overlay_path = tf.strings.join([DATASET_FOLDER, tf.constant('/overlays/'), filename])

    def read_img(path):
        img = tf.image.decode_png(tf.io.read_file(path), channels=3)
        return tf.image.resize(tf.image.convert_image_dtype(img, tf.float32), IMG_SIZE)

    return read_img(ref_path), read_img(mask_path), read_img(overlay_path), tf.stack([distance, pitch, yaw])

def create_dataset():
    ds = tf.data.Dataset.from_tensor_slices((valid_filenames, valid_distances, valid_pitches, valid_yaws))
    ds = ds.shuffle(buffer_size=NUM_SAMPLES)
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

# ========== RENDERING & LOSS ==========

def calc_transforms(pitch, yaw):
    yaw_diff   = ((yaw + 45.0) % 90.0) - 45.0
    cond_front = tf.logical_and(yaw > 145.0, yaw < 215.0)
    p = tf.where(cond_front, -pitch, pitch)
    y = tf.where(cond_front, -yaw_diff, 0.0)
    r = tf.where(cond_front, 0.0, -yaw_diff)
    p = tf.where(pitch < 15.0, pitch,  p);  y = tf.where(pitch < 15.0, 0.0,       y);  r = tf.where(pitch < 15.0, -yaw_diff, r)
    p = tf.where(pitch > 35.0, -pitch, p);  y = tf.where(pitch > 35.0, -yaw_diff, y);  r = tf.where(pitch > 35.0, 0.0,       r)
    return p, y, r

def get_rotation_matrix(pitch, yaw, roll):
    s = np.pi / 180.0
    p, y, r = pitch * s, yaw * s, roll * s
    Rp = tf.stack([[1., 0., 0.], [0., tf.cos(p), -tf.sin(p)], [0., tf.sin(p), tf.cos(p)]])
    Rr = tf.stack([[tf.cos(r), 0., tf.sin(r)], [0., 1., 0.], [-tf.sin(r), 0., tf.cos(r)]])
    Ry = tf.stack([[tf.cos(y), -tf.sin(y), 0.], [tf.sin(y), tf.cos(y), 0.], [0., 0., 1.]])
    return tf.matmul(Rp, tf.matmul(Rr, Ry))

@tf.function
def render_texture(texture, pitch, yaw, roll, distance, uv_scale=100.0, shift_u=0.0, shift_v=0.0):
    out_h, out_w = IMG_SIZE
    f  = 500.0
    high_res_tex = tf.image.resize(texture, [TEX_UPSCALE_RES, TEX_UPSCALE_RES], method='nearest')
    R            = get_rotation_matrix(pitch, yaw, roll)
    plane_normal = R[:, 2]
    plane_point  = plane_normal * (distance * 100.0)

    grid_x, grid_y = tf.meshgrid(tf.range(out_w), tf.range(out_h))
    ray_dir    = tf.stack([tf.cast(grid_x, tf.float32) - out_w/2.0, tf.cast(grid_y, tf.float32) - out_h/2.0, tf.ones([out_h, out_w]) * f], axis=-1)
    camera_pos = tf.constant([0.0, 0.0, -f])

    denom = tf.tensordot(ray_dir, plane_normal, axes=1)
    denom = tf.where(tf.abs(denom) < 1e-5, 1e-5, denom)
    t     = tf.tensordot(plane_point - camera_pos, plane_normal, axes=1) / denom

    hit_point = camera_pos + ray_dir * tf.expand_dims(t, -1)
    p_local   = tf.reshape(tf.matmul(tf.reshape(hit_point - plane_point, [-1, 3]), R), [out_h, out_w, 3])

    u = tf.math.floormod(p_local[:, :, 0] / uv_scale + shift_u, 1.0)
    v = tf.math.floormod(p_local[:, :, 1] / uv_scale + shift_v, 1.0)

    tex_h = tf.cast(tf.shape(high_res_tex)[0], tf.float32)
    tex_w = tf.cast(tf.shape(high_res_tex)[1], tf.float32)

    x, y_ = u * (tex_w - 1.0), v * (tex_h - 1.0)
    x  = tf.clip_by_value(x,  0.0, tex_w - 1.001)
    y_ = tf.clip_by_value(y_, 0.0, tex_h - 1.001)
    x0, y0 = tf.cast(tf.floor(x), tf.int32), tf.cast(tf.floor(y_), tf.int32)
    x1, y1 = x0 + 1, y0 + 1
    Ia, Ib = tf.gather_nd(high_res_tex, tf.stack([y0, x0], axis=-1)), tf.gather_nd(high_res_tex, tf.stack([y1, x0], axis=-1))
    Ic, Id = tf.gather_nd(high_res_tex, tf.stack([y0, x1], axis=-1)), tf.gather_nd(high_res_tex, tf.stack([y1, x1], axis=-1))
    wa = tf.expand_dims((tf.cast(x1, tf.float32) - x)  * (tf.cast(y1, tf.float32) - y_), -1)
    wb = tf.expand_dims((tf.cast(x1, tf.float32) - x)  * (y_ - tf.cast(y0, tf.float32)), -1)
    wc = tf.expand_dims((x - tf.cast(x0, tf.float32))  * (tf.cast(y1, tf.float32) - y_), -1)
    wd = tf.expand_dims((x - tf.cast(x0, tf.float32))  * (y_ - tf.cast(y0, tf.float32)), -1)
    output = tf.add_n([wa*Ia, wb*Ib, wc*Ic, wd*Id])

    return tf.where(tf.expand_dims(t > 0.0, -1), output, tf.zeros_like(output))

@tf.function
def compute_image_gradients(ref_img, mask_img, overlay_img, trans_tf, shift_u, shift_v):
    dist, pitch, yaw = trans_tf[0], trans_tf[1], trans_tf[2]
    p, y, r = calc_transforms(pitch, yaw)

    with tf.GradientTape() as tape:
        rendered   = render_texture(tf_texture, p, y, r, dist, shift_u=shift_u, shift_v=shift_v)
        tex_masked = tf.where(tf.reduce_max(mask_img, axis=-1, keepdims=True) > 0.1, rendered, tf.zeros_like(rendered))
        
        # Explicit FP32 casts for safety with Mixed Precision
        ref_f32 = tf.cast(ref_img, tf.float32)
        tex_masked_f32 = tf.cast(tex_masked, tf.float32)
        renderer_out = renderer_model([tf.expand_dims(ref_f32, 0), tf.expand_dims(tex_masked_f32, 0)], training=False)[0]
        
        adv_img  = tf.where(tf.reduce_max(overlay_img, axis=-1, keepdims=True) > 0.05, ref_img, renderer_out)
        yolo_in  = tf.cast(tf.image.resize(tf.expand_dims(adv_img, 0), YOLO_SIZE), tf.float32)
        yolo_out = yolo_infer(images=yolo_in)['output_0']

        all_class_scores = yolo_out[0, 4:, :]
        vehicle_scores   = tf.reduce_max(tf.gather(all_class_scores, VEHICLE_CLASS_IDS, axis=0), axis=0)
        
        if ATTACK_MODE == 'misclassification':
            all_idx = tf.range(tf.shape(all_class_scores)[0])
            non_vehicle_mask = tf.reduce_all(tf.not_equal(tf.expand_dims(all_idx, 1), tf.constant(VEHICLE_CLASS_IDS, dtype=all_idx.dtype)), axis=1)
            non_vehicle_scores = tf.reduce_max(tf.boolean_mask(all_class_scores, non_vehicle_mask, axis=0), axis=0)
            det_loss = tf.reduce_max(vehicle_scores - non_vehicle_scores)
        else:
            det_loss = tf.reduce_max(vehicle_scores)
            
        det_weighted_loss = DETECTION_WEIGHT * det_loss

    grads = tape.gradient(det_weighted_loss, tf_texture)
    return grads, det_loss, adv_img, yolo_out

@tf.function
def apply_accumulated_gradients(accumulated_image_grads, num_steps):
    averaged_image_grads = accumulated_image_grads / tf.cast(num_steps, tf.float32)
    
    with tf.GradientTape(persistent=True) as tape:
        tex_f32 = tf.cast(tf_texture, tf.float32) # Explicit FP32

        tv_loss  = TV_WEIGHT * tf.reduce_sum(tf.image.total_variation(tex_f32)) / tf.cast(tf.size(tex_f32), tf.float32)
        nps_loss = NPS_WEIGHT * tf.reduce_mean(tf.reduce_min(tf.sqrt(tf.reduce_sum(tf.square(tf.expand_dims(tf.reshape(tex_f32, [-1, 3]), 1) - TARGET_COLOURS) + 1e-8, axis=-1)), axis=1))

        
        nps_tv_loss= tv_loss + nps_loss

    nps_tv_grads = tape.gradient(nps_tv_loss, tf_texture)

    final_grads   = averaged_image_grads + nps_tv_grads 


    yolo_force = tf.norm(averaged_image_grads)

    nps_tv_force = tf.norm(nps_tv_grads)

    
    optimizer.apply_gradients([(final_grads, tf_texture)])
    tf_texture.assign(tf.clip_by_value(tf_texture, 0.0, 1.0))
    
    return tv_loss, nps_loss, yolo_force, nps_tv_force

def draw_yolo_results(image_tf, yolo_output, conf_thresh=0.25):
    img    = (image_tf.numpy() * 255).astype(np.uint8).copy()
    output = np.transpose(yolo_output.numpy()[0])
    scale  = [IMG_SIZE[1] / YOLO_SIZE[1], IMG_SIZE[0] / YOLO_SIZE[0]] * 2

    boxes, confs, class_ids = [], [], []
    for row in output:
        cls_id = np.argmax(row[4:])
        score  = row[4:][cls_id]
        if score > conf_thresh:
            cx, cy, w, h = row[:4] * scale
            boxes.append([int(cx - w/2), int(cy - h/2), int(w), int(h)])
            confs.append(float(score));  class_ids.append(cls_id)

    indices = cv2.dnn.NMSBoxes(boxes, confs, conf_thresh, 0.45)
    if len(indices) > 0:
        for i in indices.flatten():
            bx, by, bw, bh = boxes[i]
            cv2.rectangle(img, (bx, by), (bx+bw, by+bh), (0, 255, 0), 2)
            cv2.putText(img, f"{CLASSES.get(class_ids[i], 'obj')}: {confs[i]:.2f}", (bx, by-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    return img

# ========== DATASET SPLIT & MAIN LOOP ==========


train_filenames = valid_filenames[:-VAL_SPLIT_SIZE]
train_distances = valid_distances[:-VAL_SPLIT_SIZE]
train_pitches   = valid_pitches[:-VAL_SPLIT_SIZE]
train_yaws      = valid_yaws[:-VAL_SPLIT_SIZE]

val_filenames = valid_filenames[-VAL_SPLIT_SIZE:]
val_distances = valid_distances[-VAL_SPLIT_SIZE:]
val_pitches   = valid_pitches[-VAL_SPLIT_SIZE:]
val_yaws      = valid_yaws[-VAL_SPLIT_SIZE:]

NUM_TRAIN = len(train_filenames)
print(f"Split dataset: {NUM_TRAIN} for training, {VAL_SPLIT_SIZE} for validation.")

def create_dataset_split(f, d, p, y, shuffle=True):
    ds = tf.data.Dataset.from_tensor_slices((f, d, p, y))
    if shuffle: ds = ds.shuffle(buffer_size=len(f))
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    return ds.prefetch(tf.data.AUTOTUNE)

history = {'det': [], 'tv': [], 'nps': [], 'val_det': []}

for epoch in range(EPOCHS):
    print(f"\n--- Epoch {epoch + 1}/{EPOCHS} ---")
    
    train_dataset = create_dataset_split(train_filenames, train_distances, train_pitches, train_yaws, shuffle=True)
    gradient_accumulator.assign(tf.zeros_like(tf_texture))
    accumulated_count = 0
    step_det_losses = [] 
    
    last_tv, last_nps= 0.0, 0.0
    
    # --- TRAINING LOOP ---
    for step, (ref, mask, overlay, trans_tf) in enumerate(train_dataset):
        shift_u = tf.random.uniform(shape=[], minval=0.0, maxval=1.0)
        shift_v = tf.random.uniform(shape=[], minval=0.0, maxval=1.0)

        grads, det_loss, cur_adv, cur_yolo = compute_image_gradients(ref, mask, overlay, trans_tf, shift_u, shift_v)
        gradient_accumulator.assign_add(grads)
        accumulated_count += 1
        step_det_losses.append(det_loss.numpy())

        # Clean modulo check for flushing
        if (step + 1) % ACCUMULATION_STEPS == 0:
            tv_val, nps_val, yolo_force, nps_tv_force = apply_accumulated_gradients(gradient_accumulator, accumulated_count)

            last_tv, last_nps = tv_val.numpy(), nps_val.numpy()
            current_avg_det = np.mean(step_det_losses)
            
            # Print BEFORE we clear the array!
            print(f"Step {step+1:4d}/{NUM_TRAIN} | Batch Avg Det: {current_avg_det:.4f} | W-NPS: {last_nps:.4f} | W-TV: {last_tv:.4f} | YOLO force: {yolo_force.numpy():.6f} | NPS & TV force: {nps_tv_force.numpy():.6f}")

            history['det'].append(current_avg_det)
            history['tv'].append(last_tv); history['nps'].append(last_nps)
            
            gradient_accumulator.assign(tf.zeros_like(tf_texture))
            accumulated_count = 0
            step_det_losses = []

    # Unconditional safety flush at end of epoch
    if accumulated_count > 0:
        tv_val, nps_val = apply_accumulated_gradients(gradient_accumulator, accumulated_count)
        history['det'].append(np.mean(step_det_losses))
        history['tv'].append(tv_val.numpy()); history['nps'].append(nps_val.numpy())

    # --- VALIDATION LOOP ---
    val_dataset = create_dataset_split(val_filenames, val_distances, val_pitches, val_yaws, shuffle=False)
    val_losses = []
    
    for val_ref, val_mask, val_overlay, val_trans in val_dataset:
        # Pass through without gradients
        _, v_det, _, _ = compute_image_gradients(val_ref, val_mask, val_overlay, val_trans, 0.0, 0.0)
        val_losses.append(v_det.numpy())
        
    epoch_val_det = np.mean(val_losses)
    history['val_det'].append(epoch_val_det)

    current_lr = lr_schedule(optimizer.iterations).numpy()
    
    print(f">> EPOCH {epoch+1} SUMMARY | Train Det: {np.mean(history['det'][-(NUM_TRAIN//ACCUMULATION_STEPS):]):.4f} | Val Det: {epoch_val_det:.4f} | LR: {current_lr:.6f} <<")

    # Checkpoint the texture
    patch_bgr = cv2.cvtColor((tf.clip_by_value(tf_texture, 0.0, 1.0).numpy() * 255).astype(np.uint8), cv2.COLOR_RGB2BGR)
    cv2.imwrite(f"noise_checkpoints/patch_epoch_{epoch+1}.png", patch_bgr)

print("\nTraining complete. Patch saved to noise_checkpoints folder.")

# ========== VISUALISATION ==========
print("Visualizing results on a random test image from the loaded dataset...")

# Fetch one random sample from our validated lists
test_idx = np.random.randint(0, NUM_SAMPLES)
test_base_name = valid_filenames[test_idx]
ref_test = tf.image.resize(tf.image.convert_image_dtype(tf.image.decode_png(tf.io.read_file(os.path.join(DATASET_FOLDER, 'reference', test_base_name)), channels=3), tf.float32), IMG_SIZE)
mask_test = tf.image.resize(tf.image.convert_image_dtype(tf.image.decode_png(tf.io.read_file(os.path.join(DATASET_FOLDER, 'masks', test_base_name)), channels=3), tf.float32), IMG_SIZE)
overlay_test = tf.image.resize(tf.image.convert_image_dtype(tf.image.decode_png(tf.io.read_file(os.path.join(DATASET_FOLDER, 'overlays', test_base_name)), channels=3), tf.float32), IMG_SIZE)
trans_tf_test = tf.constant(np.array([valid_distances[test_idx], valid_pitches[test_idx], valid_yaws[test_idx]], dtype=np.float32))

# Baseline detection
ref_f32 = tf.cast(ref_test, tf.float32)
ref_yolo_in = tf.cast(tf.image.resize(tf.expand_dims(ref_f32, 0), YOLO_SIZE), tf.float32)
ref_yolo_out = yolo_infer(images=ref_yolo_in)['output_0']
ref_max_conf = tf.reduce_max(tf.stack([ref_yolo_out[0, 4 + c, :] for c in VEHICLE_CLASS_IDS]))

# Attack with Final Optimized Texture
p_test, y_test, r_test = calc_transforms(trans_tf_test[1], trans_tf_test[2])
test_rendered     = render_texture(tf_texture, p_test, y_test, r_test, trans_tf_test[0])
test_tex_masked   = tf.where(tf.reduce_max(mask_test, axis=-1, keepdims=True) > 0.1, test_rendered, tf.zeros_like(test_rendered))
test_renderer_out = renderer_model([tf.expand_dims(ref_f32, 0), tf.expand_dims(tf.cast(test_tex_masked, tf.float32), 0)], training=False)[0]
test_adv          = tf.where(tf.reduce_max(overlay_test, axis=-1, keepdims=True) > 0.05, ref_test, test_renderer_out)
test_yolo_in      = tf.cast(tf.image.resize(tf.expand_dims(test_adv, 0), YOLO_SIZE), tf.float32)
test_yolo         = yolo_infer(images=test_yolo_in)['output_0']

weighted_det_history = [x * DETECTION_WEIGHT for x in history['det']]

# Plot Results
plt.figure(figsize=(18, 10))

plt.subplot(2, 2, 1);  plt.imshow(draw_yolo_results(ref_test, ref_yolo_out));   plt.title(f"Original Reference (Conf: {ref_max_conf.numpy():.4f})")
plt.subplot(2, 2, 2);  plt.imshow(draw_yolo_results(test_adv, test_yolo));      plt.title(f"Optimized State")

plt.subplot(2, 2, 3)
plt.plot(weighted_det_history,   label='Weighted Detection',      linestyle='--')
plt.plot(history['nps'],   label='Weighted NPS',   linestyle='-.')
plt.plot(history['tv'],    label='Weighted TV',    linestyle=':')
plt.title("Loss Components (Per Accumulation Window)");  plt.xlabel("Accumulation Steps");  plt.legend()

plt.subplot(2, 2, 4);  
plt.imshow(tf.clip_by_value(tf_texture, 0.0, 1.0).numpy()); plt.title("Final Optimized Patch")

plt.tight_layout()
plt.show()
# Out:
# Found 5394 rows in CSV matching the filters. Checking files...
# Verified 552 valid samples for training.
# Split dataset: 480 for training, 72 for validation.
#
# --- Epoch 1/15 ---
# Step   12/480 | Batch Avg Det: 0.4068 | W-NPS: 2.1494 | W-TV: 6.1025 | YOLO force: 6.979474 | NPS & TV force: 1.385909
# Step   24/480 | Batch Avg Det: 0.5161 | W-NPS: 2.1606 | W-TV: 6.0568 | YOLO force: 4.117663 | NPS & TV force: 1.377982
# Step   36/480 | Batch Avg Det: 0.2315 | W-NPS: 2.1657 | W-TV: 5.9421 | YOLO force: 7.924084 | NPS & TV force: 1.351254
# Step   48/480 | Batch Avg Det: 0.3366 | W-NPS: 2.1658 | W-TV: 5.8900 | YOLO force: 4.753492 | NPS & TV force: 1.353119
# Step   60/480 | Batch Avg Det: 0.3858 | W-NPS: 2.1865 | W-TV: 5.8484 | YOLO force: 4.995876 | NPS & TV force: 1.327215
# Step   72/480 | Batch Avg Det: 0.3748 | W-NPS: 2.1991 | W-TV: 5.8000 | YOLO force: 4.495128 | NPS & TV force: 1.329173
# Step   84/480 | Batch Avg Det: 0.3715 | W-NPS: 2.2181 | W-TV: 5.7615 | YOLO force: 2.217319 | NPS & TV force: 1.309647
# Step   96/480 | Batch Avg Det: 0.3344 | W-NPS: 2.2309 | W-TV: 5.7161 | YOLO force: 4.965487 | NPS & TV force: 1.286103
# Step  108/480 | Batch Avg Det: 0.2951 | W-NPS: 2.2472 | W-TV: 5.6851 | YOLO force: 3.995795 | NPS & TV force: 1.291584
# Step  120/480 | Batch Avg Det: 0.3113 | W-NPS: 2.2526 | W-TV: 5.6510 | YOLO force: 3.916749 | NPS & TV force: 1.293000
# Step  132/480 | Batch Avg Det: 0.2784 | W-NPS: 2.2483 | W-TV: 5.6142 | YOLO force: 3.540663 | NPS & TV force: 1.298136
# Step  144/480 | Batch Avg Det: 0.3635 | W-NPS: 2.2526 | W-TV: 5.5711 | YOLO force: 4.191839 | NPS & TV force: 1.301925
# Step  156/480 | Batch Avg Det: 0.2532 | W-NPS: 2.2619 | W-TV: 5.5323 | YOLO force: 3.681941 | NPS & TV force: 1.289717
# Step  168/480 | Batch Avg Det: 0.3277 | W-NPS: 2.2757 | W-TV: 5.4976 | YOLO force: 1.567887 | NPS & TV force: 1.284809
# Step  180/480 | Batch Avg Det: 0.2808 | W-NPS: 2.2933 | W-TV: 5.4581 | YOLO force: 3.889835 | NPS & TV force: 1.289008
# Step  192/480 | Batch Avg Det: 0.1467 | W-NPS: 2.3172 | W-TV: 5.4299 | YOLO force: 3.030953 | NPS & TV force: 1.274669
# Step  204/480 | Batch Avg Det: 0.2960 | W-NPS: 2.3274 | W-TV: 5.4005 | YOLO force: 4.199350 | NPS & TV force: 1.277657
# Step  216/480 | Batch Avg Det: 0.0460 | W-NPS: 2.3362 | W-TV: 5.3679 | YOLO force: 1.361174 | NPS & TV force: 1.283062
# Step  228/480 | Batch Avg Det: 0.1009 | W-NPS: 2.3362 | W-TV: 5.3255 | YOLO force: 2.593171 | NPS & TV force: 1.275494
# Step  240/480 | Batch Avg Det: 0.1767 | W-NPS: 2.3216 | W-TV: 5.2764 | YOLO force: 3.788962 | NPS & TV force: 1.276399
# Step  252/480 | Batch Avg Det: 0.1489 | W-NPS: 2.3073 | W-TV: 5.2276 | YOLO force: 2.307297 | NPS & TV force: 1.267457
# Step  264/480 | Batch Avg Det: 0.0968 | W-NPS: 2.2845 | W-TV: 5.1700 | YOLO force: 0.768468 | NPS & TV force: 1.260252
# Step  276/480 | Batch Avg Det: 0.1951 | W-NPS: 2.2579 | W-TV: 5.0985 | YOLO force: 2.526597 | NPS & TV force: 1.252926
# Step  288/480 | Batch Avg Det: 0.1188 | W-NPS: 2.2341 | W-TV: 5.0144 | YOLO force: 1.173816 | NPS & TV force: 1.237505
# Step  300/480 | Batch Avg Det: 0.1163 | W-NPS: 2.2082 | W-TV: 4.9249 | YOLO force: 3.503985 | NPS & TV force: 1.220252
# Step  312/480 | Batch Avg Det: 0.2618 | W-NPS: 2.1894 | W-TV: 4.8465 | YOLO force: 2.345034 | NPS & TV force: 1.206635
# Step  324/480 | Batch Avg Det: 0.2287 | W-NPS: 2.1641 | W-TV: 4.7694 | YOLO force: 2.999717 | NPS & TV force: 1.210012
# Step  336/480 | Batch Avg Det: 0.2459 | W-NPS: 2.1442 | W-TV: 4.6978 | YOLO force: 2.821586 | NPS & TV force: 1.197193
# Step  348/480 | Batch Avg Det: 0.1398 | W-NPS: 2.1215 | W-TV: 4.6314 | YOLO force: 2.129920 | NPS & TV force: 1.186350
# Step  360/480 | Batch Avg Det: 0.2209 | W-NPS: 2.0933 | W-TV: 4.5588 | YOLO force: 4.007449 | NPS & TV force: 1.176934
# Step  372/480 | Batch Avg Det: 0.1208 | W-NPS: 2.0743 | W-TV: 4.5031 | YOLO force: 4.024323 | NPS & TV force: 1.173047
# Step  384/480 | Batch Avg Det: 0.1337 | W-NPS: 2.0600 | W-TV: 4.4593 | YOLO force: 2.491231 | NPS & TV force: 1.182550
# Step  396/480 | Batch Avg Det: 0.1057 | W-NPS: 2.0407 | W-TV: 4.4130 | YOLO force: 1.639096 | NPS & TV force: 1.185838
# Step  408/480 | Batch Avg Det: 0.1875 | W-NPS: 2.0237 | W-TV: 4.3623 | YOLO force: 1.973909 | NPS & TV force: 1.176875
# Step  420/480 | Batch Avg Det: 0.1456 | W-NPS: 2.0052 | W-TV: 4.3127 | YOLO force: 2.817801 | NPS & TV force: 1.177209
# Step  432/480 | Batch Avg Det: 0.1538 | W-NPS: 2.0001 | W-TV: 4.2688 | YOLO force: 2.911666 | NPS & TV force: 1.176986
# Step  444/480 | Batch Avg Det: 0.1572 | W-NPS: 1.9967 | W-TV: 4.2263 | YOLO force: 2.315479 | NPS & TV force: 1.177262
# Step  456/480 | Batch Avg Det: 0.1369 | W-NPS: 1.9969 | W-TV: 4.1872 | YOLO force: 2.372753 | NPS & TV force: 1.176397
# Step  468/480 | Batch Avg Det: 0.1442 | W-NPS: 1.9970 | W-TV: 4.1456 | YOLO force: 2.275157 | NPS & TV force: 1.182580
# Step  480/480 | Batch Avg Det: 0.1521 | W-NPS: 1.9921 | W-TV: 4.1002 | YOLO force: 3.524654 | NPS & TV force: 1.185471
# >> EPOCH 1 SUMMARY | Train Det: 0.2261 | Val Det: 0.1258 | LR: 0.049459 <<
#
# --- Epoch 2/15 ---
# Step   12/480 | Batch Avg Det: 0.1713 | W-NPS: 1.9867 | W-TV: 4.0564 | YOLO force: 3.149955 | NPS & TV force: 1.187327
# Step   24/480 | Batch Avg Det: 0.1446 | W-NPS: 1.9752 | W-TV: 4.0015 | YOLO force: 0.114524 | NPS & TV force: 1.170710
# Step   36/480 | Batch Avg Det: 0.2131 | W-NPS: 1.9533 | W-TV: 3.9403 | YOLO force: 3.928531 | NPS & TV force: 1.154833
# Step   48/480 | Batch Avg Det: 0.1325 | W-NPS: 1.9335 | W-TV: 3.8793 | YOLO force: 3.024781 | NPS & TV force: 1.154812
# Step   60/480 | Batch Avg Det: 0.1576 | W-NPS: 1.9181 | W-TV: 3.8269 | YOLO force: 3.496242 | NPS & TV force: 1.150076
# Step   72/480 | Batch Avg Det: 0.0595 | W-NPS: 1.9146 | W-TV: 3.7812 | YOLO force: 2.478162 | NPS & TV force: 1.145826
# Step   84/480 | Batch Avg Det: 0.2213 | W-NPS: 1.9115 | W-TV: 3.7381 | YOLO force: 1.202006 | NPS & TV force: 1.145037
# Step   96/480 | Batch Avg Det: 0.0922 | W-NPS: 1.9071 | W-TV: 3.6951 | YOLO force: 3.456070 | NPS & TV force: 1.137357
# Step  108/480 | Batch Avg Det: 0.1433 | W-NPS: 1.9049 | W-TV: 3.6560 | YOLO force: 2.693740 | NPS & TV force: 1.136464
# Step  120/480 | Batch Avg Det: 0.0945 | W-NPS: 1.8982 | W-TV: 3.6203 | YOLO force: 2.160170 | NPS & TV force: 1.140919
# Step  132/480 | Batch Avg Det: 0.0774 | W-NPS: 1.8860 | W-TV: 3.5868 | YOLO force: 1.900750 | NPS & TV force: 1.124713
# Step  144/480 | Batch Avg Det: 0.0873 | W-NPS: 1.8648 | W-TV: 3.5532 | YOLO force: 0.890616 | NPS & TV force: 1.134156
# Step  156/480 | Batch Avg Det: 0.1879 | W-NPS: 1.8365 | W-TV: 3.5086 | YOLO force: 3.890191 | NPS & TV force: 1.117165
# Step  168/480 | Batch Avg Det: 0.0989 | W-NPS: 1.8226 | W-TV: 3.4706 | YOLO force: 3.196737 | NPS & TV force: 1.107255
# Step  180/480 | Batch Avg Det: 0.1683 | W-NPS: 1.8092 | W-TV: 3.4459 | YOLO force: 2.746934 | NPS & TV force: 1.117067
# Step  192/480 | Batch Avg Det: 0.1981 | W-NPS: 1.7976 | W-TV: 3.4337 | YOLO force: 1.951429 | NPS & TV force: 1.106338
# Step  204/480 | Batch Avg Det: 0.2265 | W-NPS: 1.7853 | W-TV: 3.4266 | YOLO force: 1.384893 | NPS & TV force: 1.106943
# Step  216/480 | Batch Avg Det: 0.1817 | W-NPS: 1.7703 | W-TV: 3.4130 | YOLO force: 2.014925 | NPS & TV force: 1.112024
# Step  228/480 | Batch Avg Det: 0.1522 | W-NPS: 1.7513 | W-TV: 3.3968 | YOLO force: 2.958976 | NPS & TV force: 1.117057
# Step  240/480 | Batch Avg Det: 0.1474 | W-NPS: 1.7328 | W-TV: 3.3838 | YOLO force: 3.582700 | NPS & TV force: 1.115337
# Step  252/480 | Batch Avg Det: 0.1700 | W-NPS: 1.7188 | W-TV: 3.3809 | YOLO force: 1.534369 | NPS & TV force: 1.119127
# Step  264/480 | Batch Avg Det: 0.1768 | W-NPS: 1.7022 | W-TV: 3.3779 | YOLO force: 2.842101 | NPS & TV force: 1.116253
# Step  276/480 | Batch Avg Det: 0.1158 | W-NPS: 1.6837 | W-TV: 3.3798 | YOLO force: 4.015997 | NPS & TV force: 1.119361
# Step  288/480 | Batch Avg Det: 0.1242 | W-NPS: 1.6666 | W-TV: 3.3956 | YOLO force: 2.478549 | NPS & TV force: 1.135566
# Step  300/480 | Batch Avg Det: 0.1125 | W-NPS: 1.6546 | W-TV: 3.4124 | YOLO force: 2.667595 | NPS & TV force: 1.142166
# Step  312/480 | Batch Avg Det: 0.1347 | W-NPS: 1.6428 | W-TV: 3.4273 | YOLO force: 1.899207 | NPS & TV force: 1.153987
# Step  324/480 | Batch Avg Det: 0.0807 | W-NPS: 1.6293 | W-TV: 3.4259 | YOLO force: 1.463108 | NPS & TV force: 1.163812
# Step  336/480 | Batch Avg Det: 0.0224 | W-NPS: 1.6091 | W-TV: 3.4110 | YOLO force: 0.161208 | NPS & TV force: 1.153998
# Step  348/480 | Batch Avg Det: 0.1611 | W-NPS: 1.5821 | W-TV: 3.3928 | YOLO force: 2.779285 | NPS & TV force: 1.161103
# Step  360/480 | Batch Avg Det: 0.0667 | W-NPS: 1.5613 | W-TV: 3.3672 | YOLO force: 2.933847 | NPS & TV force: 1.145461
# Step  372/480 | Batch Avg Det: 0.1468 | W-NPS: 1.5396 | W-TV: 3.3479 | YOLO force: 2.143471 | NPS & TV force: 1.137409
# Step  384/480 | Batch Avg Det: 0.1658 | W-NPS: 1.5214 | W-TV: 3.3309 | YOLO force: 2.967366 | NPS & TV force: 1.140909
# Step  396/480 | Batch Avg Det: 0.0763 | W-NPS: 1.5111 | W-TV: 3.3231 | YOLO force: 1.101050 | NPS & TV force: 1.138620
# Step  408/480 | Batch Avg Det: 0.1179 | W-NPS: 1.4988 | W-TV: 3.3069 | YOLO force: 2.582336 | NPS & TV force: 1.131259
# Step  420/480 | Batch Avg Det: 0.2550 | W-NPS: 1.4886 | W-TV: 3.2937 | YOLO force: 3.216960 | NPS & TV force: 1.138257
# Step  432/480 | Batch Avg Det: 0.1006 | W-NPS: 1.4822 | W-TV: 3.2847 | YOLO force: 2.170197 | NPS & TV force: 1.132938
# Step  444/480 | Batch Avg Det: 0.0644 | W-NPS: 1.4751 | W-TV: 3.2732 | YOLO force: 0.843930 | NPS & TV force: 1.133570
# Step  456/480 | Batch Avg Det: 0.0835 | W-NPS: 1.4627 | W-TV: 3.2563 | YOLO force: 2.739281 | NPS & TV force: 1.134196
# Step  468/480 | Batch Avg Det: 0.1855 | W-NPS: 1.4491 | W-TV: 3.2348 | YOLO force: 1.588783 | NPS & TV force: 1.131907
# Step  480/480 | Batch Avg Det: 0.1742 | W-NPS: 1.4356 | W-TV: 3.2143 | YOLO force: 3.291307 | NPS & TV force: 1.138585
# >> EPOCH 2 SUMMARY | Train Det: 0.1373 | Val Det: 0.1181 | LR: 0.047860 <<
#
# --- Epoch 3/15 ---
# Step   12/480 | Batch Avg Det: 0.2300 | W-NPS: 1.4253 | W-TV: 3.2030 | YOLO force: 2.673966 | NPS & TV force: 1.152723
# Step   24/480 | Batch Avg Det: 0.1697 | W-NPS: 1.4102 | W-TV: 3.1933 | YOLO force: 2.338542 | NPS & TV force: 1.152226
# Step   36/480 | Batch Avg Det: 0.1828 | W-NPS: 1.3918 | W-TV: 3.1877 | YOLO force: 2.474475 | NPS & TV force: 1.159946
# Step   48/480 | Batch Avg Det: 0.0749 | W-NPS: 1.3737 | W-TV: 3.1799 | YOLO force: 3.096356 | NPS & TV force: 1.156860
# Step   60/480 | Batch Avg Det: 0.2081 | W-NPS: 1.3550 | W-TV: 3.1853 | YOLO force: 0.654383 | NPS & TV force: 1.158287
# Step   72/480 | Batch Avg Det: 0.1993 | W-NPS: 1.3305 | W-TV: 3.1804 | YOLO force: 0.368704 | NPS & TV force: 1.161086
# Step   84/480 | Batch Avg Det: 0.0824 | W-NPS: 1.3011 | W-TV: 3.1659 | YOLO force: 1.314279 | NPS & TV force: 1.156619
# Step   96/480 | Batch Avg Det: 0.1993 | W-NPS: 1.2734 | W-TV: 3.1450 | YOLO force: 2.261942 | NPS & TV force: 1.155801
# Step  108/480 | Batch Avg Det: 0.0679 | W-NPS: 1.2486 | W-TV: 3.1223 | YOLO force: 2.257097 | NPS & TV force: 1.147027
# Step  120/480 | Batch Avg Det: 0.1869 | W-NPS: 1.2289 | W-TV: 3.0999 | YOLO force: 3.313452 | NPS & TV force: 1.136888
# Step  132/480 | Batch Avg Det: 0.1368 | W-NPS: 1.2102 | W-TV: 3.0842 | YOLO force: 2.029956 | NPS & TV force: 1.124238
# Step  144/480 | Batch Avg Det: 0.1695 | W-NPS: 1.1939 | W-TV: 3.0700 | YOLO force: 3.343195 | NPS & TV force: 1.121920
# Step  156/480 | Batch Avg Det: 0.0963 | W-NPS: 1.1880 | W-TV: 3.0708 | YOLO force: 2.798599 | NPS & TV force: 1.131173
# Step  168/480 | Batch Avg Det: 0.0841 | W-NPS: 1.1887 | W-TV: 3.0805 | YOLO force: 1.939380 | NPS & TV force: 1.142424
# Step  180/480 | Batch Avg Det: 0.1260 | W-NPS: 1.1896 | W-TV: 3.0936 | YOLO force: 4.178689 | NPS & TV force: 1.166147
# Step  192/480 | Batch Avg Det: 0.0998 | W-NPS: 1.2041 | W-TV: 3.1243 | YOLO force: 3.291133 | NPS & TV force: 1.181404
# Step  204/480 | Batch Avg Det: 0.1202 | W-NPS: 1.2152 | W-TV: 3.1573 | YOLO force: 1.843383 | NPS & TV force: 1.191582
# Step  216/480 | Batch Avg Det: 0.1429 | W-NPS: 1.2238 | W-TV: 3.1759 | YOLO force: 3.001406 | NPS & TV force: 1.196515
# Step  228/480 | Batch Avg Det: 0.0468 | W-NPS: 1.2330 | W-TV: 3.1922 | YOLO force: 2.085098 | NPS & TV force: 1.192028
# Step  240/480 | Batch Avg Det: 0.1022 | W-NPS: 1.2422 | W-TV: 3.2032 | YOLO force: 2.688365 | NPS & TV force: 1.201009
# Step  252/480 | Batch Avg Det: 0.1027 | W-NPS: 1.2497 | W-TV: 3.2089 | YOLO force: 0.535842 | NPS & TV force: 1.200581
# Step  264/480 | Batch Avg Det: 0.0928 | W-NPS: 1.2522 | W-TV: 3.1991 | YOLO force: 3.022891 | NPS & TV force: 1.182773
# Step  276/480 | Batch Avg Det: 0.1200 | W-NPS: 1.2496 | W-TV: 3.1949 | YOLO force: 1.150134 | NPS & TV force: 1.184224
# Step  288/480 | Batch Avg Det: 0.1540 | W-NPS: 1.2425 | W-TV: 3.1838 | YOLO force: 2.948894 | NPS & TV force: 1.195891
# Step  300/480 | Batch Avg Det: 0.0986 | W-NPS: 1.2312 | W-TV: 3.1660 | YOLO force: 1.250146 | NPS & TV force: 1.191079
# Step  312/480 | Batch Avg Det: 0.0761 | W-NPS: 1.2141 | W-TV: 3.1413 | YOLO force: 1.227534 | NPS & TV force: 1.175340
# Step  324/480 | Batch Avg Det: 0.1809 | W-NPS: 1.1914 | W-TV: 3.1099 | YOLO force: 2.117304 | NPS & TV force: 1.153480
# Step  336/480 | Batch Avg Det: 0.1088 | W-NPS: 1.1682 | W-TV: 3.0785 | YOLO force: 2.584662 | NPS & TV force: 1.152166
# Step  348/480 | Batch Avg Det: 0.1765 | W-NPS: 1.1494 | W-TV: 3.0475 | YOLO force: 2.843230 | NPS & TV force: 1.126718
# Step  360/480 | Batch Avg Det: 0.1237 | W-NPS: 1.1386 | W-TV: 3.0276 | YOLO force: 2.638241 | NPS & TV force: 1.121835
# Step  372/480 | Batch Avg Det: 0.1752 | W-NPS: 1.1400 | W-TV: 3.0165 | YOLO force: 2.114452 | NPS & TV force: 1.128276
# Step  384/480 | Batch Avg Det: 0.1116 | W-NPS: 1.1447 | W-TV: 3.0165 | YOLO force: 2.151804 | NPS & TV force: 1.136266
# Step  396/480 | Batch Avg Det: 0.1197 | W-NPS: 1.1464 | W-TV: 3.0163 | YOLO force: 2.055959 | NPS & TV force: 1.144637
# Step  408/480 | Batch Avg Det: 0.1209 | W-NPS: 1.1503 | W-TV: 3.0154 | YOLO force: 2.647750 | NPS & TV force: 1.145696
# Step  420/480 | Batch Avg Det: 0.0601 | W-NPS: 1.1533 | W-TV: 3.0140 | YOLO force: 2.244503 | NPS & TV force: 1.139734
# Step  432/480 | Batch Avg Det: 0.1615 | W-NPS: 1.1597 | W-TV: 3.0156 | YOLO force: 0.176907 | NPS & TV force: 1.148749
# Step  444/480 | Batch Avg Det: 0.1317 | W-NPS: 1.1600 | W-TV: 3.0058 | YOLO force: 0.682632 | NPS & TV force: 1.135170
# Step  456/480 | Batch Avg Det: 0.2122 | W-NPS: 1.1493 | W-TV: 2.9861 | YOLO force: 3.752298 | NPS & TV force: 1.140844
# Step  468/480 | Batch Avg Det: 0.0546 | W-NPS: 1.1338 | W-TV: 2.9637 | YOLO force: 2.110110 | NPS & TV force: 1.132307
# Step  480/480 | Batch Avg Det: 0.1024 | W-NPS: 1.1232 | W-TV: 2.9473 | YOLO force: 2.962187 | NPS & TV force: 1.134336
# >> EPOCH 3 SUMMARY | Train Det: 0.1302 | Val Det: 0.1163 | LR: 0.045273 <<
#
# --- Epoch 4/15 ---
# Step   12/480 | Batch Avg Det: 0.1878 | W-NPS: 1.1170 | W-TV: 2.9428 | YOLO force: 3.258253 | NPS & TV force: 1.127928
# Step   24/480 | Batch Avg Det: 0.1493 | W-NPS: 1.1227 | W-TV: 2.9433 | YOLO force: 3.789599 | NPS & TV force: 1.143799
# Step   36/480 | Batch Avg Det: 0.0959 | W-NPS: 1.1359 | W-TV: 2.9656 | YOLO force: 1.510589 | NPS & TV force: 1.159688
# Step   48/480 | Batch Avg Det: 0.1121 | W-NPS: 1.1496 | W-TV: 2.9893 | YOLO force: 2.108098 | NPS & TV force: 1.181033
# Step   60/480 | Batch Avg Det: 0.0737 | W-NPS: 1.1611 | W-TV: 3.0034 | YOLO force: 1.015460 | NPS & TV force: 1.182144
# Step   72/480 | Batch Avg Det: 0.0730 | W-NPS: 1.1614 | W-TV: 3.0048 | YOLO force: 3.070069 | NPS & TV force: 1.169494
# Step   84/480 | Batch Avg Det: 0.1861 | W-NPS: 1.1687 | W-TV: 2.9967 | YOLO force: 2.486382 | NPS & TV force: 1.167785
# Step   96/480 | Batch Avg Det: 0.0635 | W-NPS: 1.1802 | W-TV: 2.9901 | YOLO force: 1.373347 | NPS & TV force: 1.174770
# Step  108/480 | Batch Avg Det: 0.2005 | W-NPS: 1.1809 | W-TV: 2.9804 | YOLO force: 2.666996 | NPS & TV force: 1.159642
# Step  120/480 | Batch Avg Det: 0.1753 | W-NPS: 1.1786 | W-TV: 2.9705 | YOLO force: 1.693426 | NPS & TV force: 1.157558
# Step  132/480 | Batch Avg Det: 0.2370 | W-NPS: 1.1666 | W-TV: 2.9571 | YOLO force: 2.600414 | NPS & TV force: 1.157817
# Step  144/480 | Batch Avg Det: 0.0855 | W-NPS: 1.1505 | W-TV: 2.9472 | YOLO force: 0.965597 | NPS & TV force: 1.161341
# Step  156/480 | Batch Avg Det: 0.2012 | W-NPS: 1.1306 | W-TV: 2.9314 | YOLO force: 1.747378 | NPS & TV force: 1.158231
# Step  168/480 | Batch Avg Det: 0.0365 | W-NPS: 1.1161 | W-TV: 2.9118 | YOLO force: 0.798740 | NPS & TV force: 1.141613
# Step  180/480 | Batch Avg Det: 0.1211 | W-NPS: 1.0990 | W-TV: 2.8892 | YOLO force: 0.226661 | NPS & TV force: 1.111888
# Step  192/480 | Batch Avg Det: 0.2706 | W-NPS: 1.0765 | W-TV: 2.8621 | YOLO force: 4.153647 | NPS & TV force: 1.093509
# Step  204/480 | Batch Avg Det: 0.2003 | W-NPS: 1.0620 | W-TV: 2.8577 | YOLO force: 3.987460 | NPS & TV force: 1.112963
# Step  216/480 | Batch Avg Det: 0.1268 | W-NPS: 1.0616 | W-TV: 2.8732 | YOLO force: 1.510058 | NPS & TV force: 1.145182
# Step  228/480 | Batch Avg Det: 0.0844 | W-NPS: 1.0732 | W-TV: 2.8903 | YOLO force: 2.031916 | NPS & TV force: 1.156387
# Step  240/480 | Batch Avg Det: 0.0927 | W-NPS: 1.0899 | W-TV: 2.9039 | YOLO force: 1.631078 | NPS & TV force: 1.150774
# Step  252/480 | Batch Avg Det: 0.1719 | W-NPS: 1.1041 | W-TV: 2.9154 | YOLO force: 1.142190 | NPS & TV force: 1.150592
# Step  264/480 | Batch Avg Det: 0.1545 | W-NPS: 1.1138 | W-TV: 2.9168 | YOLO force: 2.180478 | NPS & TV force: 1.157957
# Step  276/480 | Batch Avg Det: 0.0850 | W-NPS: 1.1142 | W-TV: 2.9088 | YOLO force: 3.379223 | NPS & TV force: 1.154503
# Step  288/480 | Batch Avg Det: 0.0702 | W-NPS: 1.1089 | W-TV: 2.8986 | YOLO force: 2.510201 | NPS & TV force: 1.155929
# Step  300/480 | Batch Avg Det: 0.0660 | W-NPS: 1.1056 | W-TV: 2.8987 | YOLO force: 0.670249 | NPS & TV force: 1.160473
# Step  312/480 | Batch Avg Det: 0.1165 | W-NPS: 1.1020 | W-TV: 2.8943 | YOLO force: 1.991684 | NPS & TV force: 1.159200
# Step  324/480 | Batch Avg Det: 0.1388 | W-NPS: 1.0942 | W-TV: 2.8934 | YOLO force: 2.022962 | NPS & TV force: 1.163188
# Step  336/480 | Batch Avg Det: 0.2040 | W-NPS: 1.0868 | W-TV: 2.8940 | YOLO force: 2.818521 | NPS & TV force: 1.165853
# Step  348/480 | Batch Avg Det: 0.1762 | W-NPS: 1.0836 | W-TV: 2.8956 | YOLO force: 2.268722 | NPS & TV force: 1.177943
# Step  360/480 | Batch Avg Det: 0.1995 | W-NPS: 1.0815 | W-TV: 2.8960 | YOLO force: 3.782173 | NPS & TV force: 1.167285
# Step  372/480 | Batch Avg Det: 0.1008 | W-NPS: 1.0836 | W-TV: 2.8961 | YOLO force: 2.655806 | NPS & TV force: 1.167881
# Step  384/480 | Batch Avg Det: 0.1256 | W-NPS: 1.0911 | W-TV: 2.9020 | YOLO force: 1.677004 | NPS & TV force: 1.173578
# Step  396/480 | Batch Avg Det: 0.0963 | W-NPS: 1.0968 | W-TV: 2.9084 | YOLO force: 1.873324 | NPS & TV force: 1.159398
# Step  408/480 | Batch Avg Det: 0.0834 | W-NPS: 1.0961 | W-TV: 2.9099 | YOLO force: 2.026794 | NPS & TV force: 1.156013
# Step  420/480 | Batch Avg Det: 0.0681 | W-NPS: 1.0937 | W-TV: 2.9026 | YOLO force: 1.820622 | NPS & TV force: 1.156561
# Step  432/480 | Batch Avg Det: 0.1312 | W-NPS: 1.0792 | W-TV: 2.8859 | YOLO force: 2.105531 | NPS & TV force: 1.157068
# Step  444/480 | Batch Avg Det: 0.0853 | W-NPS: 1.0655 | W-TV: 2.8702 | YOLO force: 2.104881 | NPS & TV force: 1.148883
# Step  456/480 | Batch Avg Det: 0.1925 | W-NPS: 1.0545 | W-TV: 2.8535 | YOLO force: 2.663815 | NPS & TV force: 1.140383
# Step  468/480 | Batch Avg Det: 0.1679 | W-NPS: 1.0482 | W-TV: 2.8438 | YOLO force: 2.754184 | NPS & TV force: 1.133032
# Step  480/480 | Batch Avg Det: 0.1089 | W-NPS: 1.0489 | W-TV: 2.8398 | YOLO force: 2.134537 | NPS & TV force: 1.140337
# >> EPOCH 4 SUMMARY | Train Det: 0.1329 | Val Det: 0.1100 | LR: 0.041811 <<
#
# --- Epoch 5/15 ---
# Step   12/480 | Batch Avg Det: 0.1317 | W-NPS: 1.0460 | W-TV: 2.8308 | YOLO force: 1.598102 | NPS & TV force: 1.141727
# Step   24/480 | Batch Avg Det: 0.1657 | W-NPS: 1.0427 | W-TV: 2.8189 | YOLO force: 2.301204 | NPS & TV force: 1.129813
# Step   36/480 | Batch Avg Det: 0.1020 | W-NPS: 1.0321 | W-TV: 2.8107 | YOLO force: 2.807440 | NPS & TV force: 1.130981
# Step   48/480 | Batch Avg Det: 0.0325 | W-NPS: 1.0235 | W-TV: 2.8140 | YOLO force: 0.343067 | NPS & TV force: 1.146490
# Step   60/480 | Batch Avg Det: 0.1530 | W-NPS: 1.0130 | W-TV: 2.8096 | YOLO force: 1.149969 | NPS & TV force: 1.144070
# Step   72/480 | Batch Avg Det: 0.1088 | W-NPS: 0.9959 | W-TV: 2.7961 | YOLO force: 3.838344 | NPS & TV force: 1.135918
# Step   84/480 | Batch Avg Det: 0.1523 | W-NPS: 0.9776 | W-TV: 2.7836 | YOLO force: 1.376855 | NPS & TV force: 1.120676
# Step   96/480 | Batch Avg Det: 0.1310 | W-NPS: 0.9693 | W-TV: 2.7727 | YOLO force: 3.698435 | NPS & TV force: 1.116299
# Step  108/480 | Batch Avg Det: 0.1726 | W-NPS: 0.9786 | W-TV: 2.7706 | YOLO force: 2.748924 | NPS & TV force: 1.116431
# Step  120/480 | Batch Avg Det: 0.2604 | W-NPS: 0.9900 | W-TV: 2.7704 | YOLO force: 2.044164 | NPS & TV force: 1.124305
# Step  132/480 | Batch Avg Det: 0.1368 | W-NPS: 1.0034 | W-TV: 2.7687 | YOLO force: 1.777720 | NPS & TV force: 1.119253
# Step  144/480 | Batch Avg Det: 0.0689 | W-NPS: 1.0155 | W-TV: 2.7676 | YOLO force: 3.352021 | NPS & TV force: 1.120041
# Step  156/480 | Batch Avg Det: 0.1080 | W-NPS: 1.0310 | W-TV: 2.7653 | YOLO force: 2.100307 | NPS & TV force: 1.125434
# Step  168/480 | Batch Avg Det: 0.0697 | W-NPS: 1.0451 | W-TV: 2.7567 | YOLO force: 0.906939 | NPS & TV force: 1.124545
# Step  180/480 | Batch Avg Det: 0.2089 | W-NPS: 1.0552 | W-TV: 2.7476 | YOLO force: 2.932704 | NPS & TV force: 1.112666
# Step  192/480 | Batch Avg Det: 0.1071 | W-NPS: 1.0643 | W-TV: 2.7380 | YOLO force: 2.705942 | NPS & TV force: 1.117112
# Step  204/480 | Batch Avg Det: 0.1100 | W-NPS: 1.0768 | W-TV: 2.7357 | YOLO force: 3.601414 | NPS & TV force: 1.134584
# Step  216/480 | Batch Avg Det: 0.0587 | W-NPS: 1.0891 | W-TV: 2.7464 | YOLO force: 2.332981 | NPS & TV force: 1.145844
# Step  228/480 | Batch Avg Det: 0.0654 | W-NPS: 1.0978 | W-TV: 2.7544 | YOLO force: 1.206354 | NPS & TV force: 1.146419
# Step  240/480 | Batch Avg Det: 0.1553 | W-NPS: 1.1022 | W-TV: 2.7607 | YOLO force: 3.753552 | NPS & TV force: 1.139573
# Step  252/480 | Batch Avg Det: 0.0780 | W-NPS: 1.1117 | W-TV: 2.7799 | YOLO force: 2.203987 | NPS & TV force: 1.132589
# Step  264/480 | Batch Avg Det: 0.0795 | W-NPS: 1.1230 | W-TV: 2.8024 | YOLO force: 2.229246 | NPS & TV force: 1.150756
# Step  276/480 | Batch Avg Det: 0.0472 | W-NPS: 1.1317 | W-TV: 2.8280 | YOLO force: 0.084384 | NPS & TV force: 1.154045
# Step  288/480 | Batch Avg Det: 0.2770 | W-NPS: 1.1330 | W-TV: 2.8443 | YOLO force: 1.984771 | NPS & TV force: 1.170755
# Step  300/480 | Batch Avg Det: 0.1675 | W-NPS: 1.1290 | W-TV: 2.8542 | YOLO force: 2.739207 | NPS & TV force: 1.164996
# Step  312/480 | Batch Avg Det: 0.1758 | W-NPS: 1.1239 | W-TV: 2.8596 | YOLO force: 2.995221 | NPS & TV force: 1.152147
# Step  324/480 | Batch Avg Det: 0.1191 | W-NPS: 1.1162 | W-TV: 2.8560 | YOLO force: 3.255238 | NPS & TV force: 1.139491
# Step  336/480 | Batch Avg Det: 0.0801 | W-NPS: 1.1147 | W-TV: 2.8533 | YOLO force: 1.468440 | NPS & TV force: 1.138641
# Step  348/480 | Batch Avg Det: 0.0989 | W-NPS: 1.1186 | W-TV: 2.8472 | YOLO force: 2.769541 | NPS & TV force: 1.132257
# Step  360/480 | Batch Avg Det: 0.1259 | W-NPS: 1.1211 | W-TV: 2.8430 | YOLO force: 2.028509 | NPS & TV force: 1.151101
# Step  372/480 | Batch Avg Det: 0.1055 | W-NPS: 1.1205 | W-TV: 2.8378 | YOLO force: 2.160430 | NPS & TV force: 1.159231
# Step  384/480 | Batch Avg Det: 0.1479 | W-NPS: 1.1169 | W-TV: 2.8236 | YOLO force: 1.485754 | NPS & TV force: 1.154522
# Step  396/480 | Batch Avg Det: 0.0866 | W-NPS: 1.1129 | W-TV: 2.8071 | YOLO force: 2.693948 | NPS & TV force: 1.158466
# Step  408/480 | Batch Avg Det: 0.2308 | W-NPS: 1.1070 | W-TV: 2.7877 | YOLO force: 1.870633 | NPS & TV force: 1.152734
# Step  420/480 | Batch Avg Det: 0.1145 | W-NPS: 1.0985 | W-TV: 2.7728 | YOLO force: 3.327245 | NPS & TV force: 1.133537
# Step  432/480 | Batch Avg Det: 0.0345 | W-NPS: 1.0938 | W-TV: 2.7659 | YOLO force: 1.799300 | NPS & TV force: 1.134547
# Step  444/480 | Batch Avg Det: 0.1998 | W-NPS: 1.0882 | W-TV: 2.7582 | YOLO force: 1.552452 | NPS & TV force: 1.125391
# Step  456/480 | Batch Avg Det: 0.1379 | W-NPS: 1.0837 | W-TV: 2.7496 | YOLO force: 3.751891 | NPS & TV force: 1.123966
# Step  468/480 | Batch Avg Det: 0.1572 | W-NPS: 1.0818 | W-TV: 2.7552 | YOLO force: 2.103469 | NPS & TV force: 1.149688
# Step  480/480 | Batch Avg Det: 0.1194 | W-NPS: 1.0836 | W-TV: 2.7671 | YOLO force: 2.487053 | NPS & TV force: 1.169040
# >> EPOCH 5 SUMMARY | Train Det: 0.1270 | Val Det: 0.1062 | LR: 0.037625 <<
#
# --- Epoch 6/15 ---
# Step   12/480 | Batch Avg Det: 0.0947 | W-NPS: 1.0972 | W-TV: 2.7851 | YOLO force: 2.109478 | NPS & TV force: 1.173233
# Step   24/480 | Batch Avg Det: 0.0309 | W-NPS: 1.1103 | W-TV: 2.7965 | YOLO force: 0.508340 | NPS & TV force: 1.168357
# Step   36/480 | Batch Avg Det: 0.1040 | W-NPS: 1.1164 | W-TV: 2.7988 | YOLO force: 2.235342 | NPS & TV force: 1.171884
# Step   48/480 | Batch Avg Det: 0.0891 | W-NPS: 1.1134 | W-TV: 2.7949 | YOLO force: 1.165943 | NPS & TV force: 1.166485
# Step   60/480 | Batch Avg Det: 0.0882 | W-NPS: 1.1008 | W-TV: 2.7864 | YOLO force: 1.985351 | NPS & TV force: 1.162200
# Step   72/480 | Batch Avg Det: 0.1209 | W-NPS: 1.0809 | W-TV: 2.7739 | YOLO force: 3.546072 | NPS & TV force: 1.154517
# Step   84/480 | Batch Avg Det: 0.0738 | W-NPS: 1.0668 | W-TV: 2.7776 | YOLO force: 2.631883 | NPS & TV force: 1.165478
# Step   96/480 | Batch Avg Det: 0.1435 | W-NPS: 1.0576 | W-TV: 2.7855 | YOLO force: 0.275637 | NPS & TV force: 1.169049
# Step  108/480 | Batch Avg Det: 0.1620 | W-NPS: 1.0465 | W-TV: 2.7857 | YOLO force: 2.979881 | NPS & TV force: 1.168372
# Step  120/480 | Batch Avg Det: 0.1415 | W-NPS: 1.0269 | W-TV: 2.7764 | YOLO force: 2.066042 | NPS & TV force: 1.167334
# Step  132/480 | Batch Avg Det: 0.1539 | W-NPS: 1.0129 | W-TV: 2.7731 | YOLO force: 2.763513 | NPS & TV force: 1.161039
# Step  144/480 | Batch Avg Det: 0.0422 | W-NPS: 1.0050 | W-TV: 2.7674 | YOLO force: 0.054514 | NPS & TV force: 1.160771
# Step  156/480 | Batch Avg Det: 0.1428 | W-NPS: 0.9980 | W-TV: 2.7547 | YOLO force: 2.331494 | NPS & TV force: 1.160631
# Step  168/480 | Batch Avg Det: 0.0827 | W-NPS: 0.9890 | W-TV: 2.7391 | YOLO force: 2.757612 | NPS & TV force: 1.144310
# Step  180/480 | Batch Avg Det: 0.1766 | W-NPS: 0.9804 | W-TV: 2.7257 | YOLO force: 2.577134 | NPS & TV force: 1.139005
# Step  192/480 | Batch Avg Det: 0.1136 | W-NPS: 0.9724 | W-TV: 2.7206 | YOLO force: 2.597409 | NPS & TV force: 1.141212
# Step  204/480 | Batch Avg Det: 0.2594 | W-NPS: 0.9703 | W-TV: 2.7132 | YOLO force: 2.707197 | NPS & TV force: 1.135446
# Step  216/480 | Batch Avg Det: 0.0843 | W-NPS: 0.9659 | W-TV: 2.7132 | YOLO force: 1.728407 | NPS & TV force: 1.134012
# Step  228/480 | Batch Avg Det: 0.0813 | W-NPS: 0.9571 | W-TV: 2.7125 | YOLO force: 0.856314 | NPS & TV force: 1.138995
# Step  240/480 | Batch Avg Det: 0.1531 | W-NPS: 0.9443 | W-TV: 2.7117 | YOLO force: 3.336104 | NPS & TV force: 1.149314
# Step  252/480 | Batch Avg Det: 0.0575 | W-NPS: 0.9367 | W-TV: 2.7077 | YOLO force: 0.421425 | NPS & TV force: 1.153047
# Step  264/480 | Batch Avg Det: 0.0945 | W-NPS: 0.9270 | W-TV: 2.7007 | YOLO force: 3.443973 | NPS & TV force: 1.149854
# Step  276/480 | Batch Avg Det: 0.0451 | W-NPS: 0.9227 | W-TV: 2.6956 | YOLO force: 2.032935 | NPS & TV force: 1.158128
# Step  288/480 | Batch Avg Det: 0.0835 | W-NPS: 0.9193 | W-TV: 2.6934 | YOLO force: 0.377991 | NPS & TV force: 1.160291
# Step  300/480 | Batch Avg Det: 0.0976 | W-NPS: 0.9155 | W-TV: 2.6873 | YOLO force: 1.565150 | NPS & TV force: 1.145773
# Step  312/480 | Batch Avg Det: 0.2244 | W-NPS: 0.9121 | W-TV: 2.6749 | YOLO force: 2.436121 | NPS & TV force: 1.142304
# Step  324/480 | Batch Avg Det: 0.1092 | W-NPS: 0.9058 | W-TV: 2.6675 | YOLO force: 0.976631 | NPS & TV force: 1.132013
# Step  336/480 | Batch Avg Det: 0.1910 | W-NPS: 0.8957 | W-TV: 2.6579 | YOLO force: 2.982943 | NPS & TV force: 1.125442
# Step  348/480 | Batch Avg Det: 0.0782 | W-NPS: 0.8910 | W-TV: 2.6535 | YOLO force: 1.795602 | NPS & TV force: 1.129101
# Step  360/480 | Batch Avg Det: 0.0769 | W-NPS: 0.8856 | W-TV: 2.6499 | YOLO force: 2.693443 | NPS & TV force: 1.121747
# Step  372/480 | Batch Avg Det: 0.2421 | W-NPS: 0.8774 | W-TV: 2.6460 | YOLO force: 2.741941 | NPS & TV force: 1.119201
# Step  384/480 | Batch Avg Det: 0.1603 | W-NPS: 0.8811 | W-TV: 2.6487 | YOLO force: 1.899284 | NPS & TV force: 1.127838
# Step  396/480 | Batch Avg Det: 0.0312 | W-NPS: 0.8860 | W-TV: 2.6529 | YOLO force: 1.264106 | NPS & TV force: 1.131754
# Step  408/480 | Batch Avg Det: 0.1509 | W-NPS: 0.8877 | W-TV: 2.6562 | YOLO force: 2.343282 | NPS & TV force: 1.131397
# Step  420/480 | Batch Avg Det: 0.1296 | W-NPS: 0.8844 | W-TV: 2.6559 | YOLO force: 3.297329 | NPS & TV force: 1.133531
# Step  432/480 | Batch Avg Det: 0.1100 | W-NPS: 0.8838 | W-TV: 2.6536 | YOLO force: 2.464581 | NPS & TV force: 1.125200
# Step  444/480 | Batch Avg Det: 0.1231 | W-NPS: 0.8855 | W-TV: 2.6569 | YOLO force: 3.801966 | NPS & TV force: 1.117538
# Step  456/480 | Batch Avg Det: 0.1535 | W-NPS: 0.8943 | W-TV: 2.6724 | YOLO force: 2.598597 | NPS & TV force: 1.129347
# Step  468/480 | Batch Avg Det: 0.2040 | W-NPS: 0.9071 | W-TV: 2.6900 | YOLO force: 2.206066 | NPS & TV force: 1.143876
# Step  480/480 | Batch Avg Det: 0.1449 | W-NPS: 0.9213 | W-TV: 2.7061 | YOLO force: 2.082015 | NPS & TV force: 1.153823
# >> EPOCH 6 SUMMARY | Train Det: 0.1212 | Val Det: 0.1116 | LR: 0.032898 <<
#
# --- Epoch 7/15 ---
# Step   12/480 | Batch Avg Det: 0.1088 | W-NPS: 0.9350 | W-TV: 2.7274 | YOLO force: 5.467487 | NPS & TV force: 1.173037
# Step   24/480 | Batch Avg Det: 0.0267 | W-NPS: 0.9657 | W-TV: 2.7578 | YOLO force: 1.979493 | NPS & TV force: 1.178154
# Step   36/480 | Batch Avg Det: 0.1106 | W-NPS: 1.0036 | W-TV: 2.7876 | YOLO force: 1.606218 | NPS & TV force: 1.193174
# Step   48/480 | Batch Avg Det: 0.0934 | W-NPS: 1.0397 | W-TV: 2.8079 | YOLO force: 2.006277 | NPS & TV force: 1.191058
# Step   60/480 | Batch Avg Det: 0.0967 | W-NPS: 1.0686 | W-TV: 2.8275 | YOLO force: 1.792476 | NPS & TV force: 1.206823
# Step   72/480 | Batch Avg Det: 0.0838 | W-NPS: 1.0869 | W-TV: 2.8386 | YOLO force: 3.254767 | NPS & TV force: 1.212663
# Step   84/480 | Batch Avg Det: 0.0584 | W-NPS: 1.0997 | W-TV: 2.8433 | YOLO force: 0.268413 | NPS & TV force: 1.210918
# Step   96/480 | Batch Avg Det: 0.0794 | W-NPS: 1.1034 | W-TV: 2.8415 | YOLO force: 0.731327 | NPS & TV force: 1.218069
# Step  108/480 | Batch Avg Det: 0.2310 | W-NPS: 1.0990 | W-TV: 2.8267 | YOLO force: 1.931026 | NPS & TV force: 1.211290
# Step  120/480 | Batch Avg Det: 0.1310 | W-NPS: 1.0866 | W-TV: 2.8091 | YOLO force: 2.560002 | NPS & TV force: 1.196467
# Step  132/480 | Batch Avg Det: 0.1296 | W-NPS: 1.0681 | W-TV: 2.7862 | YOLO force: 2.277148 | NPS & TV force: 1.180907
# Step  144/480 | Batch Avg Det: 0.1219 | W-NPS: 1.0417 | W-TV: 2.7635 | YOLO force: 0.116156 | NPS & TV force: 1.167814
# Step  156/480 | Batch Avg Det: 0.0398 | W-NPS: 1.0106 | W-TV: 2.7361 | YOLO force: 1.540836 | NPS & TV force: 1.153989
# Step  168/480 | Batch Avg Det: 0.1401 | W-NPS: 0.9800 | W-TV: 2.7043 | YOLO force: 0.630607 | NPS & TV force: 1.140597
# Step  180/480 | Batch Avg Det: 0.1641 | W-NPS: 0.9517 | W-TV: 2.6711 | YOLO force: 1.239907 | NPS & TV force: 1.123419
# Step  192/480 | Batch Avg Det: 0.1494 | W-NPS: 0.9240 | W-TV: 2.6386 | YOLO force: 2.158955 | NPS & TV force: 1.101868
# Step  204/480 | Batch Avg Det: 0.0810 | W-NPS: 0.8966 | W-TV: 2.6096 | YOLO force: 3.577858 | NPS & TV force: 1.073722
# Step  216/480 | Batch Avg Det: 0.1047 | W-NPS: 0.8727 | W-TV: 2.5983 | YOLO force: 0.839560 | NPS & TV force: 1.090912
# Step  228/480 | Batch Avg Det: 0.0447 | W-NPS: 0.8561 | W-TV: 2.5880 | YOLO force: 0.389676 | NPS & TV force: 1.101220
# Step  240/480 | Batch Avg Det: 0.0527 | W-NPS: 0.8412 | W-TV: 2.5772 | YOLO force: 0.870197 | NPS & TV force: 1.105981
# Step  252/480 | Batch Avg Det: 0.0502 | W-NPS: 0.8277 | W-TV: 2.5663 | YOLO force: 1.998009 | NPS & TV force: 1.099118
# Step  264/480 | Batch Avg Det: 0.0758 | W-NPS: 0.8201 | W-TV: 2.5590 | YOLO force: 1.424780 | NPS & TV force: 1.095145
# Step  276/480 | Batch Avg Det: 0.2655 | W-NPS: 0.8108 | W-TV: 2.5498 | YOLO force: 3.139158 | NPS & TV force: 1.080596
# Step  288/480 | Batch Avg Det: 0.0767 | W-NPS: 0.8041 | W-TV: 2.5476 | YOLO force: 2.188012 | NPS & TV force: 1.054031
# Step  300/480 | Batch Avg Det: 0.1546 | W-NPS: 0.8000 | W-TV: 2.5543 | YOLO force: 2.248833 | NPS & TV force: 1.063482
# Step  312/480 | Batch Avg Det: 0.1588 | W-NPS: 0.7967 | W-TV: 2.5686 | YOLO force: 0.532357 | NPS & TV force: 1.073563
# Step  324/480 | Batch Avg Det: 0.0622 | W-NPS: 0.7917 | W-TV: 2.5786 | YOLO force: 3.750932 | NPS & TV force: 1.090082
# Step  336/480 | Batch Avg Det: 0.1835 | W-NPS: 0.7848 | W-TV: 2.5955 | YOLO force: 3.357239 | NPS & TV force: 1.107491
# Step  348/480 | Batch Avg Det: 0.1762 | W-NPS: 0.7872 | W-TV: 2.6199 | YOLO force: 3.239316 | NPS & TV force: 1.132649
# Step  360/480 | Batch Avg Det: 0.1219 | W-NPS: 0.7967 | W-TV: 2.6445 | YOLO force: 1.876932 | NPS & TV force: 1.141167
# Step  372/480 | Batch Avg Det: 0.1666 | W-NPS: 0.8064 | W-TV: 2.6715 | YOLO force: 1.738649 | NPS & TV force: 1.147240
# Step  384/480 | Batch Avg Det: 0.0814 | W-NPS: 0.8160 | W-TV: 2.6934 | YOLO force: 0.220706 | NPS & TV force: 1.156348
# Step  396/480 | Batch Avg Det: 0.1402 | W-NPS: 0.8188 | W-TV: 2.7062 | YOLO force: 2.331439 | NPS & TV force: 1.170406
# Step  408/480 | Batch Avg Det: 0.1208 | W-NPS: 0.8155 | W-TV: 2.7092 | YOLO force: 3.054511 | NPS & TV force: 1.163594
# Step  420/480 | Batch Avg Det: 0.1221 | W-NPS: 0.8134 | W-TV: 2.7088 | YOLO force: 2.255405 | NPS & TV force: 1.168328
# Step  432/480 | Batch Avg Det: 0.2215 | W-NPS: 0.8169 | W-TV: 2.7090 | YOLO force: 2.585605 | NPS & TV force: 1.166470
# Step  444/480 | Batch Avg Det: 0.1286 | W-NPS: 0.8200 | W-TV: 2.7068 | YOLO force: 1.728054 | NPS & TV force: 1.153231
# Step  456/480 | Batch Avg Det: 0.1161 | W-NPS: 0.8220 | W-TV: 2.7035 | YOLO force: 3.088573 | NPS & TV force: 1.146712
# Step  468/480 | Batch Avg Det: 0.2739 | W-NPS: 0.8300 | W-TV: 2.7087 | YOLO force: 0.888844 | NPS & TV force: 1.172065
# Step  480/480 | Batch Avg Det: 0.1492 | W-NPS: 0.8361 | W-TV: 2.7107 | YOLO force: 2.133636 | NPS & TV force: 1.168474
# >> EPOCH 7 SUMMARY | Train Det: 0.1223 | Val Det: 0.1054 | LR: 0.027837 <<
#
# --- Epoch 8/15 ---
# Step   12/480 | Batch Avg Det: 0.1012 | W-NPS: 0.8374 | W-TV: 2.7126 | YOLO force: 1.393435 | NPS & TV force: 1.181227
# Step   24/480 | Batch Avg Det: 0.2291 | W-NPS: 0.8350 | W-TV: 2.7119 | YOLO force: 3.405309 | NPS & TV force: 1.188859
# Step   36/480 | Batch Avg Det: 0.1484 | W-NPS: 0.8367 | W-TV: 2.7124 | YOLO force: 0.686073 | NPS & TV force: 1.194156
# Step   48/480 | Batch Avg Det: 0.0289 | W-NPS: 0.8370 | W-TV: 2.7100 | YOLO force: 0.106860 | NPS & TV force: 1.185879
# Step   60/480 | Batch Avg Det: 0.1210 | W-NPS: 0.8304 | W-TV: 2.6983 | YOLO force: 2.729719 | NPS & TV force: 1.177989
# Step   72/480 | Batch Avg Det: 0.0440 | W-NPS: 0.8176 | W-TV: 2.6860 | YOLO force: 1.195238 | NPS & TV force: 1.168705
# Step   84/480 | Batch Avg Det: 0.0978 | W-NPS: 0.8019 | W-TV: 2.6692 | YOLO force: 0.886014 | NPS & TV force: 1.155763
# Step   96/480 | Batch Avg Det: 0.0699 | W-NPS: 0.7823 | W-TV: 2.6491 | YOLO force: 1.344980 | NPS & TV force: 1.134750
# Step  108/480 | Batch Avg Det: 0.0495 | W-NPS: 0.7608 | W-TV: 2.6272 | YOLO force: 0.731364 | NPS & TV force: 1.108222
# Step  120/480 | Batch Avg Det: 0.0653 | W-NPS: 0.7391 | W-TV: 2.6039 | YOLO force: 1.514645 | NPS & TV force: 1.087863
# Step  132/480 | Batch Avg Det: 0.0956 | W-NPS: 0.7194 | W-TV: 2.5796 | YOLO force: 2.982189 | NPS & TV force: 1.072894
# Step  144/480 | Batch Avg Det: 0.1208 | W-NPS: 0.7099 | W-TV: 2.5616 | YOLO force: 1.125586 | NPS & TV force: 1.065216
# Step  156/480 | Batch Avg Det: 0.2024 | W-NPS: 0.7008 | W-TV: 2.5458 | YOLO force: 3.752781 | NPS & TV force: 1.055440
# Step  168/480 | Batch Avg Det: 0.1834 | W-NPS: 0.6975 | W-TV: 2.5469 | YOLO force: 1.946665 | NPS & TV force: 1.062569
# Step  180/480 | Batch Avg Det: 0.1679 | W-NPS: 0.6972 | W-TV: 2.5520 | YOLO force: 1.036181 | NPS & TV force: 1.059667
# Step  192/480 | Batch Avg Det: 0.0879 | W-NPS: 0.6993 | W-TV: 2.5573 | YOLO force: 1.596015 | NPS & TV force: 1.062017
# Step  204/480 | Batch Avg Det: 0.1938 | W-NPS: 0.7015 | W-TV: 2.5592 | YOLO force: 0.581802 | NPS & TV force: 1.071316
# Step  216/480 | Batch Avg Det: 0.1015 | W-NPS: 0.6989 | W-TV: 2.5553 | YOLO force: 2.676785 | NPS & TV force: 1.072112
# Step  228/480 | Batch Avg Det: 0.1271 | W-NPS: 0.6945 | W-TV: 2.5485 | YOLO force: 3.112551 | NPS & TV force: 1.063197
# Step  240/480 | Batch Avg Det: 0.0718 | W-NPS: 0.6884 | W-TV: 2.5411 | YOLO force: 0.492183 | NPS & TV force: 1.053821
# Step  252/480 | Batch Avg Det: 0.0864 | W-NPS: 0.6834 | W-TV: 2.5357 | YOLO force: 2.846003 | NPS & TV force: 1.062555
# Step  264/480 | Batch Avg Det: 0.0931 | W-NPS: 0.6779 | W-TV: 2.5269 | YOLO force: 3.456561 | NPS & TV force: 1.060860
# Step  276/480 | Batch Avg Det: 0.0898 | W-NPS: 0.6759 | W-TV: 2.5262 | YOLO force: 0.415341 | NPS & TV force: 1.068390
# Step  288/480 | Batch Avg Det: 0.1453 | W-NPS: 0.6767 | W-TV: 2.5227 | YOLO force: 3.449791 | NPS & TV force: 1.067707
# Step  300/480 | Batch Avg Det: 0.1105 | W-NPS: 0.6800 | W-TV: 2.5284 | YOLO force: 2.099659 | NPS & TV force: 1.081064
# Step  312/480 | Batch Avg Det: 0.0978 | W-NPS: 0.6836 | W-TV: 2.5355 | YOLO force: 0.649424 | NPS & TV force: 1.091702
# Step  324/480 | Batch Avg Det: 0.1812 | W-NPS: 0.6872 | W-TV: 2.5422 | YOLO force: 2.024959 | NPS & TV force: 1.087705
# Step  336/480 | Batch Avg Det: 0.1803 | W-NPS: 0.6890 | W-TV: 2.5470 | YOLO force: 2.826186 | NPS & TV force: 1.100873
# Step  348/480 | Batch Avg Det: 0.1189 | W-NPS: 0.6893 | W-TV: 2.5543 | YOLO force: 1.847343 | NPS & TV force: 1.105370
# Step  360/480 | Batch Avg Det: 0.0752 | W-NPS: 0.6896 | W-TV: 2.5598 | YOLO force: 1.792776 | NPS & TV force: 1.094482
# Step  372/480 | Batch Avg Det: 0.1885 | W-NPS: 0.6865 | W-TV: 2.5617 | YOLO force: 3.795070 | NPS & TV force: 1.110863
# Step  384/480 | Batch Avg Det: 0.0888 | W-NPS: 0.6848 | W-TV: 2.5690 | YOLO force: 1.653805 | NPS & TV force: 1.134594
# Step  396/480 | Batch Avg Det: 0.1005 | W-NPS: 0.6837 | W-TV: 2.5753 | YOLO force: 3.028504 | NPS & TV force: 1.134432
# Step  408/480 | Batch Avg Det: 0.1134 | W-NPS: 0.6817 | W-TV: 2.5840 | YOLO force: 2.156891 | NPS & TV force: 1.137002
# Step  420/480 | Batch Avg Det: 0.1251 | W-NPS: 0.6808 | W-TV: 2.5964 | YOLO force: 1.719776 | NPS & TV force: 1.138029
# Step  432/480 | Batch Avg Det: 0.1738 | W-NPS: 0.6796 | W-TV: 2.6114 | YOLO force: 2.539038 | NPS & TV force: 1.150413
# Step  444/480 | Batch Avg Det: 0.1594 | W-NPS: 0.6802 | W-TV: 2.6245 | YOLO force: 2.159108 | NPS & TV force: 1.150595
# Step  456/480 | Batch Avg Det: 0.1589 | W-NPS: 0.6814 | W-TV: 2.6301 | YOLO force: 2.270267 | NPS & TV force: 1.150079
# Step  468/480 | Batch Avg Det: 0.1535 | W-NPS: 0.6831 | W-TV: 2.6332 | YOLO force: 3.357152 | NPS & TV force: 1.146306
# Step  480/480 | Batch Avg Det: 0.0454 | W-NPS: 0.6896 | W-TV: 2.6404 | YOLO force: 0.899112 | NPS & TV force: 1.150314
# >> EPOCH 8 SUMMARY | Train Det: 0.1198 | Val Det: 0.1015 | LR: 0.022663 <<
#
# --- Epoch 9/15 ---
# Step   12/480 | Batch Avg Det: 0.1793 | W-NPS: 0.6974 | W-TV: 2.6437 | YOLO force: 3.494792 | NPS & TV force: 1.144930
# Step   24/480 | Batch Avg Det: 0.1242 | W-NPS: 0.7097 | W-TV: 2.6539 | YOLO force: 3.259645 | NPS & TV force: 1.148199
# Step   36/480 | Batch Avg Det: 0.1474 | W-NPS: 0.7227 | W-TV: 2.6677 | YOLO force: 0.719066 | NPS & TV force: 1.171468
# Step   48/480 | Batch Avg Det: 0.0664 | W-NPS: 0.7296 | W-TV: 2.6776 | YOLO force: 2.170766 | NPS & TV force: 1.172948
# Step   60/480 | Batch Avg Det: 0.0551 | W-NPS: 0.7327 | W-TV: 2.6812 | YOLO force: 1.650366 | NPS & TV force: 1.175034
# Step   72/480 | Batch Avg Det: 0.1949 | W-NPS: 0.7341 | W-TV: 2.6813 | YOLO force: 1.017093 | NPS & TV force: 1.177491
# Step   84/480 | Batch Avg Det: 0.1857 | W-NPS: 0.7283 | W-TV: 2.6744 | YOLO force: 1.279355 | NPS & TV force: 1.169956
# Step   96/480 | Batch Avg Det: 0.1122 | W-NPS: 0.7160 | W-TV: 2.6636 | YOLO force: 2.276576 | NPS & TV force: 1.164977
# Step  108/480 | Batch Avg Det: 0.1223 | W-NPS: 0.7027 | W-TV: 2.6509 | YOLO force: 2.636052 | NPS & TV force: 1.148240
# Step  120/480 | Batch Avg Det: 0.2670 | W-NPS: 0.6907 | W-TV: 2.6404 | YOLO force: 4.154648 | NPS & TV force: 1.128703
# Step  132/480 | Batch Avg Det: 0.0435 | W-NPS: 0.6837 | W-TV: 2.6402 | YOLO force: 1.741181 | NPS & TV force: 1.129925
# Step  144/480 | Batch Avg Det: 0.0881 | W-NPS: 0.6807 | W-TV: 2.6409 | YOLO force: 2.305142 | NPS & TV force: 1.156882
# Step  156/480 | Batch Avg Det: 0.1092 | W-NPS: 0.6798 | W-TV: 2.6422 | YOLO force: 3.577897 | NPS & TV force: 1.167944
# Step  168/480 | Batch Avg Det: 0.0983 | W-NPS: 0.6816 | W-TV: 2.6377 | YOLO force: 2.676312 | NPS & TV force: 1.175516
# Step  180/480 | Batch Avg Det: 0.1255 | W-NPS: 0.6842 | W-TV: 2.6308 | YOLO force: 2.571429 | NPS & TV force: 1.166054
# Step  192/480 | Batch Avg Det: 0.1419 | W-NPS: 0.6876 | W-TV: 2.6244 | YOLO force: 1.857204 | NPS & TV force: 1.149009
# Step  204/480 | Batch Avg Det: 0.0960 | W-NPS: 0.6892 | W-TV: 2.6173 | YOLO force: 4.145417 | NPS & TV force: 1.125351
# Step  216/480 | Batch Avg Det: 0.1638 | W-NPS: 0.6848 | W-TV: 2.6195 | YOLO force: 2.630290 | NPS & TV force: 1.120196
# Step  228/480 | Batch Avg Det: 0.0762 | W-NPS: 0.6807 | W-TV: 2.6259 | YOLO force: 2.226052 | NPS & TV force: 1.138429
# Step  240/480 | Batch Avg Det: 0.0580 | W-NPS: 0.6795 | W-TV: 2.6343 | YOLO force: 1.319810 | NPS & TV force: 1.149398
# Step  252/480 | Batch Avg Det: 0.1161 | W-NPS: 0.6777 | W-TV: 2.6401 | YOLO force: 1.310812 | NPS & TV force: 1.166007
# Step  264/480 | Batch Avg Det: 0.1752 | W-NPS: 0.6736 | W-TV: 2.6414 | YOLO force: 2.678675 | NPS & TV force: 1.165326
# Step  276/480 | Batch Avg Det: 0.1115 | W-NPS: 0.6700 | W-TV: 2.6404 | YOLO force: 3.161073 | NPS & TV force: 1.151397
# Step  288/480 | Batch Avg Det: 0.0754 | W-NPS: 0.6674 | W-TV: 2.6400 | YOLO force: 1.297682 | NPS & TV force: 1.137141
# Step  300/480 | Batch Avg Det: 0.1247 | W-NPS: 0.6623 | W-TV: 2.6390 | YOLO force: 1.507697 | NPS & TV force: 1.131097
# Step  312/480 | Batch Avg Det: 0.0914 | W-NPS: 0.6563 | W-TV: 2.6386 | YOLO force: 2.853911 | NPS & TV force: 1.130603
# Step  324/480 | Batch Avg Det: 0.1231 | W-NPS: 0.6522 | W-TV: 2.6395 | YOLO force: 3.423514 | NPS & TV force: 1.138353
# Step  336/480 | Batch Avg Det: 0.0670 | W-NPS: 0.6504 | W-TV: 2.6410 | YOLO force: 1.801323 | NPS & TV force: 1.131148
# Step  348/480 | Batch Avg Det: 0.1908 | W-NPS: 0.6505 | W-TV: 2.6402 | YOLO force: 2.421722 | NPS & TV force: 1.135239
# Step  360/480 | Batch Avg Det: 0.1096 | W-NPS: 0.6546 | W-TV: 2.6386 | YOLO force: 1.402842 | NPS & TV force: 1.132182
# Step  372/480 | Batch Avg Det: 0.0344 | W-NPS: 0.6580 | W-TV: 2.6355 | YOLO force: 1.294611 | NPS & TV force: 1.125269
# Step  384/480 | Batch Avg Det: 0.1699 | W-NPS: 0.6602 | W-TV: 2.6291 | YOLO force: 2.840948 | NPS & TV force: 1.117145
# Step  396/480 | Batch Avg Det: 0.2093 | W-NPS: 0.6593 | W-TV: 2.6220 | YOLO force: 1.964247 | NPS & TV force: 1.113582
# Step  408/480 | Batch Avg Det: 0.0795 | W-NPS: 0.6573 | W-TV: 2.6167 | YOLO force: 1.707255 | NPS & TV force: 1.114957
# Step  420/480 | Batch Avg Det: 0.0976 | W-NPS: 0.6545 | W-TV: 2.6103 | YOLO force: 0.628603 | NPS & TV force: 1.108333
# Step  432/480 | Batch Avg Det: 0.1739 | W-NPS: 0.6488 | W-TV: 2.6010 | YOLO force: 1.742669 | NPS & TV force: 1.084651
# Step  444/480 | Batch Avg Det: 0.2105 | W-NPS: 0.6405 | W-TV: 2.5880 | YOLO force: 2.966242 | NPS & TV force: 1.082801
# Step  456/480 | Batch Avg Det: 0.1276 | W-NPS: 0.6339 | W-TV: 2.5784 | YOLO force: 2.091265 | NPS & TV force: 1.083294
# Step  468/480 | Batch Avg Det: 0.1258 | W-NPS: 0.6295 | W-TV: 2.5704 | YOLO force: 0.110155 | NPS & TV force: 1.080892
# Step  480/480 | Batch Avg Det: 0.0606 | W-NPS: 0.6227 | W-TV: 2.5604 | YOLO force: 2.615660 | NPS & TV force: 1.079220
# >> EPOCH 9 SUMMARY | Train Det: 0.1232 | Val Det: 0.1076 | LR: 0.017602 <<
#
# --- Epoch 10/15 ---
# Step   12/480 | Batch Avg Det: 0.1019 | W-NPS: 0.6163 | W-TV: 2.5487 | YOLO force: 2.648333 | NPS & TV force: 1.067652
# Step   24/480 | Batch Avg Det: 0.1433 | W-NPS: 0.6130 | W-TV: 2.5363 | YOLO force: 2.327145 | NPS & TV force: 1.053995
# Step   36/480 | Batch Avg Det: 0.0604 | W-NPS: 0.6123 | W-TV: 2.5281 | YOLO force: 1.124161 | NPS & TV force: 1.044513
# Step   48/480 | Batch Avg Det: 0.0628 | W-NPS: 0.6119 | W-TV: 2.5213 | YOLO force: 1.414222 | NPS & TV force: 1.033567
# Step   60/480 | Batch Avg Det: 0.1477 | W-NPS: 0.6123 | W-TV: 2.5160 | YOLO force: 1.334916 | NPS & TV force: 1.026163
# Step   72/480 | Batch Avg Det: 0.1353 | W-NPS: 0.6110 | W-TV: 2.5109 | YOLO force: 1.371786 | NPS & TV force: 1.035550
# Step   84/480 | Batch Avg Det: 0.1313 | W-NPS: 0.6068 | W-TV: 2.5020 | YOLO force: 1.498417 | NPS & TV force: 1.026800
# Step   96/480 | Batch Avg Det: 0.1446 | W-NPS: 0.6029 | W-TV: 2.4934 | YOLO force: 2.102822 | NPS & TV force: 1.021743
# Step  108/480 | Batch Avg Det: 0.1640 | W-NPS: 0.5964 | W-TV: 2.4877 | YOLO force: 3.474551 | NPS & TV force: 1.019826
# Step  120/480 | Batch Avg Det: 0.0602 | W-NPS: 0.5868 | W-TV: 2.4843 | YOLO force: 1.925045 | NPS & TV force: 1.020776
# Step  132/480 | Batch Avg Det: 0.0775 | W-NPS: 0.5787 | W-TV: 2.4826 | YOLO force: 2.353796 | NPS & TV force: 1.013653
# Step  144/480 | Batch Avg Det: 0.1223 | W-NPS: 0.5709 | W-TV: 2.4826 | YOLO force: 2.141402 | NPS & TV force: 1.017657
# Step  156/480 | Batch Avg Det: 0.1212 | W-NPS: 0.5657 | W-TV: 2.4864 | YOLO force: 2.820355 | NPS & TV force: 1.036841
# Step  168/480 | Batch Avg Det: 0.1631 | W-NPS: 0.5595 | W-TV: 2.4943 | YOLO force: 2.541458 | NPS & TV force: 1.048123
# Step  180/480 | Batch Avg Det: 0.1144 | W-NPS: 0.5537 | W-TV: 2.5011 | YOLO force: 4.164393 | NPS & TV force: 1.048306
# Step  192/480 | Batch Avg Det: 0.2502 | W-NPS: 0.5514 | W-TV: 2.5159 | YOLO force: 2.477297 | NPS & TV force: 1.074386
# Step  204/480 | Batch Avg Det: 0.0338 | W-NPS: 0.5525 | W-TV: 2.5309 | YOLO force: 1.741238 | NPS & TV force: 1.086125
# Step  216/480 | Batch Avg Det: 0.0456 | W-NPS: 0.5556 | W-TV: 2.5445 | YOLO force: 1.544689 | NPS & TV force: 1.103642
# Step  228/480 | Batch Avg Det: 0.1844 | W-NPS: 0.5594 | W-TV: 2.5561 | YOLO force: 2.321711 | NPS & TV force: 1.133434
# Step  240/480 | Batch Avg Det: 0.0646 | W-NPS: 0.5615 | W-TV: 2.5649 | YOLO force: 0.893570 | NPS & TV force: 1.129321
# Step  252/480 | Batch Avg Det: 0.1671 | W-NPS: 0.5600 | W-TV: 2.5708 | YOLO force: 3.937628 | NPS & TV force: 1.123455
# Step  264/480 | Batch Avg Det: 0.1411 | W-NPS: 0.5608 | W-TV: 2.5790 | YOLO force: 3.119612 | NPS & TV force: 1.136000
# Step  276/480 | Batch Avg Det: 0.2036 | W-NPS: 0.5661 | W-TV: 2.5894 | YOLO force: 1.570204 | NPS & TV force: 1.140358
# Step  288/480 | Batch Avg Det: 0.0870 | W-NPS: 0.5726 | W-TV: 2.5981 | YOLO force: 1.848340 | NPS & TV force: 1.145985
# Step  300/480 | Batch Avg Det: 0.1207 | W-NPS: 0.5782 | W-TV: 2.6063 | YOLO force: 1.875317 | NPS & TV force: 1.145818
# Step  312/480 | Batch Avg Det: 0.1222 | W-NPS: 0.5819 | W-TV: 2.6128 | YOLO force: 2.947379 | NPS & TV force: 1.145026
# Step  324/480 | Batch Avg Det: 0.0646 | W-NPS: 0.5847 | W-TV: 2.6170 | YOLO force: 1.612419 | NPS & TV force: 1.145414
# Step  336/480 | Batch Avg Det: 0.1038 | W-NPS: 0.5845 | W-TV: 2.6170 | YOLO force: 3.316118 | NPS & TV force: 1.141703
# Step  348/480 | Batch Avg Det: 0.0760 | W-NPS: 0.5842 | W-TV: 2.6164 | YOLO force: 2.340705 | NPS & TV force: 1.129962
# Step  360/480 | Batch Avg Det: 0.1323 | W-NPS: 0.5807 | W-TV: 2.6150 | YOLO force: 2.235951 | NPS & TV force: 1.134905
# Step  372/480 | Batch Avg Det: 0.2238 | W-NPS: 0.5766 | W-TV: 2.6155 | YOLO force: 1.734918 | NPS & TV force: 1.120293
# Step  384/480 | Batch Avg Det: 0.0933 | W-NPS: 0.5724 | W-TV: 2.6152 | YOLO force: 1.906047 | NPS & TV force: 1.133832
# Step  396/480 | Batch Avg Det: 0.1917 | W-NPS: 0.5683 | W-TV: 2.6121 | YOLO force: 0.098824 | NPS & TV force: 1.120623
# Step  408/480 | Batch Avg Det: 0.0959 | W-NPS: 0.5616 | W-TV: 2.6066 | YOLO force: 2.222342 | NPS & TV force: 1.118619
# ...
# Step  372/480 | Batch Avg Det: 0.1011 | W-NPS: 0.3734 | W-TV: 2.5532 | YOLO force: 3.697950 | NPS & TV force: 1.006852
# Step  384/480 | Batch Avg Det: 0.0671 | W-NPS: 0.3706 | W-TV: 2.5535 | YOLO force: 1.459615 | NPS & TV force: 1.017065
# Step  396/480 | Batch Avg Det: 0.1451 | W-NPS: 0.3679 | W-TV: 2.5533 | YOLO force: 1.773793 | NPS & TV force: 1.022913
# Step  408/480 | Batch Avg Det: 0.1260 | W-NPS: 0.3650 | W-TV: 2.5526 | YOLO force: 2.660273 | NPS & TV force: 1.027056
# Step  420/480 | Batch Avg Det: 0.1505 | W-NPS: 0.3617 | W-TV: 2.5518 | YOLO force: 0.744912 | NPS & TV force: 1.040242
# Step  432/480 | Batch Avg Det: 0.0551 | W-NPS: 0.3583 | W-TV: 2.5505 | YOLO force: 1.568159 | NPS & TV force: 1.043216
# Step  444/480 | Batch Avg Det: 0.1519 | W-NPS: 0.3538 | W-TV: 2.5485 | YOLO force: 0.324236 | NPS & TV force: 1.039759
# Step  456/480 | Batch Avg Det: 0.1332 | W-NPS: 0.3488 | W-TV: 2.5451 | YOLO force: 3.183617 | NPS & TV force: 1.029355
# Step  468/480 | Batch Avg Det: 0.0676 | W-NPS: 0.3443 | W-TV: 2.5424 | YOLO force: 1.893066 | NPS & TV force: 1.024598
# Step  480/480 | Batch Avg Det: 0.1109 | W-NPS: 0.3393 | W-TV: 2.5392 | YOLO force: 4.034024 | NPS & TV force: 1.021965
# >> EPOCH 12 SUMMARY | Train Det: 0.1203 | Val Det: 0.1072 | LR: 0.005227 <<
#
# --- Epoch 13/15 ---
# Step   12/480 | Batch Avg Det: 0.1807 | W-NPS: 0.3348 | W-TV: 2.5375 | YOLO force: 2.675715 | NPS & TV force: 1.009540
# Step   24/480 | Batch Avg Det: 0.1192 | W-NPS: 0.3315 | W-TV: 2.5382 | YOLO force: 2.387893 | NPS & TV force: 1.006951
# Step   36/480 | Batch Avg Det: 0.0904 | W-NPS: 0.3294 | W-TV: 2.5401 | YOLO force: 2.893795 | NPS & TV force: 1.022489
# Step   48/480 | Batch Avg Det: 0.1758 | W-NPS: 0.3284 | W-TV: 2.5435 | YOLO force: 2.529535 | NPS & TV force: 1.032391
# Step   60/480 | Batch Avg Det: 0.0784 | W-NPS: 0.3278 | W-TV: 2.5478 | YOLO force: 1.409194 | NPS & TV force: 1.035385
# Step   72/480 | Batch Avg Det: 0.1104 | W-NPS: 0.3268 | W-TV: 2.5516 | YOLO force: 2.579242 | NPS & TV force: 1.042388
# Step   84/480 | Batch Avg Det: 0.1630 | W-NPS: 0.3253 | W-TV: 2.5554 | YOLO force: 2.550195 | NPS & TV force: 1.050569
# Step   96/480 | Batch Avg Det: 0.0720 | W-NPS: 0.3237 | W-TV: 2.5583 | YOLO force: 2.123328 | NPS & TV force: 1.054599
# Step  108/480 | Batch Avg Det: 0.1355 | W-NPS: 0.3219 | W-TV: 2.5612 | YOLO force: 3.734082 | NPS & TV force: 1.062031
# Step  120/480 | Batch Avg Det: 0.1664 | W-NPS: 0.3219 | W-TV: 2.5639 | YOLO force: 2.429796 | NPS & TV force: 1.064383
# Step  132/480 | Batch Avg Det: 0.1409 | W-NPS: 0.3213 | W-TV: 2.5667 | YOLO force: 1.545667 | NPS & TV force: 1.071545
# Step  144/480 | Batch Avg Det: 0.1026 | W-NPS: 0.3198 | W-TV: 2.5679 | YOLO force: 2.715185 | NPS & TV force: 1.066271
# Step  156/480 | Batch Avg Det: 0.1473 | W-NPS: 0.3188 | W-TV: 2.5689 | YOLO force: 0.744522 | NPS & TV force: 1.071544
# Step  168/480 | Batch Avg Det: 0.0920 | W-NPS: 0.3170 | W-TV: 2.5686 | YOLO force: 2.046374 | NPS & TV force: 1.068511
# Step  180/480 | Batch Avg Det: 0.1491 | W-NPS: 0.3141 | W-TV: 2.5681 | YOLO force: 3.900090 | NPS & TV force: 1.069853
# Step  192/480 | Batch Avg Det: 0.1385 | W-NPS: 0.3126 | W-TV: 2.5691 | YOLO force: 1.005975 | NPS & TV force: 1.078803
# Step  204/480 | Batch Avg Det: 0.1231 | W-NPS: 0.3103 | W-TV: 2.5689 | YOLO force: 3.044651 | NPS & TV force: 1.067752
# Step  216/480 | Batch Avg Det: 0.1063 | W-NPS: 0.3087 | W-TV: 2.5682 | YOLO force: 1.458438 | NPS & TV force: 1.060427
# Step  228/480 | Batch Avg Det: 0.0914 | W-NPS: 0.3070 | W-TV: 2.5670 | YOLO force: 3.073201 | NPS & TV force: 1.046972
# Step  240/480 | Batch Avg Det: 0.1480 | W-NPS: 0.3051 | W-TV: 2.5666 | YOLO force: 1.737081 | NPS & TV force: 1.038178
# Step  252/480 | Batch Avg Det: 0.2017 | W-NPS: 0.3031 | W-TV: 2.5656 | YOLO force: 1.580697 | NPS & TV force: 1.044729
# Step  264/480 | Batch Avg Det: 0.0748 | W-NPS: 0.3008 | W-TV: 2.5647 | YOLO force: 0.655238 | NPS & TV force: 1.040095
# Step  276/480 | Batch Avg Det: 0.2040 | W-NPS: 0.2983 | W-TV: 2.5631 | YOLO force: 3.662548 | NPS & TV force: 1.027025
# Step  288/480 | Batch Avg Det: 0.1710 | W-NPS: 0.2966 | W-TV: 2.5628 | YOLO force: 1.199755 | NPS & TV force: 1.035182
# Step  300/480 | Batch Avg Det: 0.1412 | W-NPS: 0.2948 | W-TV: 2.5621 | YOLO force: 1.675568 | NPS & TV force: 1.032088
# Step  312/480 | Batch Avg Det: 0.0419 | W-NPS: 0.2928 | W-TV: 2.5606 | YOLO force: 1.871406 | NPS & TV force: 1.027165
# Step  324/480 | Batch Avg Det: 0.0964 | W-NPS: 0.2905 | W-TV: 2.5591 | YOLO force: 1.104253 | NPS & TV force: 1.026668
# Step  336/480 | Batch Avg Det: 0.1469 | W-NPS: 0.2877 | W-TV: 2.5572 | YOLO force: 2.174049 | NPS & TV force: 1.024160
# Step  348/480 | Batch Avg Det: 0.0831 | W-NPS: 0.2849 | W-TV: 2.5551 | YOLO force: 1.591335 | NPS & TV force: 1.013220
# Step  360/480 | Batch Avg Det: 0.1864 | W-NPS: 0.2822 | W-TV: 2.5524 | YOLO force: 3.882716 | NPS & TV force: 1.006124
# Step  372/480 | Batch Avg Det: 0.0636 | W-NPS: 0.2793 | W-TV: 2.5510 | YOLO force: 1.411976 | NPS & TV force: 0.999901
# Step  384/480 | Batch Avg Det: 0.0839 | W-NPS: 0.2763 | W-TV: 2.5495 | YOLO force: 2.566013 | NPS & TV force: 0.990854
# Step  396/480 | Batch Avg Det: 0.1343 | W-NPS: 0.2734 | W-TV: 2.5475 | YOLO force: 1.754781 | NPS & TV force: 0.997369
# Step  408/480 | Batch Avg Det: 0.0472 | W-NPS: 0.2712 | W-TV: 2.5454 | YOLO force: 1.230339 | NPS & TV force: 0.988915
# Step  420/480 | Batch Avg Det: 0.2417 | W-NPS: 0.2690 | W-TV: 2.5436 | YOLO force: 1.343056 | NPS & TV force: 0.982160
# Step  432/480 | Batch Avg Det: 0.2287 | W-NPS: 0.2666 | W-TV: 2.5417 | YOLO force: 1.977891 | NPS & TV force: 0.976097
# Step  444/480 | Batch Avg Det: 0.0749 | W-NPS: 0.2644 | W-TV: 2.5402 | YOLO force: 3.423010 | NPS & TV force: 0.967929
# Step  456/480 | Batch Avg Det: 0.0949 | W-NPS: 0.2622 | W-TV: 2.5381 | YOLO force: 1.537307 | NPS & TV force: 0.963169
# Step  468/480 | Batch Avg Det: 0.0769 | W-NPS: 0.2601 | W-TV: 2.5365 | YOLO force: 2.245030 | NPS & TV force: 0.949386
# Step  480/480 | Batch Avg Det: 0.0751 | W-NPS: 0.2581 | W-TV: 2.5356 | YOLO force: 1.882611 | NPS & TV force: 0.950498
# >> EPOCH 13 SUMMARY | Train Det: 0.1250 | Val Det: 0.1080 | LR: 0.002640 <<
#
# --- Epoch 14/15 ---
# Step   12/480 | Batch Avg Det: 0.0781 | W-NPS: 0.2562 | W-TV: 2.5346 | YOLO force: 1.805471 | NPS & TV force: 0.947744
# Step   24/480 | Batch Avg Det: 0.1578 | W-NPS: 0.2542 | W-TV: 2.5336 | YOLO force: 3.387628 | NPS & TV force: 0.957573
# Step   36/480 | Batch Avg Det: 0.1335 | W-NPS: 0.2526 | W-TV: 2.5331 | YOLO force: 1.968899 | NPS & TV force: 0.966172
# Step   48/480 | Batch Avg Det: 0.0923 | W-NPS: 0.2512 | W-TV: 2.5332 | YOLO force: 2.763339 | NPS & TV force: 0.970123
# Step   60/480 | Batch Avg Det: 0.1382 | W-NPS: 0.2497 | W-TV: 2.5334 | YOLO force: 1.799455 | NPS & TV force: 0.971496
# Step   72/480 | Batch Avg Det: 0.0423 | W-NPS: 0.2482 | W-TV: 2.5336 | YOLO force: 1.265764 | NPS & TV force: 0.960196
# Step   84/480 | Batch Avg Det: 0.1270 | W-NPS: 0.2467 | W-TV: 2.5337 | YOLO force: 2.272646 | NPS & TV force: 0.964882
# Step   96/480 | Batch Avg Det: 0.2709 | W-NPS: 0.2451 | W-TV: 2.5343 | YOLO force: 2.927530 | NPS & TV force: 0.966774
# Step  108/480 | Batch Avg Det: 0.0609 | W-NPS: 0.2434 | W-TV: 2.5355 | YOLO force: 2.622160 | NPS & TV force: 0.976803
# Step  120/480 | Batch Avg Det: 0.1976 | W-NPS: 0.2418 | W-TV: 2.5367 | YOLO force: 2.135868 | NPS & TV force: 0.981478
# Step  132/480 | Batch Avg Det: 0.1248 | W-NPS: 0.2405 | W-TV: 2.5374 | YOLO force: 2.543360 | NPS & TV force: 0.980044
# Step  144/480 | Batch Avg Det: 0.1553 | W-NPS: 0.2397 | W-TV: 2.5383 | YOLO force: 2.912091 | NPS & TV force: 0.991919
# Step  156/480 | Batch Avg Det: 0.1665 | W-NPS: 0.2388 | W-TV: 2.5390 | YOLO force: 3.713822 | NPS & TV force: 0.990155
# Step  168/480 | Batch Avg Det: 0.1423 | W-NPS: 0.2379 | W-TV: 2.5399 | YOLO force: 2.664478 | NPS & TV force: 0.998733
# Step  180/480 | Batch Avg Det: 0.1730 | W-NPS: 0.2374 | W-TV: 2.5411 | YOLO force: 3.818569 | NPS & TV force: 0.999236
# Step  192/480 | Batch Avg Det: 0.0466 | W-NPS: 0.2380 | W-TV: 2.5429 | YOLO force: 2.395547 | NPS & TV force: 1.017480
# Step  204/480 | Batch Avg Det: 0.2374 | W-NPS: 0.2386 | W-TV: 2.5445 | YOLO force: 1.205867 | NPS & TV force: 1.028350
# Step  216/480 | Batch Avg Det: 0.1189 | W-NPS: 0.2390 | W-TV: 2.5457 | YOLO force: 1.583216 | NPS & TV force: 1.030788
# Step  228/480 | Batch Avg Det: 0.1181 | W-NPS: 0.2389 | W-TV: 2.5463 | YOLO force: 0.104421 | NPS & TV force: 1.025081
# Step  240/480 | Batch Avg Det: 0.0811 | W-NPS: 0.2383 | W-TV: 2.5462 | YOLO force: 1.747245 | NPS & TV force: 1.021545
# Step  252/480 | Batch Avg Det: 0.1385 | W-NPS: 0.2374 | W-TV: 2.5457 | YOLO force: 0.694964 | NPS & TV force: 1.016081
# Step  264/480 | Batch Avg Det: 0.1826 | W-NPS: 0.2361 | W-TV: 2.5450 | YOLO force: 1.333217 | NPS & TV force: 1.009741
# Step  276/480 | Batch Avg Det: 0.1458 | W-NPS: 0.2345 | W-TV: 2.5441 | YOLO force: 3.118914 | NPS & TV force: 1.001730
# Step  288/480 | Batch Avg Det: 0.0871 | W-NPS: 0.2331 | W-TV: 2.5431 | YOLO force: 1.987211 | NPS & TV force: 0.993184
# Step  300/480 | Batch Avg Det: 0.0534 | W-NPS: 0.2314 | W-TV: 2.5416 | YOLO force: 1.513356 | NPS & TV force: 0.981729
# Step  312/480 | Batch Avg Det: 0.0589 | W-NPS: 0.2296 | W-TV: 2.5404 | YOLO force: 1.858899 | NPS & TV force: 0.976788
# Step  324/480 | Batch Avg Det: 0.0906 | W-NPS: 0.2277 | W-TV: 2.5391 | YOLO force: 2.371086 | NPS & TV force: 0.965409
# Step  336/480 | Batch Avg Det: 0.1172 | W-NPS: 0.2261 | W-TV: 2.5380 | YOLO force: 3.269744 | NPS & TV force: 0.962293
# Step  348/480 | Batch Avg Det: 0.1557 | W-NPS: 0.2248 | W-TV: 2.5375 | YOLO force: 2.546992 | NPS & TV force: 0.978105
# Step  360/480 | Batch Avg Det: 0.2359 | W-NPS: 0.2235 | W-TV: 2.5373 | YOLO force: 2.995687 | NPS & TV force: 0.983088
# Step  372/480 | Batch Avg Det: 0.1180 | W-NPS: 0.2225 | W-TV: 2.5374 | YOLO force: 4.135114 | NPS & TV force: 0.987200
# Step  384/480 | Batch Avg Det: 0.0630 | W-NPS: 0.2217 | W-TV: 2.5379 | YOLO force: 2.779312 | NPS & TV force: 0.999396
# Step  396/480 | Batch Avg Det: 0.1016 | W-NPS: 0.2210 | W-TV: 2.5383 | YOLO force: 2.599673 | NPS & TV force: 0.998195
# Step  408/480 | Batch Avg Det: 0.1524 | W-NPS: 0.2204 | W-TV: 2.5389 | YOLO force: 3.949527 | NPS & TV force: 0.995737
# Step  420/480 | Batch Avg Det: 0.1443 | W-NPS: 0.2201 | W-TV: 2.5398 | YOLO force: 2.278974 | NPS & TV force: 1.003908
# Step  432/480 | Batch Avg Det: 0.0598 | W-NPS: 0.2201 | W-TV: 2.5405 | YOLO force: 1.734556 | NPS & TV force: 1.005743
# Step  444/480 | Batch Avg Det: 0.1877 | W-NPS: 0.2201 | W-TV: 2.5412 | YOLO force: 1.009821 | NPS & TV force: 1.013080
# Step  456/480 | Batch Avg Det: 0.1164 | W-NPS: 0.2198 | W-TV: 2.5415 | YOLO force: 2.105191 | NPS & TV force: 1.013609
# Step  468/480 | Batch Avg Det: 0.1782 | W-NPS: 0.2194 | W-TV: 2.5417 | YOLO force: 2.545505 | NPS & TV force: 1.014397
# Step  480/480 | Batch Avg Det: 0.0786 | W-NPS: 0.2188 | W-TV: 2.5418 | YOLO force: 2.608154 | NPS & TV force: 1.009495
# >> EPOCH 14 SUMMARY | Train Det: 0.1282 | Val Det: 0.1084 | LR: 0.001041 <<
#
# --- Epoch 15/15 ---
# Step   12/480 | Batch Avg Det: 0.1340 | W-NPS: 0.2182 | W-TV: 2.5417 | YOLO force: 1.373318 | NPS & TV force: 1.001159
# Step   24/480 | Batch Avg Det: 0.0486 | W-NPS: 0.2176 | W-TV: 2.5414 | YOLO force: 1.728507 | NPS & TV force: 0.994367
# Step   36/480 | Batch Avg Det: 0.1708 | W-NPS: 0.2169 | W-TV: 2.5410 | YOLO force: 1.752559 | NPS & TV force: 0.985888
# Step   48/480 | Batch Avg Det: 0.2350 | W-NPS: 0.2160 | W-TV: 2.5404 | YOLO force: 3.360708 | NPS & TV force: 0.978945
# Step   60/480 | Batch Avg Det: 0.1837 | W-NPS: 0.2153 | W-TV: 2.5400 | YOLO force: 3.102560 | NPS & TV force: 0.974143
# Step   72/480 | Batch Avg Det: 0.0807 | W-NPS: 0.2147 | W-TV: 2.5398 | YOLO force: 1.042193 | NPS & TV force: 0.975449
# Step   84/480 | Batch Avg Det: 0.1341 | W-NPS: 0.2140 | W-TV: 2.5395 | YOLO force: 3.593891 | NPS & TV force: 0.962582
# Step   96/480 | Batch Avg Det: 0.2632 | W-NPS: 0.2135 | W-TV: 2.5393 | YOLO force: 1.594677 | NPS & TV force: 0.969054
# Step  108/480 | Batch Avg Det: 0.1358 | W-NPS: 0.2129 | W-TV: 2.5392 | YOLO force: 3.149713 | NPS & TV force: 0.969741
# Step  120/480 | Batch Avg Det: 0.0753 | W-NPS: 0.2126 | W-TV: 2.5392 | YOLO force: 1.309404 | NPS & TV force: 0.977935
# Step  132/480 | Batch Avg Det: 0.0879 | W-NPS: 0.2123 | W-TV: 2.5391 | YOLO force: 2.347661 | NPS & TV force: 0.976386
# Step  144/480 | Batch Avg Det: 0.1412 | W-NPS: 0.2119 | W-TV: 2.5390 | YOLO force: 1.424208 | NPS & TV force: 0.975107
# Step  156/480 | Batch Avg Det: 0.1562 | W-NPS: 0.2115 | W-TV: 2.5388 | YOLO force: 1.860065 | NPS & TV force: 0.971781
# Step  168/480 | Batch Avg Det: 0.1162 | W-NPS: 0.2110 | W-TV: 2.5387 | YOLO force: 3.177277 | NPS & TV force: 0.966517
# Step  180/480 | Batch Avg Det: 0.0745 | W-NPS: 0.2106 | W-TV: 2.5386 | YOLO force: 1.360834 | NPS & TV force: 0.971512
# Step  192/480 | Batch Avg Det: 0.1473 | W-NPS: 0.2101 | W-TV: 2.5385 | YOLO force: 1.603438 | NPS & TV force: 0.968922
# Step  204/480 | Batch Avg Det: 0.1124 | W-NPS: 0.2096 | W-TV: 2.5382 | YOLO force: 0.951786 | NPS & TV force: 0.965907
# Step  216/480 | Batch Avg Det: 0.0849 | W-NPS: 0.2090 | W-TV: 2.5379 | YOLO force: 2.744427 | NPS & TV force: 0.964764
# Step  228/480 | Batch Avg Det: 0.1993 | W-NPS: 0.2084 | W-TV: 2.5374 | YOLO force: 1.543936 | NPS & TV force: 0.955898
# Step  240/480 | Batch Avg Det: 0.1632 | W-NPS: 0.2077 | W-TV: 2.5369 | YOLO force: 1.475578 | NPS & TV force: 0.946493
# Step  252/480 | Batch Avg Det: 0.0989 | W-NPS: 0.2069 | W-TV: 2.5364 | YOLO force: 1.713688 | NPS & TV force: 0.940120
# Step  264/480 | Batch Avg Det: 0.1096 | W-NPS: 0.2061 | W-TV: 2.5360 | YOLO force: 1.516574 | NPS & TV force: 0.935868
# Step  276/480 | Batch Avg Det: 0.1143 | W-NPS: 0.2053 | W-TV: 2.5355 | YOLO force: 3.270995 | NPS & TV force: 0.926264
# Step  288/480 | Batch Avg Det: 0.1013 | W-NPS: 0.2044 | W-TV: 2.5350 | YOLO force: 2.288190 | NPS & TV force: 0.916192
# Step  300/480 | Batch Avg Det: 0.0828 | W-NPS: 0.2036 | W-TV: 2.5345 | YOLO force: 1.293254 | NPS & TV force: 0.911699
# Step  312/480 | Batch Avg Det: 0.2537 | W-NPS: 0.2027 | W-TV: 2.5340 | YOLO force: 2.911711 | NPS & TV force: 0.902648
# Step  324/480 | Batch Avg Det: 0.1367 | W-NPS: 0.2020 | W-TV: 2.5337 | YOLO force: 2.563535 | NPS & TV force: 0.896308
# Step  336/480 | Batch Avg Det: 0.1187 | W-NPS: 0.2014 | W-TV: 2.5335 | YOLO force: 1.752254 | NPS & TV force: 0.893714
# Step  348/480 | Batch Avg Det: 0.0474 | W-NPS: 0.2008 | W-TV: 2.5334 | YOLO force: 2.611957 | NPS & TV force: 0.897797
# Step  360/480 | Batch Avg Det: 0.1201 | W-NPS: 0.2003 | W-TV: 2.5334 | YOLO force: 3.342329 | NPS & TV force: 0.897815
# Step  372/480 | Batch Avg Det: 0.0998 | W-NPS: 0.1998 | W-TV: 2.5335 | YOLO force: 1.864534 | NPS & TV force: 0.900940
# Step  384/480 | Batch Avg Det: 0.1028 | W-NPS: 0.1993 | W-TV: 2.5336 | YOLO force: 2.501677 | NPS & TV force: 0.901602
# Step  396/480 | Batch Avg Det: 0.1503 | W-NPS: 0.1989 | W-TV: 2.5338 | YOLO force: 2.187605 | NPS & TV force: 0.906298
# Step  408/480 | Batch Avg Det: 0.0807 | W-NPS: 0.1984 | W-TV: 2.5340 | YOLO force: 5.381444 | NPS & TV force: 0.908445
# Step  420/480 | Batch Avg Det: 0.1169 | W-NPS: 0.1981 | W-TV: 2.5342 | YOLO force: 1.386259 | NPS & TV force: 0.915854
# Step  432/480 | Batch Avg Det: 0.1535 | W-NPS: 0.1978 | W-TV: 2.5344 | YOLO force: 3.077059 | NPS & TV force: 0.920831
# Step  444/480 | Batch Avg Det: 0.0896 | W-NPS: 0.1976 | W-TV: 2.5346 | YOLO force: 2.817248 | NPS & TV force: 0.931573
# Step  456/480 | Batch Avg Det: 0.0312 | W-NPS: 0.1974 | W-TV: 2.5349 | YOLO force: 0.709371 | NPS & TV force: 0.944973
# Step  468/480 | Batch Avg Det: 0.0765 | W-NPS: 0.1971 | W-TV: 2.5351 | YOLO force: 2.192630 | NPS & TV force: 0.948808
# Step  480/480 | Batch Avg Det: 0.1328 | W-NPS: 0.1967 | W-TV: 2.5353 | YOLO force: 0.109139 | NPS & TV force: 0.951198
# >> EPOCH 15 SUMMARY | Train Det: 0.1240 | Val Det: 0.1084 | LR: 0.000500 <<
#
# Training complete. Patch saved to noise_checkpoints folder.
# Visualizing results on a random test image from the loaded dataset...
